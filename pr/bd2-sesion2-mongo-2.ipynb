# %% [markdown]
# ## NoSQL (MongoDB) (sesión 2), 25-26.

# %% [markdown]
# ## Introducción

# %% [markdown]
# ![MongoDB](https://webassets.mongodb.com/_com_assets/cms/MongoDB_Logo_FullColorBlack_RGB-4td3yuxzjs.png)
#
# Esta hoja muestra cómo acceder a bases de datos MongoDB y también a conectar la salida con Jupyter. Se puede utilizar el *shell* propio de MongoDB en el contenedor usando el programa `mongo`. La diferencia es que ese programa espera código Javascript y aquí trabajaremos con Python.

# %%
import sys

RunningInCOLAB: bool = 'google.colab' in sys.modules

# %% [markdown]
# ## Instalación inicial de MongoDB (sólo necesaria en Google Colab)

# %%
import subprocess
import urllib.request

if RunningInCOLAB:
  urllib.request.urlretrieve("https://raw.githubusercontent.com/dsevilla/bdge/refs/heads/25-26/addendum/mongo-utils/run-mongo-local.sh",
                             "run-mongo-local.sh")
  subprocess.run(["sh", "run-mongo-local.sh"])

# %% [markdown]
# ## Instalación de la librería `pymongo`

# %%
# %pip install --upgrade pymongo 'pandas[performance,parquet]'
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.12/dist-packages (4.16.0)
# Requirement already satisfied: pandas[parquet,performance] in /usr/local/lib/python3.12/dist-packages (3.0.1)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in /usr/local/lib/python3.12/dist-packages (from pymongo) (2.8.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas[parquet,performance]) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas[parquet,performance]) (2.9.0.post0)
# Requirement already satisfied: bottleneck>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from pandas[parquet,performance]) (1.4.2)
# Requirement already satisfied: numba>=0.60.0 in /usr/local/lib/python3.12/dist-packages (from pandas[parquet,performance]) (0.60.0)
# Requirement already satisfied: numexpr>=2.10.2 in /usr/local/lib/python3.12/dist-packages (from pandas[parquet,performance]) (2.14.1)
# Requirement already satisfied: pyarrow>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from pandas[parquet,performance]) (18.1.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60.0->pandas[parquet,performance]) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas[parquet,performance]) (1.17.0)

# %%
from pprint import pprint as pp

import pandas as pd

# %% [markdown]
# Usaremos la librería `pymongo` para python. La cargamos a continuación.

# %%
from pymongo import MongoClient

# %% [markdown]
# ## Conexión a la base de datos

# %% [markdown]
# La conexión se inicia con `MongoClient` en el `host` descrito en el fichero `docker-compose.yml` (establecido en la variable de entorno `DB_HOSTNAME`), o bien a `localhost` si lo estamos haciendo en Colab.

# %%
import os

db_hostname: str = os.getenv('DB_HOSTNAME', "localhost")

# %%
from typing import Any

client: MongoClient[dict[str, Any]] = MongoClient(db_hostname,27017,compressors='zlib')
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, compressors=['zlib'])

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'stackoverflow']

# %% [markdown]
# Las bases de datos se crean conforme se nombran. Se puede utilizar la notación punto o la de diccionario. Las colecciones también se crean implícitamente al insertar un primer documento, o las podemos crear explícitamente.

# %%
from pymongo.collection import Collection
from pymongo.database import Database

db: Database = client.stackoverflow
# db: Database = client['stackoverflow'] # (equivalente)
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, compressors=['zlib']), 'stackoverflow')

# %% [markdown]
# ## Importación de los datos de Stackoverflow
#
# Procedemos a importar los ficheros Parquet, pero antes ponemos el formato y signifcado de los campos de `Stack Overflow` para poder consultarlos si lo necesitamos.

# %% [markdown]
# <details><summary><b>🗂️ Formato datos Stack Overflow</b> <span style="color: #007acc;">▶️ Haz click para ver el esquema y ejemplos</span></summary>
#
# > Notas generales
# - Formato: cada fichero es XML y suele distribuirse 7zipped.
# - Codificación: UTF-8. Los campos de fecha siguen el formato ISO8601: "YYYY-MM-DDTHH:mm:ss.fff".
# - Nulos: cuando un campo no aplica (p.ej., `ParentId` en preguntas), no aparece o viene vacío; en nuestros Parquet suele ser `null`.
# - Identificadores: `Id` es clave primaria en cada entidad. Claves foráneas enlazan por `Id` entre ficheros.
#
# ---
#
# :file_folder: <b>badges.xml</b> (insignias logradas por usuarios)
# - UserId: Id del usuario que recibe la insignia. Ej: 420. Uso: FK a `users.Id`.
# - Name: Nombre de la insignia. Ej: "Teacher". Uso: clasificar tipo de logro.
# - Date: Fecha de concesión. Ej: "2008-09-15T08:55:03.923". Uso: series temporales.
# - Class: Categoría (1=Gold, 2=Silver, 3=Bronze). Ej: 3. Uso: nivel de la insignia.
# - TagBased: Si la insignia es específica de etiqueta. Ej: true. Uso: filtrar logros por etiquetas.
#
# ---
#
# :file_folder: <b>comments.xml</b> (comentarios en publicaciones)
# - Id: Identificador del comentario. Ej: 12345. Uso: PK.
# - PostId: Publicación a la que comenta. Ej: 100234. Uso: FK a `posts.Id`.
# - Score: Puntuación del comentario. Ej: 5. Uso: ordenar/filtrar relevancia.
# - Text: Texto del comentario. Ej: "¿Puedes compartir el error exacto?". Uso: contenido.
# - CreationDate: Fecha de creación. Ej: "2008-09-06T08:07:10.730". Uso: análisis temporal.
# - UserId: Autor del comentario. Ej: 314159. Uso: FK a `users.Id`.
# - UserDisplayName: Nombre mostrado si el usuario fue eliminado. Ej: "user123". Uso: se usa cuando `UserId` es nulo/ausente.
# - ContentLicense: Licencia del contenido. Ej: "CC BY-SA 4.0". Uso: cumplimiento/licencias.
#
# ---
#
# :file_folder: <b>posts.xml</b> (preguntas y respuestas)
# - Id: Identificador de la publicación. Ej: 98765. Uso: PK.
# - PostTypeId: Tipo (1=Pregunta, 2=Respuesta). Ej: 1. Uso: rutas de procesamiento/particionado.
# - ParentId: Id de la pregunta padre si es respuesta. Ej: 1234. Uso: FK a `posts.Id` (solo si `PostTypeId=2`).
# - AcceptedAnswerId: Id de la respuesta aceptada (solo en preguntas). Ej: 4567. Uso: FK a `posts.Id` para marcar aceptadas.
# - CreationDate: Fecha de creación. Ej: "2010-02-15T10:21:34.120". Uso: análisis temporal.
# - Score: Votos netos (upvotes-downvotes). Ej: 42. Uso: ranking/calidad.
# - ViewCount: Nº de vistas (solo preguntas). Ej: 12345. Uso: popularidad.
# - Body: HTML/Markdown del cuerpo. Ej: "<p>¿Cómo...?</p>". Uso: contenido/NLP.
# - OwnerUserId: Autor. Ej: 271828. Uso: FK a `users.Id`.
# - OwnerDisplayName: Nombre mostrado si el autor fue eliminado. Ej: "John Doe". Uso: se usa cuando `OwnerUserId` es nulo (usuario eliminado o anónimo).
# - LastEditorUserId: Último usuario que editó. Ej: 314159. Uso: FK a `users.Id`.
# - LastEditorDisplayName: Nombre si el editor fue eliminado. Ej: "Community". Uso: solo cuando `LastEditorUserId` es nulo.
# - LastEditDate: Fecha de última edición. Ej: "2009-03-05T22:28:34.823". Uso: auditoría.
# - LastActivityDate: Última actividad (edición, comentario, etc.). Ej: "2009-03-11T12:51:01.480". Uso: ordenación por actividad reciente.
# - CommunityOwnedDate: Fecha desde la que es de la comunidad. Ej: "2009-03-11T12:51:01.480". Uso: gobernanza.
# - ClosedDate: Fecha de cierre (si procede). Ej: "2012-01-01T12:00:00.000". Uso: moderación.
# - Title: Título de la pregunta. Ej: "¿Cómo unir listas en Python?". Uso: metadata/búsqueda.
# - Tags: Lista de etiquetas en formato XML/HTML: "<python><list><merge>". Uso: clasificación por tema.
# - AnswerCount: Nº de respuestas (en preguntas). Ej: 5. Uso: engagement.
# - CommentCount: Nº de comentarios. Ej: 3. Uso: actividad.
# - FavoriteCount: Favoritos marcados (legacy). Ej: 10. Uso: popularidad histórica.
# - ContentLicense: Licencia. Ej: "CC BY-SA 4.0". Uso: cumplimiento.
#
# ---
#
# :file_folder: <b>posthistory.xml</b> (historial detallado de cambios)
# - Id: PK del evento de historial. Ej: 5555.
# - PostHistoryTypeId: Tipo de cambio. Uso: clasifica el evento. Ejemplos:
#   - 1: Initial Title – primer título de la pregunta.
#   - 2: Initial Body – primer cuerpo en crudo.
#   - 3: Initial Tags – primeras etiquetas.
#   - 4: Edit Title – cambio de título.
#   - 5: Edit Body – cambio de cuerpo (markdown crudo).
#   - 6: Edit Tags – cambio de etiquetas.
#   - 7/8/9: Rollback Title/Body/Tags – revertidos.
#   - 10: Post Closed – cierre por votos.
#   - 11: Post Reopened – reapertura.
#   - 12/13: Post Deleted/Undeleted – borrado/restaurado.
#   - 14/15: Post Locked/Unlocked – bloqueado/desbloqueado.
#   - 16: Community Owned – pasa a comunidad.
#   - 17: Post Migrated – migración (origen/destino).
#   - 18: Question Merged – fusión de preguntas.
#   - 19/20: Question Protected/Unprotected – protegido/desprotegido.
#   - 21: Post Disassociated – se elimina el OwnerUserId.
#   - 22: Question Unmerged – deshace fusión.
# - PostId: Publicación afectada. Ej: 98765. Uso: FK a `posts.Id`.
# - RevisionGUID: Agrupa múltiples registros de un mismo acto. Ej: "3E5B...". Uso: correlación.
# - CreationDate: Fecha del evento. Ej: "2009-03-05T22:28:34.823".
# - UserId: Usuario que realiza el cambio. Ej: 271828. Uso: FK a `users.Id`.
# - UserDisplayName: Si el usuario fue eliminado. Ej: "user123". Uso: cuando `UserId` nulo.
# - Comment: Comentario del editor. Ej: "typo fix". Uso: auditoría.
# - Text: Valor crudo nuevo asociado al cambio. Ej: nuevo markdown o JSON.
#   - Para tipos 10–15: JSON con usuarios que han votado esa acción de moderación.
#   - Para tipo 17: Detalles de migración: "from <url>" o "to <url>".
# - CloseReasonId: Motivo de cierre (histórico). Ejemplos:
#   - 1: Exact Duplicate – duplicada de otra.
#   - 2: off-topic – fuera de tema.
#   - 3: subjective – demasiado subjetiva.
#   - 4: not a real question – no es una pregunta real.
#   - 7: too localized – demasiado localizada.
#
# ---
#
# :file_folder: <b>postlinks.xml</b> (enlaces entre publicaciones)
# - Id: PK del enlace. Ej: 2222.
# - CreationDate: Fecha del enlace. Ej: "2011-05-05T10:00:00.000".
# - PostId: Publicación origen. Ej: 1000. Uso: FK a `posts.Id`.
# - RelatedPostId: Publicación destino. Ej: 1001. Uso: FK a `posts.Id`.
# - PostLinkTypeId: Tipo de relación. Uso: grafo entre posts.
#   - 1: Linked – relacionados.
#   - 3: Duplicate – duplicados.
#
# ---
#
# :file_folder: <b>users.xml</b> (usuarios)
# - Id: PK del usuario. Ej: 271828.
# - AccountId: Id de cuenta en la red Stack Exchange. Ej: 123456. Uso: consolidación multi-sitio.
# - Reputation: Reputación. Ej: 15234. Uso: privilegios/ordenación.
# - CreationDate: Alta del usuario. Ej: "2008-07-31T21:42:52.667".
# - DisplayName: Nombre mostrado. Ej: "Jane Doe". Uso: UI.
# - EmailHash: Hash MD5 de email (legacy). Ej: "fcea920f...". Uso: avatar histórico.
# - LastAccessDate: Último acceso. Ej: "2020-04-01T12:00:00.000". Uso: actividad.
# - WebsiteUrl: Web personal. Ej: "https://janedoe.dev".
# - Location: Ubicación libre. Ej: "Madrid, ES".
# - Age: Edad (cuando se compartía). Ej: 32.
# - AboutMe: BIO en HTML/Markdown. Ej: "<p>Desarrollo datos...</p>".
# - Views: Visitas al perfil. Ej: 1234.
# - UpVotes: Upvotes emitidos por el usuario. Ej: 500.
# - DownVotes: Downvotes emitidos. Ej: 20.
# - ProfileImageUrl: Avatar. Ej: "https://.../image.png".
#
# ---
#
# :file_folder: <b>votes.xml</b> (votos a publicaciones)
# - Id: PK del voto. Ej: 7777.
# - PostId: Publicación votada. Ej: 98765. Uso: FK a `posts.Id`.
# - VoteTypeId: Tipo de voto/acción. Uso: métricas de calidad/moderación.
#   - 1: AcceptedByOriginator – el autor de la pregunta acepta una respuesta (equivale a `AcceptedAnswerId`).
#   - 2: UpMod – upvote.
#   - 3: DownMod – downvote.
#   - 4: Offensive – ofensivo (legacy).
#   - 5: Favorite – marcado como favorito (legacy); si `VoteTypeId=5`, `UserId` se rellena.
#   - 6: Close – voto de cierre.
#   - 7: Reopen – voto de reapertura.
#   - 8: BountyStart – inicio de recompensa.
#   - 9: BountyClose – cierre de recompensa; si `VoteTypeId=9`, `BountyAmount` se rellena.
#   - 10: Deletion – voto de borrado.
#   - 11: Undeletion – voto de restauración.
#   - 12: Spam – marcado como spam.
#   - 13: InformModerator – informar a moderación.
# - CreationDate: Fecha del voto. Ej: "2015-06-10T09:30:00.000".
# - UserId: Usuario que vota (solo para algunos tipos como 5). Ej: 54321. Uso: FK a `users.Id`.
# - BountyAmount: Cantidad de recompensa (solo tipo 9). Ej: 100.
#
# ---
#
# :file_folder: <b>tags.xml</b> (etiquetas del sitio)
# - Id: PK de la etiqueta. Ej: 42.
# - TagName: Nombre de la etiqueta. Ej: "python". Uso: clasificación temática.
# - Count: Nº de usos en preguntas. Ej: 150234. Uso: popularidad.
# - ExcerptPostId: Id del post con el extracto de la wiki de etiqueta. Ej: 123. Uso: FK a `posts.Id`.
# - WikiPostId: Id del post con el artículo de la wiki de etiqueta. Ej: 124. Uso: FK a `posts.Id`.
#
# </details>

# %% [markdown]
# Importamos los ficheros Parquet, primero definiendo las funciones que se necesitan, y después ejecutándolas.

# %%
from asyncio import Queue, Task, create_task, to_thread

from pandas import DataFrame


def load_dataframe(parquetfile: str, logqueue: Queue[str] | None = None) -> DataFrame:
    BASE_URL: str = "https://github.com/dsevilla/bd2-data/releases/download/parquet-files-25-26/"
    try:
        df: DataFrame = pd.read_parquet(f"{BASE_URL}/{parquetfile}", dtype_backend="pyarrow")
        logqueue.put_nowait(f"Loaded {len(df)} rows from dataframe.") if logqueue else None

        # A MongoDB no le gusta el tipo pd.NaT, así que lo convertimos a None (null en MongoDB)
        return df.replace({pd.NaT: None})

    except Exception as e:
        logqueue.put_nowait(f"Error loading Dataframe: {e}.") if logqueue else None
        raise e

# %%
from pymongo.results import InsertManyResult


def insert_dataframe_into_mongo(
    collection: Collection, df: DataFrame, logqueue: Queue | None = None
) -> InsertManyResult:
    result: InsertManyResult = collection.insert_many(
        df.to_dict("records"), ordered=False, bypass_document_validation=True
    )
    logqueue.put_nowait(f"Inserted {len(df)} records into MongoDB.") if logqueue else None
    return result


def load_parquet_into_mongo(
    collection: Collection,
    parquetfile: str,
    logqueue: Queue[str] | None = None,
) -> InsertManyResult:
    df: DataFrame = load_dataframe(parquetfile, logqueue)
    try:
        return insert_dataframe_into_mongo(collection, df, logqueue)
    except Exception as e:
        logqueue.put_nowait(f"Error inserting DataFrame into MongoDB: {e}.") if logqueue else None
        raise e
    finally:
        del df  # Free memory

# %% [markdown]
# Importación de los ficheros Parquet. Por ahora creamos una colección diferente para cada uno. Después estudiaremos cómo poder optimizar el acceso usando agregación.

# %% [markdown]
# Creamos un índice para el campo 'Id' en la colección de tags.

# %%
tags_collection: Collection[dict[str, Any]] = db["tags"]
tags_collection.create_index([("Id", 1)], unique=True)
# Out:
# 'Id_1'

# %% [markdown]
# Se crea una cola de mensajes (`Queue`) para que los procesos en segundo plano puedan ir mostrando el progreso de la importación. En cualquier momento se puede leer mensajes de esa cola (si están disponibles) y podemos ver si se ha producido algún error o si se ha terminado de procesar los elementos.
#
# La importación de los *Tags* se realiza en primer plano porque es pequeña. El resto de colecciones las importaremos en segundo plano (con un hilo o *thread*).

# %%
# No añadir datos si ya existe la colección
existing_tags_count: int = tags_collection.count_documents({})
if existing_tags_count > 0:
    print("La colección Tags ya existe. No se realiza la importación. Elimínala con drop().")
else:
    insert_tags_queue: Queue[str] = Queue()
    load_parquet_into_mongo(tags_collection, "Tags.parquet", insert_tags_queue)
    while not insert_tags_queue.empty():
        log_message: str = await insert_tags_queue.get()
        print(log_message)
# Out:
# La colección Tags ya existe. No se realiza la importación. Elimínala con drop().

# %%
tags_collection.find_one()
# Out:
# {'_id': ObjectId('69a8d751736d6c0569d1feb5'),
#  'Id': 1,
#  'Count': 1472,
#  'ExcerptPostId': 680,
#  'TagName': '.net',
#  'WikiPostId': 679}

# %% [markdown]
# Importamos los datos de Stackoverflow. Lo haremos en paralelo con todas las colecciones restantes:

# %%
users_collection: Collection[dict[str, Any]] = db["users"]
users_collection.create_index([("Id", 1)], unique=True)

users_load_task: Task[InsertManyResult] = create_task(
    to_thread(load_parquet_into_mongo, users_collection, "Users.parquet")
)

# %%
posts_collection: Collection[dict[str, Any]] = db["posts"]
posts_collection.create_index([("Id", 1)], unique=True)

posts_load_queue: Queue[str] = Queue()
posts_load_task: Task[InsertManyResult] = create_task(
    to_thread(load_parquet_into_mongo, posts_collection, "Posts.parquet", posts_load_queue)
)

# %%
comments_collection: Collection[dict[str, Any]] = db["comments"]
comments_collection.create_index([("Id", 1)], unique=True)

comments_load_queue: Queue[str] = Queue()
comments_load_task: Task[InsertManyResult] = create_task(
    to_thread(load_parquet_into_mongo, comments_collection, "Comments.parquet", comments_load_queue)
)

# %%
votes_collection: Collection[dict[str, Any]] = db["votes"]
votes_collection.create_index([("Id", 1)], unique=True)

votes_load_queue: Queue[str] = Queue()
votes_load_task: Task[InsertManyResult] = create_task(
    to_thread(load_parquet_into_mongo, votes_collection, "Votes.parquet", votes_load_queue)
)

# %%
print(f"Post loading done: {posts_load_task.done()}.")
while not posts_load_queue.empty():
    log_message: str = posts_load_queue.get_nowait()
    print(log_message)
# Out:
# Post loading done: False.

# %%
users_load_task.done()
# Out:
# False

# %%
comments_load_task.done()
# Out:
# False

# %%
votes_load_task.done()
# Out:
# False

# %% [markdown]
# ## Framework de Agregación
#
# Framework de agregación:
# - Aquí está la referencia de las diferentes etapas por las que puede pasar un pipeline: https://www.mongodb.com/docs/manual/reference/operator/aggregation-pipeline/.
# - Y aquí los distintos operadores que se permiten dentro de las etapas: https://docs.mongodb.com/manual/reference/operator/aggregation/.
# - Y aquí incluso un libro completo con usos prácticos de ejecutar agregación: https://www.practical-mongodb-aggregations.com/.
#
# A continuación un vídeo interesante:

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('VSX4a3h4SmQ',width=800)

# %% [markdown]
# Aquí tenemos un esquema con un ejemplo básico de agregación.

# %% [markdown]
# ![](https://miro.medium.com/max/1060/1*2lDBxvZ8Cr3JYkoODTa0lQ.png)

# %% [markdown]
# ## Esperamos a que todo se haya cargado para poder continuar.

# %%
import asyncio

await asyncio.gather(
    users_load_task,
    posts_load_task,
    comments_load_task,
    votes_load_task
);
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# /tmp/ipykernel_2382/423113517.py in <cell line: 1>()
#       1 import asyncio
#       2
# ----> 3 await asyncio.gather(
#       4     users_load_task,
#       5     posts_load_task,
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_2382/423113517.py in <cell line: 1>()
#       1 import asyncio
#       2
# ----> 3 await asyncio.gather(
#       4     users_load_task,
#       5     posts_load_task,
#
# /usr/lib/python3.12/asyncio/threads.py in to_thread(func, *args, **kwargs)
#      23     ctx = contextvars.copy_context()
#      24     func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25     return await loop.run_in_executor(None, func_call)
#
# /usr/lib/python3.12/concurrent/futures/thread.py in run(self)
#      57
#      58         try:
# ---> 59             result = self.fn(*self.args, **self.kwargs)
#      60         except BaseException as exc:
#      61             self.future.set_exception(exc)
#
# /tmp/ipykernel_2382/1712218454.py in load_parquet_into_mongo(collection, parquetfile, logqueue)
#      22     except Exception as e:
#      23         logqueue.put_nowait(f"Error inserting DataFrame into MongoDB: {e}.") if logqueue else None
# ---> 24         raise e
#      25     finally:
#      26         del df  # Free memory
#
# /tmp/ipykernel_2382/1712218454.py in load_parquet_into_mongo(collection, parquetfile, logqueue)
#      19     df: DataFrame = load_dataframe(parquetfile, logqueue)
#      20     try:
# ---> 21         return insert_dataframe_into_mongo(collection, df, logqueue)
#      22     except Exception as e:
#      23         logqueue.put_nowait(f"Error inserting DataFrame into MongoDB: {e}.") if logqueue else None
#
# /tmp/ipykernel_2382/1712218454.py in insert_dataframe_into_mongo(collection, df, logqueue)
#       5     collection: Collection, df: DataFrame, logqueue: Queue | None = None
#       6 ) -> InsertManyResult:
# ----> 7     result: InsertManyResult = collection.insert_many(
#       8         df.to_dict("records"), ordered=False, bypass_document_validation=True
#       9     )
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973         blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974         blk.ops = list(gen())
# --> 975         blk.execute(write_concern, session, _Op.INSERT)
#     976         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     977
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/bulk.py in execute(self, write_concern, session, operation)
#     749                 return None
#     750         else:
# --> 751             return self.execute_command(generator, write_concern, session, operation)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/bulk.py in execute_command(self, generator, write_concern, session, operation)
#     602
#     603         client = self.collection.database.client
# --> 604         _ = client._retryable_write(
#     605             self.is_retryable,
#     606             retryable_bulk,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2081         """
#    2082         with self._tmp_session(session) as s:
# -> 2083             return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#    2084
#    2085     def _cleanup_cursor_no_lock(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1966             retryable and self.options.retry_writes and session and not session.in_transaction
#    1967         )
# -> 1968         return self._retry_internal(
#    1969             func=func,
#    1970             session=session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    2012             retryable=retryable,
#    2013             operation_id=operation_id,
# -> 2014         ).run()
#    2015
#    2016     def _retryable_read(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2761             self._check_last_error(check_csot=True)
#    2762             try:
# -> 2763                 return self._read() if self._is_read else self._write()
#    2764             except ServerSelectionTimeoutError:
#    2765                 # The application may think the write was never attempted
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _write(self)
#    2893                         operationId=self._operation_id,
#    2894                     )
# -> 2895                 return self._func(self._session, conn, self._retryable)  # type: ignore
#    2896         except PyMongoError as exc:
#    2897             if not self._retryable:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/bulk.py in retryable_bulk(session, conn, retryable)
#     591             session: Optional[ClientSession], conn: Connection, retryable: bool
#     592         ) -> None:
# --> 593             self._execute_command(
#     594                 generator,
#     595                 write_concern,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/bulk.py in _execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     536                 # Run as many ops as possible in one command.
#     537                 if write_concern.acknowledged:
# --> 538                     result, to_send = self._execute_batch(bwc, cmd, ops, client)
#     539
#     540                     # Retryable writeConcernErrors halt the execution of this run.
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/bulk.py in _execute_batch(self, bwc, cmd, ops, client)
#     460         else:
#     461             request_id, msg, to_send = bwc.batch_command(cmd, ops)
# --> 462             result = self.write_command(bwc, cmd, request_id, msg, to_send, client)  # type: ignore[arg-type]
#     463
#     464         return result, to_send  # type: ignore[return-value]
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/helpers.py in inner(*args, **kwargs)
#      45
#      46         try:
# ---> 47             return func(*args, **kwargs)
#      48         except OperationFailure as exc:
#      49             if no_reauth:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/bulk.py in write_command(self, bwc, cmd, request_id, msg, docs, client)
#     272             bwc._start(cmd, request_id, docs)
#     273         try:
# --> 274             reply = bwc.conn.write_command(request_id, msg, bwc.codec)  # type: ignore[misc]
#     275             duration = datetime.datetime.now() - bwc.start_time
#     276             if _COMMAND_LOGGER.isEnabledFor(logging.DEBUG):
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/pool.py in write_command(self, request_id, msg, codec_options)
#     488
#     489         # Raises NotPrimaryError or OperationFailure.
# --> 490         helpers_shared._check_command_response(result, self.max_wire_version)
#     491         return result
#     492
#
# /usr/local/lib/python3.12/dist-packages/pymongo/helpers_shared.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     282         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     283
# --> 284     raise OperationFailure(errmsg, code, response, max_wire_version)
#     285
#     286
#
# OperationFailure: BSON size limit hit while building Message. Size: 18691865 (0x11D3719); maxSize: 16809984(16MB), full error: {'ok': 0.0, 'errmsg': 'BSON size limit hit while building Message. Size: 18691865 (0x11D3719); maxSize: 16809984(16MB)', 'code': 10334, 'codeName': 'BSONObjectTooLarge'}

# %% [markdown]
# ## Algunos operadores de agregación

# %% [markdown]
# ### `$match`
#
# Este operador permite filtrar los documentos que queremos que pasen a la siguiente fase del pipeline definiendo una serie de condiciones sobre los campos de los documentos.
#
# Vamos a filtrar aquellos documentos que tengan un `Score` igual o superior (`$gte`) a 150.

# %%
from pymongo.command_cursor import CommandCursor

respuestas: CommandCursor[dict[str, Any]] = db.posts.aggregate( [
        {'$match': { 'Score' : {'$gte': 150}}}
])
pp(list(respuestas))
# Out:
# [{'AcceptedAnswerId': None,
#   'AnswerCount': 0,
#   'Body': '<p>Asumiendo que se está haciendo un <code>join</code> de columnas '
#           'sin duplicados, lo cuál es un caso '
#           'común:</p><br/><ul><br/><li><p>Un <strong>inner join</strong> de A '
#           'y B entregará el resultado de la intersección de los conjuntos A y '
#           'B. En otras palabras, la parte <em>interna</em> –intersección– en '
#           'un diagrama de Venn.</p><br/></li><br/><li><p>Un <strong>full outer '
#           'join</strong> entre A y B entregará el resultado de la unión de A y '
#           'B. En otras palabras, la parte <em>externa</em> –unión– en un '
#           'diagrama de Venn '
#           '.</p><br/></li><br/></ul><br/><h1>Ejemplos:</h1><br/><p>Supongamos '
#           'que tenemos dos tablas, con una sola columna cada una y los '
#           'siguientes datos:</p><br/><pre><code>A    B<br/>-    -<br/>1    '
#           '3<br/>2    4<br/>3    5<br/>4    6<br/></code></pre><br/><p>Nota '
#           'que (1,2) solo se encuentran en A, (3,4) son comunes y (5,6) '
#           'solamente se encuentran en B.</p><br/><h1>Inner Join</h1><br/><p>Un '
#           'inner join –utilizando cualquiera de las sintaxis de consulta '
#           'equivalente– te entrega la intersección de ambas tablas, es decir, '
#           'las filas que ambas tablas tienen en '
#           'común.</p><br/><pre><code>select * from a INNER JOIN b on a.a = '
#           'b.b;<br/>select a.*, b.*  from a, b where a.a = b.b;<br/><br/>a | '
#           'b<br/>--+--<br/>3 | 3<br/>4 | 4<br/></code></pre><br/><h1>Left '
#           'outer join</h1><br/><p>Un <code>outer join</code> por la izquierda, '
#           'te dará todas las filas de A, incluyendo las filas comunes entre A '
#           'y B.</p><br/><pre><code>select * from a LEFT OUTER JOIN b on a.a = '
#           'b.b;<br/>select a.*,b.*  from a,b where a.a = b.b(+);<br/><br/>a |  '
#           'b<br/>--+-----<br/>1 | null<br/>2 | null<br/>3 |    3<br/>4 |    '
#           '4<br/></code></pre><br/><h1>Right outer join</h1><br/><p>Un '
#           '<code>outer join</code> por la derecha te dará todas las filas de '
#           'B, incluyendo las filas comunes con A.</p><br/><pre><code>select * '
#           'from a RIGHT OUTER JOIN b on a.a = b.b;<br/>select a.*,b.*  from '
#           'a,b where a.a(+) = b.b;<br/><br/>a    |  b<br/>-----+----<br/>3    '
#           '|  3<br/>4    |  4<br/>null |  5<br/>null |  '
#           '6<br/></code></pre><br/><h1>Full outer join</h1><br/><p>Un '
#           '<code>outer join</code> completo (full) te entregará la unión de A '
#           'y B; es decir, todas las filas de A y todas las filas de B. Si una '
#           'fila en A no tiene una fila correspondiente en B, la porción de B '
#           'es null, y vice versa.</p><br/><pre><code>select * from a FULL '
#           'OUTER JOIN b on a.a = b.b;<br/><br/> a   |  '
#           'b<br/>-----+-----<br/>   1 | null<br/>   2 | null<br/>   3 |    '
#           '3<br/>   4 |    4<br/>null |    5<br/>null |    '
#           '6<br/></code></pre><br/><h1>Diagramas de Venn</h1><br/><p>Esto '
#           'mismo, podemos verlo con diagramas de Venn:</p><br/><p><img '
#           'src="https://upload.wikimedia.org/wikipedia/commons/e/eb/SQL_Joins_es.svg" '
#           'alt="Explicación visual de joins" /><br/>Imagen <a '
#           'href="https://commons.wikimedia.org/wiki/File:SQL_Joins_es.svg" '
#           'rel="nofollow noreferrer">SQL_Joins_es.svg</a> de <a '
#           'href="https://es.stackoverflow.com/users/21/jachguate">jachguate</a>/<a '
#           'href="https://commons.wikimedia.org/wiki/User:Arbeck" rel="nofollow '
#           'noreferrer">Arbeck</a>, compartida bajo licencia <a '
#           'href="https://creativecommons.org/licenses/by/3.0/deed.en" '
#           'rel="nofollow noreferrer">CC BY 3.0</a>.</p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 4,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 4.0',
#   'CreationDate': datetime.datetime(2015, 11, 2, 17, 8, 19, 893000),
#   'FavoriteCount': 0,
#   'Id': 40,
#   'LastActivityDate': datetime.datetime(2023, 7, 12, 6, 22, 59, 157000),
#   'LastEditDate': datetime.datetime(2023, 7, 12, 6, 22, 59, 157000),
#   'LastEditorDisplayName': None,
#   'LastEditorUserId': 21,
#   'OwnerDisplayName': None,
#   'OwnerUserId': 21,
#   'ParentId': 36,
#   'PostTypeId': 2,
#   'Score': 206,
#   'Tags': None,
#   'Title': None,
#   'ViewCount': 0,
#   '_id': ObjectId('69a8de13736d6c0569ed75c9')},
#  {'AcceptedAnswerId': None,
#   'AnswerCount': 13,
#   'Body': '<p>Unas veces los cálculos funcionan correctamente, pero otras '
#           'veces no:</p><br/><br/><pre><code>&gt; 0.1 + 0.1<br/>0.2 // '
#           'correcto<br/>&gt; 0.1 + 0.2<br/>0.30000000000000004 // '
#           '¿qué?<br/>&gt; 10 * 0.67<br/>6.7 // correcto<br/>&gt; 10 * '
#           '0.68<br/>6.800000000000001 // demasiado grande<br/>&gt; 10 * '
#           '0.69<br/>6.8999999999999995 // demasiado '
#           'pequeño<br/></code></pre><br/><br/><p>(Estos ejemplos están '
#           'escritos en JavaScript, pero el mismo problema existe en muchos '
#           'lenguajes de programación)</p><br/><br/><p>Estos cálculos son '
#           'bastante fáciles: creo que todos podemos hacerlos en un momento. '
#           '¿Por qué mis programas no pueden hacer cálculos aritméticos '
#           'correctamente, y qué puedo hacer si necesito resultados más '
#           'precisos?</p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 10,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2015, 12, 2, 6, 15, 7, 957000),
#   'FavoriteCount': 0,
#   'Id': 197,
#   'LastActivityDate': datetime.datetime(2023, 2, 6, 22, 11, 20, 880000),
#   'LastEditDate': datetime.datetime(2015, 12, 5, 20, 22, 47, 177000),
#   'LastEditorDisplayName': None,
#   'LastEditorUserId': 20,
#   'OwnerDisplayName': None,
#   'OwnerUserId': 416,
#   'ParentId': None,
#   'PostTypeId': 1,
#   'Score': 176,
#   'Tags': '<matemáticas><coma-flotante><lenguaje-agnóstico>',
#   'Title': '¿Por qué mis programas no pueden hacer cálculos aritméticos '
#            'correctamente?',
#   'ViewCount': 9091,
#   '_id': ObjectId('69a8de13736d6c0569ed7649')},
#  {'AcceptedAnswerId': None,
#   'AnswerCount': 0,
#   'Body': '<p>El problema viene de la limitación que los ordenadores tienen '
#           'para representar números de <a '
#           'href="https://es.wikipedia.org/wiki/Coma_flotante">coma '
#           'flotante</a> usando un número finito de bits.</p><br/><br/><p><a '
#           'href="http://www.exploringbinary.com/why-0-point-1-does-not-exist-in-floating-point">En '
#           'este artículo en inglés</a> hay una muy buena explicación. '
#           'Básicamente, para representar el número 0.1 en coma flotante '
#           'necesitamos un número infinito de dígitos '
#           'binarios:</p><br/><br/><p><a '
#           'href="https://i.stack.imgur.com/e5fNJ.png"><img '
#           'src="https://i.stack.imgur.com/e5fNJ.png" alt="Dividiendo 1 entre '
#           '10 en binario"></a></p><br/><br/><p><em>Dividiendo 1 entre 10 en '
#           'binario</em></p><br/><br/><p><a '
#           'href="https://i.stack.imgur.com/rvPPD.png"><img '
#           'src="https://i.stack.imgur.com/rvPPD.png" alt="1/10 en binario '
#           '(primeros 1369 dígitos)"></a></p><br/><br/><p><em>1/10 en binario '
#           '(primeros 1369 dígitos)</em></p><br/><br/><p>Si suponemos que '
#           'nuestro ordenador es capaz de almacenar hasta 53 dígitos, una vez '
#           'truncado nuestro 0.1 queda representado en binario '
#           'como:</p><br/><br/><p>0.0001100110011001100110011001100110011001100110011001101</p><br/><br/><p>...que '
#           'en decimal '
#           'es</p><br/><br/><p>0.1000000000000000055511151231257827021181583404541015625</p><br/><br/><p>Para '
#           'este problema hay básicamente dos '
#           'soluciones:</p><br/><br/><ul><br/><li>Usar un tipo decimal exacto '
#           'en vez de coma flotante. Hay lenguajes que proporcionan estos tipos '
#           'nativamente (por ejemplo, .NET tiene el tipo <a '
#           'href="https://msdn.microsoft.com/en-us/library/364x0z75.aspx">decimal</a>); '
#           'para los que no, suele haber librerías especializadas para ello '
#           '(por ejemplo <a '
#           'href="https://github.com/MikeMcl/decimal.js">decimal.js</a> para '
#           'Javascript).</li><br/><li>Si el número de decimales se conoce por '
#           'adelantado (por ejemplo al tratar con valores monetarios), los '
#           'valores se pueden representar como enteros. Así, 123.45€ se '
#           'representaría como 12345 céntimos. El punto decimal se añadiría al '
#           'final, a la hora de mostrar el valor al '
#           'usuario.</li><br/></ul><br/><br/><p>Un buen sitio con más '
#           'información sobre este tema: <a '
#           'href="http://puntoflotante.org">http://puntoflotante.org</a></p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 3,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2015, 12, 2, 7, 43, 50, 70000),
#   'FavoriteCount': 0,
#   'Id': 204,
#   'LastActivityDate': datetime.datetime(2015, 12, 2, 9, 56, 34, 630000),
#   'LastEditDate': datetime.datetime(2015, 12, 2, 9, 56, 34, 630000),
#   'LastEditorDisplayName': None,
#   'LastEditorUserId': 23,
#   'OwnerDisplayName': None,
#   'OwnerUserId': 23,
#   'ParentId': 197,
#   'PostTypeId': 2,
#   'Score': 195,
#   'Tags': None,
#   'Title': None,
#   'ViewCount': 0,
#   '_id': ObjectId('69a8de13736d6c0569ed764d')},
#  {'AcceptedAnswerId': 18233,
#   'AnswerCount': 6,
#   'Body': '<p>Las sentencias dinámicas son sentencias SQL que se crean como '
#           'cadenas de texto (strings) y en las que se insertan/concatenan '
#           'valores obtenidos de alguna fuente (normalmente proveniente del '
#           'usuario), lo que puede hacer que sean vulnerables a inyección SQL '
#           'si no se sanean las entradas, como por '
#           'ejemplo:</p><br/><br/><pre><code>$id_usuario = '
#           '$_POST["id"];<br/><br/>mysql_query("SELECT * FROM usuarios WHERE id '
#           '= $id_usuario");<br/></code></pre><br/><br/><p>Eso es un ejemplo de '
#           'una vulnerabilidad grave en la seguridad de una aplicación (web o '
#           'no) porque si el usuario introdujese un valor como <code>1; DROP '
#           'TABLE usuarios;--</code> nos encontraríamos con que la sentencia '
#           'ejecutada sería:</p><br/><br/><pre><code>SELECT * FROM usuarios '
#           'WHERE id = 1; DROP TABLE '
#           'usuarios;--<br/></code></pre><br/><br/><p>Y se eliminaría la tabla '
#           'Usuarios con todos los datos contenidos en ella. '
#           '</p><br/><br/><p><strong>¿Cómo puedo evitar que la inyección SQL '
#           'ocurra en PHP?</strong></p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 1,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'FavoriteCount': 0,
#   'Id': 18232,
#   'LastActivityDate': datetime.datetime(2023, 5, 16, 22, 14, 53, 633000),
#   'LastEditDate': datetime.datetime(2017, 3, 4, 3, 8, 9, 33000),
#   'LastEditorDisplayName': None,
#   'LastEditorUserId': 29967,
#   'OwnerDisplayName': None,
#   'OwnerUserId': 250,
#   'ParentId': None,
#   'PostTypeId': 1,
#   'Score': 232,
#   'Tags': '<php><mysql><sql><seguridad><inyección-sql>',
#   'Title': '¿Cómo evitar la inyección SQL en PHP?',
#   'ViewCount': 77113,
#   '_id': ObjectId('69a8de13736d6c0569edae17')},
#  {'AcceptedAnswerId': None,
#   'AnswerCount': 0,
#   'Body': '<blockquote><br/><h1>NO USES SENTENCIAS DINÁMICAS NI FUNCIONES '
#           '<code>mysql_*</code></h1><br/><p>Las funciones <code>mysql_*</code> '
#           '(<code>mysql_connect</code>, <code>mysql_query</code>, etc.) son '
#           'inseguras por naturaleza y su uso no sólo no está recomendado, sino '
#           'que <strong>se consideran obsoletas y se han eliminado '
#           'completamente a partir de PHP7</strong>.</p><br/><p>Incluso los '
#           'métodos nativos que existen en PHP para sanear las entradas de '
#           'usuario (como <code>mysql_real_escape_string</code>) pueden '
#           'presentar (raros) problemas y fallar en algunos casos como cuando '
#           'se usan codificación de caracteres diferentes a UTF-8 junto a '
#           'versiones no actualizadas de MySQL (en las <a '
#           'href="http://php.net/manual/es/mysqli.real-escape-string.php" '
#           'rel="noreferrer">páginas de PHP para estas funciones</a> se avisa '
#           'de este riesgo).</p><br/></blockquote><br/><hr /><br/><h1>Usa '
#           'sentencias preparadas y consultas parametrizadas</h1><br/><p>Aunque '
#           'se podrían sanear las entradas usando métodos como '
#           '<code>mysqli_real_escape_string</code>, es más recomendable la '
#           'utilización de sentencias preparadas o parametrizadas. Las '
#           'sentencias preparadas te permitirán ejecutar la misma sentencia con '
#           'gran eficiencia.</p><br/><p>En PHP, tienes dos alternativas '
#           'principales: <a href="https://www.php.net/manual/es/book.pdo.php" '
#           'rel="noreferrer">PDO</a> y  <a '
#           'href="https://www.php.net/manual/es/book.mysqli.php" '
#           'rel="noreferrer">MySQLi</a>. Hay varias diferencias entre ambas, '
#           'pero la principal es que PDO se puede usar con diferentes tipos de '
#           'base de datos (<a '
#           'href="https://www.php.net/manual/es/intro.pdo.php#intro.pdo" '
#           'rel="noreferrer">dependiendo del driver utilizado</a>) mientras que '
#           'MySQLi es exclusivamente para bases de datos MySQL. Es por ello que '
#           'recomendaría PDO sobre MySQLi.</p><br/><h2>PDO</h2><br/><p>Los <a '
#           'href="https://www.php.net/manual/es/pdo.prepare.php#refsect1-pdo.prepare-description" '
#           'rel="noreferrer">marcadores de posición</a> (que indican dónde se '
#           'sustituirá una cadena por su valor), se pueden definir bien usando '
#           'un signo de interrogación (<code>?</code>) o bien usando un nombre '
#           '(generalmente empezando con <code>:</code>). Personalmente prefiero '
#           'usar un nombre, porque eso me ayuda a encontrar posibles errores en '
#           'caso de tener múltiples variables.</p><br/><p>Aquí dejo un ejemplo '
#           'para el código de la pregunta:</p><br/><pre><code>// la variable '
#           '$pdo contendrá el objeto con la conexión PDO<br/>$pdo = new '
#           "PDO('mysql:host=mihost;dbname=basedatos', &quot;usuario&quot;, "
#           '&quot;contraseña&quot;);<br/><br/>$id_usuario = '
#           '$_POST[&quot;id&quot;];<br/><br/>$sentencia = '
#           '$pdo-&gt;prepare(&quot;SELECT * FROM usuarios WHERE id = '
#           ':idusuario&quot;);<br/>$sentencia=$pdo-&gt;setAttribute(PDO::ATTR_EMULATE_PREPARES, '
#           'false);<br/>$sentencia-&gt;bindParam(&quot;:idusuario&quot;, '
#           '$id_usuario, '
#           'PDO::PARAM_INT);<br/>$sentencia-&gt;execute();<br/></code></pre><br/><p>En '
#           'este caso, <code>:idusuario</code> se sustituirá por el valor de '
#           '<code>$_POST[&quot;id&quot;]</code> de forma segura, y cuando hace '
#           'el <em>bind</em> se indica que la variable es de tipo entero '
#           '(<code>PDO::PARAM_INT</code>).</p><br/><blockquote><br/><p>Nota: si '
#           'la variable es una cadena de texto se usará '
#           '<code>PDO::PARAM_STR</code> y no hace falta poner las comillas en '
#           'la sentencia SQL; al especificarle a PHP que es una cadena, las '
#           'añadirá automáticamente al hacer el '
#           '<em>bind</em>.</p><br/></blockquote><br/><p>En caso de que existan '
#           'varias variables a incluir en la sentencia SQL, se debe incluir un '
#           'único parámetro para cada uno de los valores que se usan en la '
#           'sentencia. Del ejemplo anterior, el <code>:idusuario</code> puede '
#           'usarse una única vez en la consulta que se esta preparando. Si '
#           'fuera necesario usar el &quot;idusuario&quot; de nuevo en la '
#           'consulta, se debe crear otro parámetro con el valor de '
#           '<code>$id_usuario</code>.</p><br/><pre><code>$pdo = new '
#           "PDO('mysql:host=mihost;dbname=basedatos', &quot;usuario&quot;, "
#           '&quot;contraseña&quot;);<br/><br/>$id_usuario = '
#           '$_POST[&quot;id&quot;];<br/>    <br/>$sentencia = '
#           '$pdo-&gt;prepare(&quot;UPDATE usuarios SET id = :idusuario WHERE id '
#           '= '
#           ':idusuario1&quot;);<br/>$sentencia=$pdo-&gt;setAttribute(PDO::ATTR_EMULATE_PREPARES, '
#           'false);<br/>$sentencia-&gt;bindParam(&quot;:idusuario&quot;, '
#           '$id_usuario, '
#           'PDO::PARAM_INT);<br/>$sentencia-&gt;bindParam(&quot;:idusuario1&quot;, '
#           '$id_usuario, '
#           'PDO::PARAM_INT);<br/>$sentencia-&gt;execute();<br/></code></pre><br/><h2>MySQLi</h2><br/><p>Este '
#           'método tiene <a '
#           'href="https://www.php.net/manual/es/mysqli.quickstart.dual-interface.php" '
#           'rel="noreferrer">dos interfaces</a>: una procedural y otra '
#           'orientada a objetos. La interfaz procedural es muy parecida a '
#           '<code>mysql_*</code>, y por ello la gente que migra desde '
#           '<code>mysql_*</code> puede sentirse atraída por la facilidad que '
#           '<code>mysqli_*</code> ofrece. Aunque, de nuevo personalmente, '
#           'optaría por la versión POO.</p><br/><blockquote><br/><p>Nota: '
#           'aunque las funciones <code>mysqli_*</code> suelen ser parecidas a '
#           'las <code>mysql_*</code>, en algunos casos pueden tener diferentes '
#           'parámetros de entrada o diferentes salidas, lo que puede llevar a '
#           'algo de confusión al principio.</p><br/></blockquote><br/><p>El '
#           'ejemplo de la pregunta quedaría así con MySQLi en su interfaz '
#           'orientada a objetos:</p><br/><pre><code>// en $mysqli tendremos la '
#           'conexión MySQLi<br/>$mysqli = new mysqli(&quot;mihost&quot;, '
#           '&quot;usuario&quot;, &quot;contraseña&quot;, '
#           '&quot;basedatos&quot;);<br/><br/>$id_usuario = '
#           '$_POST[&quot;id&quot;];<br/><br/>$sentencia = '
#           '$mysqli-&gt;prepare(&quot;SELECT * FROM usuarios WHERE id = '
#           '?&quot;);<br/>$sentencia-&gt;bind_param(&quot;i&quot;, $id_usuario '
#           ');<br/>$sentencia-&gt;execute();<br/></code></pre><br/><p>Como se '
#           'puede ver, es bastante parecido a PDO (cambia un poco cómo se '
#           'especifica el <a '
#           'href="https://www.php.net/manual/es/mysqli-stmt.bind-param.php#refsect1-mysqli-stmt.bind-param-parameters" '
#           'rel="noreferrer">tipo de valor</a>, <code>i</code> para enteros y '
#           '<code>s</code> para cadenas, pero la idea es '
#           'similar).</p><br/><p>En la versión procedural de MySQLi, el código '
#           'equivalente sería:</p><br/><pre><code>// en $conn tendríamos la '
#           'conexión a la base de datos con MySQLi<br/>$conn = '
#           'mysqli_connect(&quot;mihost&quot;, &quot;usuario&quot;, '
#           '&quot;contraseña&quot;, '
#           '&quot;basedatos&quot;);<br/><br/>$id_usuario = '
#           '$_POST[&quot;id&quot;];<br/><br/>$sentencia = '
#           'mysqli_prepare(&quot;SELECT * FROM usuarios WHERE id = '
#           '?&quot;);<br/>mysqli_stmt_bind_param($sentencia, &quot;i&quot;, '
#           '$id_usuario);<br/>mysqli_stmt_execute($sentencia);<br/></code></pre><br/><hr '
#           '/><br/><p>Fuente y bibliografía para más información en '
#           'español:</p><br/><ul><br/><li><a '
#           'href="http://php.net/manual/es/mysqli.quickstart.prepared-statements.php" '
#           'rel="noreferrer">Página oficial de PHP sobre sentencias '
#           'preparadas</a></li><br/><li><a '
#           'href="http://php.net/manual/es/pdo.prepared-statements.php" '
#           'rel="noreferrer">Página oficial de PHP sobre sentencias preparadas '
#           'en PDO</a></li><br/><li><a '
#           'href="https://es.wikipedia.org/wiki/Inyecci%C3%B3n_SQL" '
#           'rel="noreferrer">Artículo en Wikipedia sobre la <strong>inyección '
#           'SQL y cómo evitarla en PHP y otros '
#           'lenguajes</strong></a></li><br/></ul><br/>',
#   'ClosedDate': None,
#   'CommentCount': 4,
#   'CommunityOwnedDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'ContentLicense': 'CC BY-SA 4.0',
#   'CreationDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'FavoriteCount': 0,
#   'Id': 18233,
#   'LastActivityDate': datetime.datetime(2022, 8, 13, 1, 55, 39, 97000),
#   'LastEditDate': datetime.datetime(2022, 8, 13, 1, 55, 39, 97000),
#   'LastEditorDisplayName': None,
#   'LastEditorUserId': 195444,
#   'OwnerDisplayName': None,
#   'OwnerUserId': 250,
#   'ParentId': 18232,
#   'PostTypeId': 2,
#   'Score': 219,
#   'Tags': None,
#   'Title': None,
#   'ViewCount': 0,
#   '_id': ObjectId('69a8de13736d6c0569edae18')},
#  {'AcceptedAnswerId': None,
#   'AnswerCount': 0,
#   'Body': '<p>Hola, mi nombre es Álvaro Montoro, soy un Ingeniero Informático '
#           'español aunque actualmente vivo y trabajo en los Estados Unidos, en '
#           'la capital del estado de Texas: Austin.</p><br/><br/><p>Tengo '
#           'experiencia en diferentes ámbitos de programación: back-end, '
#           'front-end, bases de datos, seguridad... y en bastantes lenguajes: '
#           'PHP, Java, C#, Visual Basic, C/C++, JavaScript... lo que hace que '
#           'me mueva por un grupo variado de etiquetas (aunque prefiera las de '
#           'programación web) y se refleja en la medalla <a '
#           'href="https://es.stackoverflow.com/help/badges/15/generalist"><code>generalista</code></a> '
#           '(de momento el único que la '
#           'tiene).</p><br/><br/><p>Pros:</p><br/><br/><ul><br/><li>Paso '
#           'bastante tiempo en SOes (he visitado el sitio 594 días, 384 '
#           'consecutivos ).</li><br/><li>He estado en el sitio desde Area 51 y '
#           'cuento con experiencia en otros sitios de SE (no como '
#           'moderador).</li><br/><li>Me gusta guiarme por las reglas del Centro '
#           'de '
#           'Ayuda.</li><br/></ul><br/><br/><p>Contras:</p><br/><br/><ul><br/><li>Aunque '
#           'activo en chat y meta, debería ser más activo.</li><br/><li>Cuento '
#           'con experiencia en otros sitios de SE, lo que hace que a veces use '
#           'la misma vara de medir que usaría en otros sitios.</li><br/><li>Me '
#           'gusta guiarme por las reglas del Centro de Ayuda... y a veces hay '
#           'que ser más paciente y flexible.</li><br/></ul><br/>',
#   'ClosedDate': None,
#   'CommentCount': 12,
#   'CommunityOwnedDate': datetime.datetime(2017, 7, 18, 20, 7, 26, 473000),
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2017, 7, 18, 20, 7, 26, 473000),
#   'FavoriteCount': 0,
#   'Id': 87842,
#   'LastActivityDate': datetime.datetime(2017, 7, 20, 15, 58, 45, 867000),
#   'LastEditDate': datetime.datetime(2017, 7, 20, 15, 58, 45, 867000),
#   'LastEditorDisplayName': None,
#   'LastEditorUserId': 250,
#   'OwnerDisplayName': None,
#   'OwnerUserId': 250,
#   'ParentId': None,
#   'PostTypeId': 6,
#   'Score': 173,
#   'Tags': None,
#   'Title': None,
#   'ViewCount': 0,
#   '_id': ObjectId('69a8de13736d6c0569ee76ce')}]

# %% [markdown]
# ### `$project`
#
# El operador `$project`permite filtar qué campos de los documentos queremos usar en la siguientes fases de agregación.
#
# Generalmente este operador suele combinarse con otros como `$find`, `$match` o `$lookup` en fases más avanzadas de la agregación.
#
# En el siguiente ejemplo, realizamos un filtrado en donde solo nos quedamos con el campo `Id` de los posts.

# %%
respuestas: CommandCursor[dict[str, Any]] = db['posts'].aggregate( [
    {'$project' : { 'Id' : True }},
    {'$limit': 20} ])
pp(list(respuestas))
# Out:
# [{'Id': 1, '_id': ObjectId('69a8de13736d6c0569ed75a5')},
#  {'Id': 2, '_id': ObjectId('69a8de13736d6c0569ed75a6')},
#  {'Id': 3, '_id': ObjectId('69a8de13736d6c0569ed75a7')},
#  {'Id': 4, '_id': ObjectId('69a8de13736d6c0569ed75a8')},
#  {'Id': 5, '_id': ObjectId('69a8de13736d6c0569ed75a9')},
#  {'Id': 6, '_id': ObjectId('69a8de13736d6c0569ed75aa')},
#  {'Id': 7, '_id': ObjectId('69a8de13736d6c0569ed75ab')},
#  {'Id': 8, '_id': ObjectId('69a8de13736d6c0569ed75ac')},
#  {'Id': 9, '_id': ObjectId('69a8de13736d6c0569ed75ad')},
#  {'Id': 10, '_id': ObjectId('69a8de13736d6c0569ed75ae')},
#  {'Id': 11, '_id': ObjectId('69a8de13736d6c0569ed75af')},
#  {'Id': 12, '_id': ObjectId('69a8de13736d6c0569ed75b0')},
#  {'Id': 14, '_id': ObjectId('69a8de13736d6c0569ed75b1')},
#  {'Id': 15, '_id': ObjectId('69a8de13736d6c0569ed75b2')},
#  {'Id': 16, '_id': ObjectId('69a8de13736d6c0569ed75b3')},
#  {'Id': 17, '_id': ObjectId('69a8de13736d6c0569ed75b4')},
#  {'Id': 18, '_id': ObjectId('69a8de13736d6c0569ed75b5')},
#  {'Id': 19, '_id': ObjectId('69a8de13736d6c0569ed75b6')},
#  {'Id': 20, '_id': ObjectId('69a8de13736d6c0569ed75b7')},
#  {'Id': 21, '_id': ObjectId('69a8de13736d6c0569ed75b8')}]

# %% [markdown]
# ### `$group`
#
# La función `$group` se usa dentro del *pipeline* de agregación de documentos seguido por Mongo (`.aggregate`). Esta función admite dos parámetros diferentes:
# * `_id`: El identificador por el que queremos agrupar los documentos.
# * `campo`: Expresión mediante la cual queremos aggregar los documentos (esto es opcional).

# %% [markdown]
# Vamos a contar el número de posts por usuario, usando el campo `OwnerUserId`, en la colección `posts`.

# %%
from pymongo.command_cursor import CommandCursor

users_count_scores: CommandCursor[dict[str, Any]] = db.posts.aggregate(
    [
        {
            "$group":{
                "_id": "$OwnerUserId",
                "count": {"$sum": 1}
            }
        },
        {
            "$limit": 10
        }
    ]
)
pp(list(users_count_scores))
# Out:
# [{'_id': 27611, 'count': 6},
#  {'_id': 295126, 'count': 27},
#  {'_id': 304739, 'count': 2},
#  {'_id': 306367, 'count': 1},
#  {'_id': 133811, 'count': 2},
#  {'_id': 103742, 'count': 1},
#  {'_id': 133994, 'count': 1},
#  {'_id': 300835, 'count': 29},
#  {'_id': 77, 'count': 2},
#  {'_id': 215058, 'count': 1}]

# %% [markdown]
# Ahora vamos calcular el `score` medio por usuario, usando de nuevo `OnwerUserId`, en base a todos sus posts.

# %%
users_avg_scores: CommandCursor[dict[str, Any]] = db.posts.aggregate(
    [{
        "$group":{
            "_id": "$OwnerUserId",
            "avg_score": {"$avg":'$Score'}
        }
        },
        { "$limit": 10 }
    ]
)
pp(list(users_avg_scores))
# Out:
# [{'_id': 65886, 'avg_score': 0.0},
#  {'_id': 115827, 'avg_score': 0.0},
#  {'_id': 190743, 'avg_score': 4.0},
#  {'_id': 2000, 'avg_score': 5.0},
#  {'_id': 48873, 'avg_score': 1.0},
#  {'_id': 321862, 'avg_score': 0.0},
#  {'_id': 115299, 'avg_score': 0.5},
#  {'_id': 50238, 'avg_score': 0.0},
#  {'_id': 155910, 'avg_score': 0.0},
#  {'_id': 42139, 'avg_score': 0.0}]

# %% [markdown]
# ### `$lookup`

# %% [markdown]
# El operador `$lookup` permite realizar búsquedas en otras colecciones. Podrían interpretarse como un *join* en el modelo relacional. Esta función admite cuatro parámetros diferentes:
#
# *   `from`: especifica la colección en la misma base de datos con la que hacer la búsqueda (o el *join*).
# *   `localField`: Especifica el campo de los documentos de entrada a usar para realizar una comparación de igualdad con el campo `foreignField` de los documentos de la colección `from`.
# *   `foreignField`: Especifica el campo de los documentos de la colección `from` a usar en la comparación de igualdad con el `localField`.
# *   `as`: Especifica el nombre del nuevo campo array que se añadirá a los documentos de entrada. Este nuevo campo contiene los documentos coincidentes de la colección `from`.
#
# En el ejemplo siguiente, en primer lugar seleccionamos los posts con un `Score` igual o mayor a 150 con `$match` para a continuación seleccionar los usuarios que han publicado dichos posts incluyéndolo en un nuevo campo llamado `owner`.

# %%
respuestas: CommandCursor[dict[str, Any]] = db.posts.aggregate( [
    {'$match': { 'Score' : {'$gte': 150}}},
    {'$lookup': {
        'from': "users",
        'localField': "OwnerUserId",
        'foreignField': "Id",
        'as': "owner"}
    }
])
pp(list(respuestas))
# Out:
# [{'AcceptedAnswerId': None,
#   'AnswerCount': 0,
#   'Body': '<p>Asumiendo que se está haciendo un <code>join</code> de columnas '
#           'sin duplicados, lo cuál es un caso '
#           'común:</p><br/><ul><br/><li><p>Un <strong>inner join</strong> de A '
#           'y B entregará el resultado de la intersección de los conjuntos A y '
#           'B. En otras palabras, la parte <em>interna</em> –intersección– en '
#           'un diagrama de Venn.</p><br/></li><br/><li><p>Un <strong>full outer '
#           'join</strong> entre A y B entregará el resultado de la unión de A y '
#           'B. En otras palabras, la parte <em>externa</em> –unión– en un '
#           'diagrama de Venn '
#           '.</p><br/></li><br/></ul><br/><h1>Ejemplos:</h1><br/><p>Supongamos '
#           'que tenemos dos tablas, con una sola columna cada una y los '
#           'siguientes datos:</p><br/><pre><code>A    B<br/>-    -<br/>1    '
#           '3<br/>2    4<br/>3    5<br/>4    6<br/></code></pre><br/><p>Nota '
#           'que (1,2) solo se encuentran en A, (3,4) son comunes y (5,6) '
#           'solamente se encuentran en B.</p><br/><h1>Inner Join</h1><br/><p>Un '
#           'inner join –utilizando cualquiera de las sintaxis de consulta '
#           'equivalente– te entrega la intersección de ambas tablas, es decir, '
#           'las filas que ambas tablas tienen en '
#           'común.</p><br/><pre><code>select * from a INNER JOIN b on a.a = '
#           'b.b;<br/>select a.*, b.*  from a, b where a.a = b.b;<br/><br/>a | '
#           'b<br/>--+--<br/>3 | 3<br/>4 | 4<br/></code></pre><br/><h1>Left '
#           'outer join</h1><br/><p>Un <code>outer join</code> por la izquierda, '
#           'te dará todas las filas de A, incluyendo las filas comunes entre A '
#           'y B.</p><br/><pre><code>select * from a LEFT OUTER JOIN b on a.a = '
#           'b.b;<br/>select a.*,b.*  from a,b where a.a = b.b(+);<br/><br/>a |  '
#           'b<br/>--+-----<br/>1 | null<br/>2 | null<br/>3 |    3<br/>4 |    '
#           '4<br/></code></pre><br/><h1>Right outer join</h1><br/><p>Un '
#           '<code>outer join</code> por la derecha te dará todas las filas de '
#           'B, incluyendo las filas comunes con A.</p><br/><pre><code>select * '
#           'from a RIGHT OUTER JOIN b on a.a = b.b;<br/>select a.*,b.*  from '
#           'a,b where a.a(+) = b.b;<br/><br/>a    |  b<br/>-----+----<br/>3    '
#           '|  3<br/>4    |  4<br/>null |  5<br/>null |  '
#           '6<br/></code></pre><br/><h1>Full outer join</h1><br/><p>Un '
#           '<code>outer join</code> completo (full) te entregará la unión de A '
#           'y B; es decir, todas las filas de A y todas las filas de B. Si una '
#           'fila en A no tiene una fila correspondiente en B, la porción de B '
#           'es null, y vice versa.</p><br/><pre><code>select * from a FULL '
#           'OUTER JOIN b on a.a = b.b;<br/><br/> a   |  '
#           'b<br/>-----+-----<br/>   1 | null<br/>   2 | null<br/>   3 |    '
#           '3<br/>   4 |    4<br/>null |    5<br/>null |    '
#           '6<br/></code></pre><br/><h1>Diagramas de Venn</h1><br/><p>Esto '
#           'mismo, podemos verlo con diagramas de Venn:</p><br/><p><img '
#           'src="https://upload.wikimedia.org/wikipedia/commons/e/eb/SQL_Joins_es.svg" '
#           'alt="Explicación visual de joins" /><br/>Imagen <a '
#           'href="https://commons.wikimedia.org/wiki/File:SQL_Joins_es.svg" '
#           'rel="nofollow noreferrer">SQL_Joins_es.svg</a> de <a '
#           'href="https://es.stackoverflow.com/users/21/jachguate">jachguate</a>/<a '
#           'href="https://commons.wikimedia.org/wiki/User:Arbeck" rel="nofollow '
#           'noreferrer">Arbeck</a>, compartida bajo licencia <a '
#           'href="https://creativecommons.org/licenses/by/3.0/deed.en" '
#           'rel="nofollow noreferrer">CC BY 3.0</a>.</p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 4,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 4.0',
#   'CreationDate': datetime.datetime(2015, 11, 2, 17, 8, 19, 893000),
#   'FavoriteCount': 0,
#   'Id': 40,
#   'LastActivityDate': datetime.datetime(2023, 7, 12, 6, 22, 59, 157000),
#   'LastEditDate': datetime.datetime(2023, 7, 12, 6, 22, 59, 157000),
#   'LastEditorDisplayName': None,
#   'LastEditorUserId': 21,
#   'OwnerDisplayName': None,
#   'OwnerUserId': 21,
#   'ParentId': 36,
#   'PostTypeId': 2,
#   'Score': 206,
#   'Tags': None,
#   'Title': None,
#   'ViewCount': 0,
#   '_id': ObjectId('69a8de13736d6c0569ed75c9'),
#   'owner': [{'AboutMe': '<p>Entrepreneur, software developer and '
#                         '<strong>traveler</strong>. :)</p><br/>',
#              'AccountId': 93263,
#              'CreationDate': datetime.datetime(2015, 10, 29, 13, 46, 46, 317000),
#              'DisplayName': 'jachguate',
#              'DownVotes': 281,
#              'Id': 21,
#              'LastAccessDate': datetime.datetime(2023, 11, 28, 16, 55, 27, 633000),
#              'Location': 'Guatemala',
#              'Reputation': 30128,
#              'UpVotes': 2727,
#              'Views': 2892,
#              'WebsiteUrl': 'http://jachguate.wordpress.com',
#              '_id': ObjectId('69a8ddc1736d6c0569d20ab2')}]},
#  {'AcceptedAnswerId': None,
#   'AnswerCount': 13,
#   'Body': '<p>Unas veces los cálculos funcionan correctamente, pero otras '
#           'veces no:</p><br/><br/><pre><code>&gt; 0.1 + 0.1<br/>0.2 // '
#           'correcto<br/>&gt; 0.1 + 0.2<br/>0.30000000000000004 // '
#           '¿qué?<br/>&gt; 10 * 0.67<br/>6.7 // correcto<br/>&gt; 10 * '
#           '0.68<br/>6.800000000000001 // demasiado grande<br/>&gt; 10 * '
#           '0.69<br/>6.8999999999999995 // demasiado '
#           'pequeño<br/></code></pre><br/><br/><p>(Estos ejemplos están '
#           'escritos en JavaScript, pero el mismo problema existe en muchos '
#           'lenguajes de programación)</p><br/><br/><p>Estos cálculos son '
#           'bastante fáciles: creo que todos podemos hacerlos en un momento. '
#           '¿Por qué mis programas no pueden hacer cálculos aritméticos '
#           'correctamente, y qué puedo hacer si necesito resultados más '
#           'precisos?</p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 10,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2015, 12, 2, 6, 15, 7, 957000),
#   'FavoriteCount': 0,
#   'Id': 197,
#   'LastActivityDate': datetime.datetime(2023, 2, 6, 22, 11, 20, 880000),
#   'LastEditDate': datetime.datetime(2015, 12, 5, 20, 22, 47, 177000),
#   'LastEditorDisplayName': None,
#   'LastEditorUserId': 20,
#   'OwnerDisplayName': None,
#   'OwnerUserId': 416,
#   'ParentId': None,
#   'PostTypeId': 1,
#   'Score': 176,
#   'Tags': '<matemáticas><coma-flotante><lenguaje-agnóstico>',
#   'Title': '¿Por qué mis programas no pueden hacer cálculos aritméticos '
#            'correctamente?',
#   'ViewCount': 9091,
#   '_id': ObjectId('69a8de13736d6c0569ed7649'),
#   'owner': [{'AboutMe': '<p><strong>Projects</strong></p><br/><br/><ul><br/><li><a '
#                         'href="https://www.dong-chinese.com/" rel="nofollow '
#                         'noreferrer">Dong Chinese</a></li><br/><li><a '
#                         'href="https://github.com/peterolson/BigInteger.js" '
#                         'rel="nofollow '
#                         'noreferrer">BigInteger.js</a></li><br/><li><a '
#                         'href="http://www.virtualtrebuchet.com/" rel="nofollow '
#                         'noreferrer">Virtual Trebuchet</a></li><br/><li><a '
#                         'href="https://play.google.com/store/apps/details?id=com.peterolson.magnetpuzzle" '
#                         'rel="nofollow noreferrer">The Magnet '
#                         'Puzzle</a></li><br/></ul><br/><br/><h2><img '
#                         'src="https://projecteuler.net/profile/peter.olson.png" '
#                         'alt="enter image description '
#                         'here"></h2><br/><br/><p>You can contact me at '
#                         '</p><br/><br/><pre><code>peter.e.c.olson+stackexchange@gmail.com<br/></code></pre><br/>',
#              'AccountId': 262054,
#              'CreationDate': datetime.datetime(2015, 12, 2, 0, 35, 33, 333000),
#              'DisplayName': 'Peter Olson',
#              'DownVotes': 0,
#              'Id': 416,
#              'LastAccessDate': datetime.datetime(2022, 12, 5, 14, 52, 5, 970000),
#              'Location': 'Qingdao, China',
#              'Reputation': 4795,
#              'UpVotes': 7,
#              'Views': 178,
#              'WebsiteUrl': 'https://www.dong-chinese.com',
#              '_id': ObjectId('69a8ddc1736d6c0569d20c1c')}]},
#  {'AcceptedAnswerId': None,
#   'AnswerCount': 0,
#   'Body': '<p>El problema viene de la limitación que los ordenadores tienen '
#           'para representar números de <a '
#           'href="https://es.wikipedia.org/wiki/Coma_flotante">coma '
#           'flotante</a> usando un número finito de bits.</p><br/><br/><p><a '
#           'href="http://www.exploringbinary.com/why-0-point-1-does-not-exist-in-floating-point">En '
#           'este artículo en inglés</a> hay una muy buena explicación. '
#           'Básicamente, para representar el número 0.1 en coma flotante '
#           'necesitamos un número infinito de dígitos '
#           'binarios:</p><br/><br/><p><a '
#           'href="https://i.stack.imgur.com/e5fNJ.png"><img '
#           'src="https://i.stack.imgur.com/e5fNJ.png" alt="Dividiendo 1 entre '
#           '10 en binario"></a></p><br/><br/><p><em>Dividiendo 1 entre 10 en '
#           'binario</em></p><br/><br/><p><a '
#           'href="https://i.stack.imgur.com/rvPPD.png"><img '
#           'src="https://i.stack.imgur.com/rvPPD.png" alt="1/10 en binario '
#           '(primeros 1369 dígitos)"></a></p><br/><br/><p><em>1/10 en binario '
#           '(primeros 1369 dígitos)</em></p><br/><br/><p>Si suponemos que '
#           'nuestro ordenador es capaz de almacenar hasta 53 dígitos, una vez '
#           'truncado nuestro 0.1 queda representado en binario '
#           'como:</p><br/><br/><p>0.0001100110011001100110011001100110011001100110011001101</p><br/><br/><p>...que '
#           'en decimal '
#           'es</p><br/><br/><p>0.1000000000000000055511151231257827021181583404541015625</p><br/><br/><p>Para '
#           'este problema hay básicamente dos '
#           'soluciones:</p><br/><br/><ul><br/><li>Usar un tipo decimal exacto '
#           'en vez de coma flotante. Hay lenguajes que proporcionan estos tipos '
#           'nativamente (por ejemplo, .NET tiene el tipo <a '
#           'href="https://msdn.microsoft.com/en-us/library/364x0z75.aspx">decimal</a>); '
#           'para los que no, suele haber librerías especializadas para ello '
#           '(por ejemplo <a '
#           'href="https://github.com/MikeMcl/decimal.js">decimal.js</a> para '
#           'Javascript).</li><br/><li>Si el número de decimales se conoce por '
#           'adelantado (por ejemplo al tratar con valores monetarios), los '
#           'valores se pueden representar como enteros. Así, 123.45€ se '
#           'representaría como 12345 céntimos. El punto decimal se añadiría al '
#           'final, a la hora de mostrar el valor al '
#           'usuario.</li><br/></ul><br/><br/><p>Un buen sitio con más '
#           'información sobre este tema: <a '
#           'href="http://puntoflotante.org">http://puntoflotante.org</a></p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 3,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2015, 12, 2, 7, 43, 50, 70000),
#   'FavoriteCount': 0,
#   'Id': 204,
#   'LastActivityDate': datetime.datetime(2015, 12, 2, 9, 56, 34, 630000),
#   'LastEditDate': datetime.datetime(2015, 12, 2, 9, 56, 34, 630000),
#   'LastEditorDisplayName': None,
#   'LastEditorUserId': 23,
#   'OwnerDisplayName': None,
#   'OwnerUserId': 23,
#   'ParentId': 197,
#   'PostTypeId': 2,
#   'Score': 195,
#   'Tags': None,
#   'Title': None,
#   'ViewCount': 0,
#   '_id': ObjectId('69a8de13736d6c0569ed764d'),
#   'owner': [{'AboutMe': '<p>Empecemos por lo importante: me encantan los <a '
#                         'href="http://en.wikipedia.org/wiki/MSX" rel="nofollow '
#                         'noreferrer">ordenadores MSX</a> y el <a '
#                         'href="https://en.wikipedia.org/wiki/Renault_Twingo#Twingo_I_.281993.E2.80.932007.29" '
#                         'rel="nofollow noreferrer">Renault Twingo clásico</a> '
#                         '(sólo el modelo 1993-2007; los modelos más nuevos son '
#                         'tan aburridos como cualquier otro '
#                         'coche).<br/></p><br/><p>Y ahora la parte aburrida. '
#                         'Soy ingeniero de telecomunicaciones pero trabajo como '
#                         'programador, principalmente en C#. He hecho mucho '
#                         'desarrollo en Windows Forms en el pasado, también WPF '
#                         'y Silverlight, pero ahora estoy más metido en el '
#                         'desarrollo web (al principio sólo backend, pero ahora '
#                         'estoy en el mundo del frontend '
#                         'también).<br/></p><br/><p><del>Cuando tengo tiempo '
#                         'libre me gusta</del> Cuando <em>tenía</em> tiempo '
#                         'libre me gustaba programar mi MSX Turbo-R en '
#                         'ensamblador de Z80. De hecho he desarrollado incluso '
#                         '<a href="http://konamiman.com/msx/msx-s.html#inl" '
#                         'rel="nofollow noreferrer">una pila TCP/IP completa '
#                         'para MSX</a> (<a '
#                         'href="https://bitbucket.org/konamiman/msx/src/cf8fc0cc652e1ff79b1a2fc657b2f10d4e0c72fb/SRC/INL/?at=default" '
#                         'rel="nofollow noreferrer">las fuentes están '
#                         'disponibles</a>, ¡échales un ojo!), que presenté como '
#                         'mi proyecto de final de carrera en la universidad, '
#                         'con muy buenos resultados.</p><br/><p>Puedes ver mis '
#                         'proyectos de software aquí:<br/><br/><a '
#                         'href="http://www.konamiman.com" rel="nofollow '
#                         'noreferrer">http://www.konamiman.com</a><br/><br/><a '
#                         'href="http://github.com/konamiman" rel="nofollow '
#                         'noreferrer">http://github.com/konamiman</a></p><br/><p>Y '
#                         'si quieres puedes escribirme: '
#                         'konamiman@konamiman.com</p><br/>',
#              'AccountId': 3201,
#              'CreationDate': datetime.datetime(2015, 10, 29, 14, 53, 36, 233000),
#              'DisplayName': 'Konamiman',
#              'DownVotes': 4,
#              'Id': 23,
#              'LastAccessDate': datetime.datetime(2023, 11, 13, 20, 49, 46, 673000),
#              'Location': 'Palma de Mallorca, Spain',
#              'Reputation': 5278,
#              'UpVotes': 367,
#              'Views': 787,
#              'WebsiteUrl': 'http://www.konamiman.com',
#              '_id': ObjectId('69a8ddc1736d6c0569d20ab4')}]},
#  {'AcceptedAnswerId': 18233,
#   'AnswerCount': 6,
#   'Body': '<p>Las sentencias dinámicas son sentencias SQL que se crean como '
#           'cadenas de texto (strings) y en las que se insertan/concatenan '
#           'valores obtenidos de alguna fuente (normalmente proveniente del '
#           'usuario), lo que puede hacer que sean vulnerables a inyección SQL '
#           'si no se sanean las entradas, como por '
#           'ejemplo:</p><br/><br/><pre><code>$id_usuario = '
#           '$_POST["id"];<br/><br/>mysql_query("SELECT * FROM usuarios WHERE id '
#           '= $id_usuario");<br/></code></pre><br/><br/><p>Eso es un ejemplo de '
#           'una vulnerabilidad grave en la seguridad de una aplicación (web o '
#           'no) porque si el usuario introdujese un valor como <code>1; DROP '
#           'TABLE usuarios;--</code> nos encontraríamos con que la sentencia '
#           'ejecutada sería:</p><br/><br/><pre><code>SELECT * FROM usuarios '
#           'WHERE id = 1; DROP TABLE '
#           'usuarios;--<br/></code></pre><br/><br/><p>Y se eliminaría la tabla '
#           'Usuarios con todos los datos contenidos en ella. '
#           '</p><br/><br/><p><strong>¿Cómo puedo evitar que la inyección SQL '
#           'ocurra en PHP?</strong></p><br/>',
#   'ClosedDate': None,
#   'CommentCount': 1,
#   'CommunityOwnedDate': None,
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'FavoriteCount': 0,
#   'Id': 18232,
#   'LastActivityDate': datetime.datetime(2023, 5, 16, 22, 14, 53, 633000),
#   'LastEditDate': datetime.datetime(2017, 3, 4, 3, 8, 9, 33000),
#   'LastEditorDisplayName': None,
#   'LastEditorUserId': 29967,
#   'OwnerDisplayName': None,
#   'OwnerUserId': 250,
#   'ParentId': None,
#   'PostTypeId': 1,
#   'Score': 232,
#   'Tags': '<php><mysql><sql><seguridad><inyección-sql>',
#   'Title': '¿Cómo evitar la inyección SQL en PHP?',
#   'ViewCount': 77113,
#   '_id': ObjectId('69a8de13736d6c0569edae17'),
#   'owner': [{'AboutMe': '<p>Ingeniero Software con experiencia en diferentes '
#                         'lenguajes y tecnologías. Moderador electo de Stack '
#                         'Overflow en español desde 2017.</p><br/><br/><p>En mi '
#                         'tiempo libre me gusta jugar con tecnologías web y, en '
#                         'particular, hacer pequeñas cosas en HTML y CSS (sin '
#                         'JavaScript). Como por ejemplo esta <a '
#                         'href="https://codepen.io/alvaromontoro/full/WZZNPR" '
#                         'rel="nofollow noreferrer">pila Duracell</a>, un <a '
#                         'href="https://codepen.io/alvaromontoro/full/jGLOBy" '
#                         'rel="nofollow noreferrer">juego de preguntas</a>, un '
#                         '<a '
#                         'href="https://codepen.io/alvaromontoro/full/Nwgarb/" '
#                         'rel="nofollow noreferrer">reloj textual</a>, o un <a '
#                         'href="https://codepen.io/alvaromontoro/full/OwwQMm/" '
#                         'rel="nofollow noreferrer">juego de mesa completo: '
#                         'Serpientes y '
#                         'Escaleras</a>.</p><br/><br/><hr><br/><br/><p>Enlace a '
#                         'mi <a '
#                         'href="https://www.linkedin.com/in/alvaromontoro/" '
#                         'rel="nofollow noreferrer">perfil profesional de '
#                         'LinkedIn</a>. Si me añades como conexión, añade una '
#                         'nota con tu nombre en Stack Overflow para saber quién '
#                         'eres.</p><br/>',
#              'AccountId': 4550651,
#              'CreationDate': datetime.datetime(2015, 12, 1, 18, 7, 59, 433000),
#              'DisplayName': 'Alvaro Montoro',
#              'DownVotes': 1312,
#              'Id': 250,
#              'LastAccessDate': datetime.datetime(2023, 12, 1, 18, 9, 25, 387000),
#              'Location': 'Austin, TX',
#              'Reputation': 49245,
#              'UpVotes': 3420,
#              'Views': 7610,
#              'WebsiteUrl': 'http://www.alvaromontoro.com',
#              '_id': ObjectId('69a8ddc1736d6c0569d20b85')}]},
#  {'AcceptedAnswerId': None,
#   'AnswerCount': 0,
#   'Body': '<blockquote><br/><h1>NO USES SENTENCIAS DINÁMICAS NI FUNCIONES '
#           '<code>mysql_*</code></h1><br/><p>Las funciones <code>mysql_*</code> '
#           '(<code>mysql_connect</code>, <code>mysql_query</code>, etc.) son '
#           'inseguras por naturaleza y su uso no sólo no está recomendado, sino '
#           'que <strong>se consideran obsoletas y se han eliminado '
#           'completamente a partir de PHP7</strong>.</p><br/><p>Incluso los '
#           'métodos nativos que existen en PHP para sanear las entradas de '
#           'usuario (como <code>mysql_real_escape_string</code>) pueden '
#           'presentar (raros) problemas y fallar en algunos casos como cuando '
#           'se usan codificación de caracteres diferentes a UTF-8 junto a '
#           'versiones no actualizadas de MySQL (en las <a '
#           'href="http://php.net/manual/es/mysqli.real-escape-string.php" '
#           'rel="noreferrer">páginas de PHP para estas funciones</a> se avisa '
#           'de este riesgo).</p><br/></blockquote><br/><hr /><br/><h1>Usa '
#           'sentencias preparadas y consultas parametrizadas</h1><br/><p>Aunque '
#           'se podrían sanear las entradas usando métodos como '
#           '<code>mysqli_real_escape_string</code>, es más recomendable la '
#           'utilización de sentencias preparadas o parametrizadas. Las '
#           'sentencias preparadas te permitirán ejecutar la misma sentencia con '
#           'gran eficiencia.</p><br/><p>En PHP, tienes dos alternativas '
#           'principales: <a href="https://www.php.net/manual/es/book.pdo.php" '
#           'rel="noreferrer">PDO</a> y  <a '
#           'href="https://www.php.net/manual/es/book.mysqli.php" '
#           'rel="noreferrer">MySQLi</a>. Hay varias diferencias entre ambas, '
#           'pero la principal es que PDO se puede usar con diferentes tipos de '
#           'base de datos (<a '
#           'href="https://www.php.net/manual/es/intro.pdo.php#intro.pdo" '
#           'rel="noreferrer">dependiendo del driver utilizado</a>) mientras que '
#           'MySQLi es exclusivamente para bases de datos MySQL. Es por ello que '
#           'recomendaría PDO sobre MySQLi.</p><br/><h2>PDO</h2><br/><p>Los <a '
#           'href="https://www.php.net/manual/es/pdo.prepare.php#refsect1-pdo.prepare-description" '
#           'rel="noreferrer">marcadores de posición</a> (que indican dónde se '
#           'sustituirá una cadena por su valor), se pueden definir bien usando '
#           'un signo de interrogación (<code>?</code>) o bien usando un nombre '
#           '(generalmente empezando con <code>:</code>). Personalmente prefiero '
#           'usar un nombre, porque eso me ayuda a encontrar posibles errores en '
#           'caso de tener múltiples variables.</p><br/><p>Aquí dejo un ejemplo '
#           'para el código de la pregunta:</p><br/><pre><code>// la variable '
#           '$pdo contendrá el objeto con la conexión PDO<br/>$pdo = new '
#           "PDO('mysql:host=mihost;dbname=basedatos', &quot;usuario&quot;, "
#           '&quot;contraseña&quot;);<br/><br/>$id_usuario = '
#           '$_POST[&quot;id&quot;];<br/><br/>$sentencia = '
#           '$pdo-&gt;prepare(&quot;SELECT * FROM usuarios WHERE id = '
#           ':idusuario&quot;);<br/>$sentencia=$pdo-&gt;setAttribute(PDO::ATTR_EMULATE_PREPARES, '
#           'false);<br/>$sentencia-&gt;bindParam(&quot;:idusuario&quot;, '
#           '$id_usuario, '
#           'PDO::PARAM_INT);<br/>$sentencia-&gt;execute();<br/></code></pre><br/><p>En '
#           'este caso, <code>:idusuario</code> se sustituirá por el valor de '
#           '<code>$_POST[&quot;id&quot;]</code> de forma segura, y cuando hace '
#           'el <em>bind</em> se indica que la variable es de tipo entero '
#           '(<code>PDO::PARAM_INT</code>).</p><br/><blockquote><br/><p>Nota: si '
#           'la variable es una cadena de texto se usará '
#           '<code>PDO::PARAM_STR</code> y no hace falta poner las comillas en '
#           'la sentencia SQL; al especificarle a PHP que es una cadena, las '
#           'añadirá automáticamente al hacer el '
#           '<em>bind</em>.</p><br/></blockquote><br/><p>En caso de que existan '
#           'varias variables a incluir en la sentencia SQL, se debe incluir un '
#           'único parámetro para cada uno de los valores que se usan en la '
#           'sentencia. Del ejemplo anterior, el <code>:idusuario</code> puede '
#           'usarse una única vez en la consulta que se esta preparando. Si '
#           'fuera necesario usar el &quot;idusuario&quot; de nuevo en la '
#           'consulta, se debe crear otro parámetro con el valor de '
#           '<code>$id_usuario</code>.</p><br/><pre><code>$pdo = new '
#           "PDO('mysql:host=mihost;dbname=basedatos', &quot;usuario&quot;, "
#           '&quot;contraseña&quot;);<br/><br/>$id_usuario = '
#           '$_POST[&quot;id&quot;];<br/>    <br/>$sentencia = '
#           '$pdo-&gt;prepare(&quot;UPDATE usuarios SET id = :idusuario WHERE id '
#           '= '
#           ':idusuario1&quot;);<br/>$sentencia=$pdo-&gt;setAttribute(PDO::ATTR_EMULATE_PREPARES, '
#           'false);<br/>$sentencia-&gt;bindParam(&quot;:idusuario&quot;, '
#           '$id_usuario, '
#           'PDO::PARAM_INT);<br/>$sentencia-&gt;bindParam(&quot;:idusuario1&quot;, '
#           '$id_usuario, '
#           'PDO::PARAM_INT);<br/>$sentencia-&gt;execute();<br/></code></pre><br/><h2>MySQLi</h2><br/><p>Este '
#           'método tiene <a '
#           'href="https://www.php.net/manual/es/mysqli.quickstart.dual-interface.php" '
#           'rel="noreferrer">dos interfaces</a>: una procedural y otra '
#           'orientada a objetos. La interfaz procedural es muy parecida a '
#           '<code>mysql_*</code>, y por ello la gente que migra desde '
#           '<code>mysql_*</code> puede sentirse atraída por la facilidad que '
#           '<code>mysqli_*</code> ofrece. Aunque, de nuevo personalmente, '
#           'optaría por la versión POO.</p><br/><blockquote><br/><p>Nota: '
#           'aunque las funciones <code>mysqli_*</code> suelen ser parecidas a '
#           'las <code>mysql_*</code>, en algunos casos pueden tener diferentes '
#           'parámetros de entrada o diferentes salidas, lo que puede llevar a '
#           'algo de confusión al principio.</p><br/></blockquote><br/><p>El '
#           'ejemplo de la pregunta quedaría así con MySQLi en su interfaz '
#           'orientada a objetos:</p><br/><pre><code>// en $mysqli tendremos la '
#           'conexión MySQLi<br/>$mysqli = new mysqli(&quot;mihost&quot;, '
#           '&quot;usuario&quot;, &quot;contraseña&quot;, '
#           '&quot;basedatos&quot;);<br/><br/>$id_usuario = '
#           '$_POST[&quot;id&quot;];<br/><br/>$sentencia = '
#           '$mysqli-&gt;prepare(&quot;SELECT * FROM usuarios WHERE id = '
#           '?&quot;);<br/>$sentencia-&gt;bind_param(&quot;i&quot;, $id_usuario '
#           ');<br/>$sentencia-&gt;execute();<br/></code></pre><br/><p>Como se '
#           'puede ver, es bastante parecido a PDO (cambia un poco cómo se '
#           'especifica el <a '
#           'href="https://www.php.net/manual/es/mysqli-stmt.bind-param.php#refsect1-mysqli-stmt.bind-param-parameters" '
#           'rel="noreferrer">tipo de valor</a>, <code>i</code> para enteros y '
#           '<code>s</code> para cadenas, pero la idea es '
#           'similar).</p><br/><p>En la versión procedural de MySQLi, el código '
#           'equivalente sería:</p><br/><pre><code>// en $conn tendríamos la '
#           'conexión a la base de datos con MySQLi<br/>$conn = '
#           'mysqli_connect(&quot;mihost&quot;, &quot;usuario&quot;, '
#           '&quot;contraseña&quot;, '
#           '&quot;basedatos&quot;);<br/><br/>$id_usuario = '
#           '$_POST[&quot;id&quot;];<br/><br/>$sentencia = '
#           'mysqli_prepare(&quot;SELECT * FROM usuarios WHERE id = '
#           '?&quot;);<br/>mysqli_stmt_bind_param($sentencia, &quot;i&quot;, '
#           '$id_usuario);<br/>mysqli_stmt_execute($sentencia);<br/></code></pre><br/><hr '
#           '/><br/><p>Fuente y bibliografía para más información en '
#           'español:</p><br/><ul><br/><li><a '
#           'href="http://php.net/manual/es/mysqli.quickstart.prepared-statements.php" '
#           'rel="noreferrer">Página oficial de PHP sobre sentencias '
#           'preparadas</a></li><br/><li><a '
#           'href="http://php.net/manual/es/pdo.prepared-statements.php" '
#           'rel="noreferrer">Página oficial de PHP sobre sentencias preparadas '
#           'en PDO</a></li><br/><li><a '
#           'href="https://es.wikipedia.org/wiki/Inyecci%C3%B3n_SQL" '
#           'rel="noreferrer">Artículo en Wikipedia sobre la <strong>inyección '
#           'SQL y cómo evitarla en PHP y otros '
#           'lenguajes</strong></a></li><br/></ul><br/>',
#   'ClosedDate': None,
#   'CommentCount': 4,
#   'CommunityOwnedDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'ContentLicense': 'CC BY-SA 4.0',
#   'CreationDate': datetime.datetime(2016, 7, 31, 21, 3, 26, 190000),
#   'FavoriteCount': 0,
#   'Id': 18233,
#   'LastActivityDate': datetime.datetime(2022, 8, 13, 1, 55, 39, 97000),
#   'LastEditDate': datetime.datetime(2022, 8, 13, 1, 55, 39, 97000),
#   'LastEditorDisplayName': None,
#   'LastEditorUserId': 195444,
#   'OwnerDisplayName': None,
#   'OwnerUserId': 250,
#   'ParentId': 18232,
#   'PostTypeId': 2,
#   'Score': 219,
#   'Tags': None,
#   'Title': None,
#   'ViewCount': 0,
#   '_id': ObjectId('69a8de13736d6c0569edae18'),
#   'owner': [{'AboutMe': '<p>Ingeniero Software con experiencia en diferentes '
#                         'lenguajes y tecnologías. Moderador electo de Stack '
#                         'Overflow en español desde 2017.</p><br/><br/><p>En mi '
#                         'tiempo libre me gusta jugar con tecnologías web y, en '
#                         'particular, hacer pequeñas cosas en HTML y CSS (sin '
#                         'JavaScript). Como por ejemplo esta <a '
#                         'href="https://codepen.io/alvaromontoro/full/WZZNPR" '
#                         'rel="nofollow noreferrer">pila Duracell</a>, un <a '
#                         'href="https://codepen.io/alvaromontoro/full/jGLOBy" '
#                         'rel="nofollow noreferrer">juego de preguntas</a>, un '
#                         '<a '
#                         'href="https://codepen.io/alvaromontoro/full/Nwgarb/" '
#                         'rel="nofollow noreferrer">reloj textual</a>, o un <a '
#                         'href="https://codepen.io/alvaromontoro/full/OwwQMm/" '
#                         'rel="nofollow noreferrer">juego de mesa completo: '
#                         'Serpientes y '
#                         'Escaleras</a>.</p><br/><br/><hr><br/><br/><p>Enlace a '
#                         'mi <a '
#                         'href="https://www.linkedin.com/in/alvaromontoro/" '
#                         'rel="nofollow noreferrer">perfil profesional de '
#                         'LinkedIn</a>. Si me añades como conexión, añade una '
#                         'nota con tu nombre en Stack Overflow para saber quién '
#                         'eres.</p><br/>',
#              'AccountId': 4550651,
#              'CreationDate': datetime.datetime(2015, 12, 1, 18, 7, 59, 433000),
#              'DisplayName': 'Alvaro Montoro',
#              'DownVotes': 1312,
#              'Id': 250,
#              'LastAccessDate': datetime.datetime(2023, 12, 1, 18, 9, 25, 387000),
#              'Location': 'Austin, TX',
#              'Reputation': 49245,
#              'UpVotes': 3420,
#              'Views': 7610,
#              'WebsiteUrl': 'http://www.alvaromontoro.com',
#              '_id': ObjectId('69a8ddc1736d6c0569d20b85')}]},
#  {'AcceptedAnswerId': None,
#   'AnswerCount': 0,
#   'Body': '<p>Hola, mi nombre es Álvaro Montoro, soy un Ingeniero Informático '
#           'español aunque actualmente vivo y trabajo en los Estados Unidos, en '
#           'la capital del estado de Texas: Austin.</p><br/><br/><p>Tengo '
#           'experiencia en diferentes ámbitos de programación: back-end, '
#           'front-end, bases de datos, seguridad... y en bastantes lenguajes: '
#           'PHP, Java, C#, Visual Basic, C/C++, JavaScript... lo que hace que '
#           'me mueva por un grupo variado de etiquetas (aunque prefiera las de '
#           'programación web) y se refleja en la medalla <a '
#           'href="https://es.stackoverflow.com/help/badges/15/generalist"><code>generalista</code></a> '
#           '(de momento el único que la '
#           'tiene).</p><br/><br/><p>Pros:</p><br/><br/><ul><br/><li>Paso '
#           'bastante tiempo en SOes (he visitado el sitio 594 días, 384 '
#           'consecutivos ).</li><br/><li>He estado en el sitio desde Area 51 y '
#           'cuento con experiencia en otros sitios de SE (no como '
#           'moderador).</li><br/><li>Me gusta guiarme por las reglas del Centro '
#           'de '
#           'Ayuda.</li><br/></ul><br/><br/><p>Contras:</p><br/><br/><ul><br/><li>Aunque '
#           'activo en chat y meta, debería ser más activo.</li><br/><li>Cuento '
#           'con experiencia en otros sitios de SE, lo que hace que a veces use '
#           'la misma vara de medir que usaría en otros sitios.</li><br/><li>Me '
#           'gusta guiarme por las reglas del Centro de Ayuda... y a veces hay '
#           'que ser más paciente y flexible.</li><br/></ul><br/>',
#   'ClosedDate': None,
#   'CommentCount': 12,
#   'CommunityOwnedDate': datetime.datetime(2017, 7, 18, 20, 7, 26, 473000),
#   'ContentLicense': 'CC BY-SA 3.0',
#   'CreationDate': datetime.datetime(2017, 7, 18, 20, 7, 26, 473000),
#   'FavoriteCount': 0,
#   'Id': 87842,
#   'LastActivityDate': datetime.datetime(2017, 7, 20, 15, 58, 45, 867000),
#   'LastEditDate': datetime.datetime(2017, 7, 20, 15, 58, 45, 867000),
#   'LastEditorDisplayName': None,
#   'LastEditorUserId': 250,
#   'OwnerDisplayName': None,
#   'OwnerUserId': 250,
#   'ParentId': None,
#   'PostTypeId': 6,
#   'Score': 173,
#   'Tags': None,
#   'Title': None,
#   'ViewCount': 0,
#   '_id': ObjectId('69a8de13736d6c0569ee76ce'),
#   'owner': [{'AboutMe': '<p>Ingeniero Software con experiencia en diferentes '
#                         'lenguajes y tecnologías. Moderador electo de Stack '
#                         'Overflow en español desde 2017.</p><br/><br/><p>En mi '
#                         'tiempo libre me gusta jugar con tecnologías web y, en '
#                         'particular, hacer pequeñas cosas en HTML y CSS (sin '
#                         'JavaScript). Como por ejemplo esta <a '
#                         'href="https://codepen.io/alvaromontoro/full/WZZNPR" '
#                         'rel="nofollow noreferrer">pila Duracell</a>, un <a '
#                         'href="https://codepen.io/alvaromontoro/full/jGLOBy" '
#                         'rel="nofollow noreferrer">juego de preguntas</a>, un '
#                         '<a '
#                         'href="https://codepen.io/alvaromontoro/full/Nwgarb/" '
#                         'rel="nofollow noreferrer">reloj textual</a>, o un <a '
#                         'href="https://codepen.io/alvaromontoro/full/OwwQMm/" '
#                         'rel="nofollow noreferrer">juego de mesa completo: '
#                         'Serpientes y '
#                         'Escaleras</a>.</p><br/><br/><hr><br/><br/><p>Enlace a '
#                         'mi <a '
#                         'href="https://www.linkedin.com/in/alvaromontoro/" '
#                         'rel="nofollow noreferrer">perfil profesional de '
#                         'LinkedIn</a>. Si me añades como conexión, añade una '
#                         'nota con tu nombre en Stack Overflow para saber quién '
#                         'eres.</p><br/>',
#              'AccountId': 4550651,
#              'CreationDate': datetime.datetime(2015, 12, 1, 18, 7, 59, 433000),
#              'DisplayName': 'Alvaro Montoro',
#              'DownVotes': 1312,
#              'Id': 250,
#              'LastAccessDate': datetime.datetime(2023, 12, 1, 18, 9, 25, 387000),
#              'Location': 'Austin, TX',
#              'Reputation': 49245,
#              'UpVotes': 3420,
#              'Views': 7610,
#              'WebsiteUrl': 'http://www.alvaromontoro.com',
#              '_id': ObjectId('69a8ddc1736d6c0569d20b85')}]}]

# %% [markdown]
# ### `$arrayElemAt`
#
# El `$lookup` genera un _array_ con todos los resultados. El operador `$arrayElemenAt` accede al primer elemento.

# %% [markdown]
# En este ejemplo, de nuevo seleccionamos, en primer lugar, los posts con un `Score` igual o mayor a 150 con `$match` para a continuación seleccionar los usuarios que han publicado dichos posts incluyéndolo en un nuevo campo llamado `owner`. Finalmente, seleccionamos sólo el elemento en la posición 0 del array generado para `username`.

# %%
respuestas: CommandCursor[dict[str, Any]] = db.posts.aggregate( [
    {'$match': { 'Score' : {'$gte': 150}}},
    {'$lookup': {
        'from': "users",
        'localField': "OwnerUserId",
        'foreignField': "Id",
        'as': "owner"}
    },
    { '$project' : {
        'Id' : True,
        'Score' : True,
        'username' : {'$arrayElemAt' : ['$owner.DisplayName', 0]},
        'owner.DisplayName' : True
      }}
    ])
pp(list(respuestas))
# Out:
# [{'Id': 40,
#   'Score': 206,
#   '_id': ObjectId('69a8de13736d6c0569ed75c9'),
#   'owner': [{'DisplayName': 'jachguate'}],
#   'username': 'jachguate'},
#  {'Id': 197,
#   'Score': 176,
#   '_id': ObjectId('69a8de13736d6c0569ed7649'),
#   'owner': [{'DisplayName': 'Peter Olson'}],
#   'username': 'Peter Olson'},
#  {'Id': 204,
#   'Score': 195,
#   '_id': ObjectId('69a8de13736d6c0569ed764d'),
#   'owner': [{'DisplayName': 'Konamiman'}],
#   'username': 'Konamiman'},
#  {'Id': 18232,
#   'Score': 232,
#   '_id': ObjectId('69a8de13736d6c0569edae17'),
#   'owner': [{'DisplayName': 'Alvaro Montoro'}],
#   'username': 'Alvaro Montoro'},
#  {'Id': 18233,
#   'Score': 219,
#   '_id': ObjectId('69a8de13736d6c0569edae18'),
#   'owner': [{'DisplayName': 'Alvaro Montoro'}],
#   'username': 'Alvaro Montoro'},
#  {'Id': 87842,
#   'Score': 173,
#   '_id': ObjectId('69a8de13736d6c0569ee76ce'),
#   'owner': [{'DisplayName': 'Alvaro Montoro'}],
#   'username': 'Alvaro Montoro'}]

# %% [markdown]
# ### `$unwind`
#
# Este operador *desdobla* una fila por cada elemento del array de la colección.
#
# Ej: El siguiente código:
#
# ```python
# db.inventario.insert_one({ "_id" : 1, "item" : "ABC1", "tallas": [ "S", "M", "L"] })
# db.inventario.aggregate( [ { "$unwind" : "$tallas" } ] )
# ```
#
# Devolverá:
#
# ```json
# { "_id" : 1, "item" : "ABC1", "tallas" : "S" }
# { "_id" : 1, "item" : "ABC1", "tallas" : "M" }
# { "_id" : 1, "item" : "ABC1", "tallas" : "L" }
# ```
#
# En el ejemplo de procesamiento de posts que estamos llevando a cabo, como sabemos que el array `$owner` sólo contiene un elemento, sólo habrá una fila por fila original, pero sin el _array_. Finalmente se puede proyectar el campo que se quiera. En este caso el `ownerDisplayName` que es proyectado (renombrado) como `username`.

# %%
respuestas: CommandCursor[dict[str, Any]] = db.posts.aggregate( [
    { '$match': { 'Score' : {'$gte': 150}}},
    { '$lookup': {
        'from': "users",
        'localField': "OwnerUserId",
        'foreignField': "Id",
        'as': "owner"
      }
    },
    { '$unwind': '$owner'},
    { '$project' : {
          'username': '$owner.DisplayName'
      }
    }
    ])
pp(list(respuestas))
# Out:
# [{'_id': ObjectId('69a8de13736d6c0569ed75c9'), 'username': 'jachguate'},
#  {'_id': ObjectId('69a8de13736d6c0569ed7649'), 'username': 'Peter Olson'},
#  {'_id': ObjectId('69a8de13736d6c0569ed764d'), 'username': 'Konamiman'},
#  {'_id': ObjectId('69a8de13736d6c0569edae17'), 'username': 'Alvaro Montoro'},
#  {'_id': ObjectId('69a8de13736d6c0569edae18'), 'username': 'Alvaro Montoro'},
#  {'_id': ObjectId('69a8de13736d6c0569ee76ce'), 'username': 'Alvaro Montoro'}]

# %% [markdown]
# ### `$push`
#
# Devuelve un array con *todos* los valores que resultan de aplicar una determinada expresión a los documentos que forman parte del pipeline.
#
# El siguiente ejemplo obtiene el listado con el identificador de `Posts` (`Id`) asociados a cada valor de `Score`.

# %%
posts_by_score: CommandCursor[dict[str, Any]] = db.posts.aggregate([
    { '$limit': 2000 },
    {
        '$group':{
            '_id': '$Score',
            'posts':{
                '$push': {
                    'post': '$Id'
                }
            }
        }
    }

])
pp(list(posts_by_score))
# Out:
# [{'_id': 6,
#   'posts': [{'post': 4},
#             {'post': 30},
#             {'post': 49},
#             {'post': 109},
#             {'post': 123},
#             {'post': 127},
#             {'post': 134},
#             {'post': 139},
#             {'post': 178},
#             {'post': 199},
#             {'post': 247},
#             {'post': 259},
#             {'post': 262},
#             {'post': 274},
#             {'post': 288},
#             {'post': 290},
#             {'post': 314},
#             {'post': 322},
#             {'post': 324},
#             {'post': 351},
#             {'post': 370},
#             {'post': 387},
#             {'post': 413},
#             {'post': 415},
#             {'post': 420},
#             {'post': 433},
#             {'post': 444},
#             {'post': 462},
#             {'post': 475},
#             {'post': 477},
#             {'post': 537},
#             {'post': 541},
#             {'post': 546},
#             {'post': 557},
#             {'post': 563},
#             {'post': 620},
#             {'post': 663},
#             {'post': 745},
#             {'post': 753},
#             {'post': 760},
#             {'post': 775},
#             {'post': 794},
#             {'post': 810},
#             {'post': 836},
#             {'post': 872},
#             {'post': 896},
#             {'post': 901},
#             {'post': 905},
#             {'post': 906},
#             {'post': 908},
#             {'post': 933},
#             {'post': 937},
#             {'post': 963},
#             {'post': 966},
#             {'post': 967},
#             {'post': 973},
#             {'post': 978},
#             {'post': 983},
#             {'post': 985},
#             {'post': 991},
#             {'post': 995},
#             {'post': 1070},
#             {'post': 1072},
#             {'post': 1073},
#             {'post': 1076},
#             {'post': 1081},
#             {'post': 1174},
#             {'post': 1195},
#             {'post': 1199},
#             {'post': 1249},
#             {'post': 1274},
#             {'post': 1276},
#             {'post': 1310},
#             {'post': 1362},
#             {'post': 1438},
#             {'post': 1461},
#             {'post': 1465},
#             {'post': 1491},
#             {'post': 1509},
#             {'post': 1532},
#             {'post': 1545},
#             {'post': 1570},
#             {'post': 1651},
#             {'post': 1657},
#             {'post': 1658},
#             {'post': 1747},
#             {'post': 1768},
#             {'post': 1790},
#             {'post': 1879},
#             {'post': 1928},
#             {'post': 1945},
#             {'post': 1986},
#             {'post': 1997},
#             {'post': 2002},
#             {'post': 2070},
#             {'post': 2103},
#             {'post': 2106},
#             {'post': 2136},
#             {'post': 2150},
#             {'post': 2155},
#             {'post': 2187}]},
#  {'_id': 9,
#   'posts': [{'post': 23},
#             {'post': 39},
#             {'post': 89},
#             {'post': 138},
#             {'post': 190},
#             {'post': 266},
#             {'post': 342},
#             {'post': 439},
#             {'post': 484},
#             {'post': 515},
#             {'post': 534},
#             {'post': 543},
#             {'post': 610},
#             {'post': 734},
#             {'post': 844},
#             {'post': 855},
#             {'post': 875},
#             {'post': 934},
#             {'post': 939},
#             {'post': 956},
#             {'post': 957},
#             {'post': 962},
#             {'post': 971},
#             {'post': 980},
#             {'post': 994},
#             {'post': 1231},
#             {'post': 1252},
#             {'post': 1275},
#             {'post': 1321},
#             {'post': 1332},
#             {'post': 1336},
#             {'post': 1446},
#             {'post': 1492},
#             {'post': 1498},
#             {'post': 1527},
#             {'post': 1784},
#             {'post': 1912},
#             {'post': 2022},
#             {'post': 2064},
#             {'post': 2071},
#             {'post': 2198}]},
#  {'_id': 27,
#   'posts': [{'post': 6},
#             {'post': 29},
#             {'post': 191},
#             {'post': 774},
#             {'post': 1558}]},
#  {'_id': 8,
#   'posts': [{'post': 41},
#             {'post': 45},
#             {'post': 48},
#             {'post': 97},
#             {'post': 101},
#             {'post': 119},
#             {'post': 131},
#             {'post': 133},
#             {'post': 167},
#             {'post': 187},
#             {'post': 193},
#             {'post': 195},
#             {'post': 222},
#             {'post': 233},
#             {'post': 237},
#             {'post': 300},
#             {'post': 303},
#             {'post': 341},
#             {'post': 384},
#             {'post': 390},
#             {'post': 407},
#             {'post': 463},
#             {'post': 470},
#             {'post': 536},
#             {'post': 568},
#             {'post': 572},
#             {'post': 587},
#             {'post': 595},
#             {'post': 626},
#             {'post': 755},
#             {'post': 806},
#             {'post': 849},
#             {'post': 871},
#             {'post': 879},
#             {'post': 895},
#             {'post': 927},
#             {'post': 948},
#             {'post': 951},
#             {'post': 981},
#             {'post': 1173},
#             {'post': 1202},
#             {'post': 1245},
#             {'post': 1250},
#             {'post': 1295},
#             {'post': 1334},
#             {'post': 1450},
#             {'post': 1483},
#             {'post': 1495},
#             {'post': 1503},
#             {'post': 1531},
#             {'post': 1542},
#             {'post': 1656},
#             {'post': 1705},
#             {'post': 1750},
#             {'post': 1754},
#             {'post': 1765},
#             {'post': 1781},
#             {'post': 1805},
#             {'post': 1830},
#             {'post': 1872},
#             {'post': 1887},
#             {'post': 1898},
#             {'post': 1992},
#             {'post': 2040},
#             {'post': 2063}]},
#  {'_id': 33, 'posts': [{'post': 621}, {'post': 938}]},
#  {'_id': 39, 'posts': [{'post': 35}, {'post': 334}, {'post': 561}]},
#  {'_id': 1,
#   'posts': [{'post': 260},
#             {'post': 310},
#             {'post': 311},
#             {'post': 321},
#             {'post': 355},
#             {'post': 367},
#             {'post': 392},
#             {'post': 429},
#             {'post': 435},
#             {'post': 489},
#             {'post': 509},
#             {'post': 535},
#             {'post': 566},
#             {'post': 576},
#             {'post': 580},
#             {'post': 625},
#             {'post': 766},
#             {'post': 767},
#             {'post': 770},
#             {'post': 791},
#             {'post': 903},
#             {'post': 931},
#             {'post': 1007},
#             {'post': 1029},
#             {'post': 1031},
#             {'post': 1040},
#             {'post': 1059},
#             {'post': 1078},
#             {'post': 1092},
#             {'post': 1115},
#             {'post': 1131},
#             {'post': 1137},
#             {'post': 1142},
#             {'post': 1182},
#             {'post': 1207},
#             {'post': 1211},
#             {'post': 1220},
#             {'post': 1240},
#             {'post': 1248},
#             {'post': 1253},
#             {'post': 1263},
#             {'post': 1264},
#             {'post': 1268},
#             {'post': 1279},
#             {'post': 1294},
#             {'post': 1303},
#             {'post': 1307},
#             {'post': 1328},
#             {'post': 1329},
#             {'post': 1340},
#             {'post': 1351},
#             {'post': 1354},
#             {'post': 1357},
#             {'post': 1368},
#             {'post': 1380},
#             {'post': 1398},
#             {'post': 1416},
#             {'post': 1417},
#             {'post': 1418},
#             {'post': 1419},
#             {'post': 1420},
#             {'post': 1425},
#             {'post': 1426},
#             {'post': 1439},
#             {'post': 1441},
#             {'post': 1445},
#             {'post': 1447},
#             {'post': 1499},
#             {'post': 1510},
#             {'post': 1552},
#             {'post': 1555},
#             {'post': 1590},
#             {'post': 1600},
#             {'post': 1601},
#             {'post': 1618},
#             {'post': 1633},
#             {'post': 1634},
#             {'post': 1635},
#             {'post': 1646},
#             {'post': 1665},
#             {'post': 1668},
#             {'post': 1721},
#             {'post': 1724},
#             {'post': 1731},
#             {'post': 1743},
#             {'post': 1749},
#             {'post': 1758},
#             {'post': 1766},
#             {'post': 1769},
#             {'post': 1771},
#             {'post': 1775},
#             {'post': 1819},
#             {'post': 1828},
#             {'post': 1844},
#             {'post': 1905},
#             {'post': 1911},
#             {'post': 1947},
#             {'post': 1970},
#             {'post': 1975},
#             {'post': 1976},
#             {'post': 1977},
#             {'post': 1983},
#             {'post': 1998},
#             {'post': 2010},
#             {'post': 2017},
#             {'post': 2026},
#             {'post': 2067},
#             {'post': 2068},
#             {'post': 2072},
#             {'post': 2073},
#             {'post': 2074},
#             {'post': 2075},
#             {'post': 2081},
#             {'post': 2083},
#             {'post': 2090},
#             {'post': 2117},
#             {'post': 2119},
#             {'post': 2120},
#             {'post': 2123},
#             {'post': 2124},
#             {'post': 2128},
#             {'post': 2149},
#             {'post': 2208},
#             {'post': 2214},
#             {'post': 2220},
#             {'post': 2222},
#             {'post': 2231},
#             {'post': 2232},
#             {'post': 2234},
#             {'post': 2235},
#             {'post': 2239}]},
#  {'_id': 20,
#   'posts': [{'post': 3},
#             {'post': 50},
#             {'post': 87},
#             {'post': 129},
#             {'post': 153},
#             {'post': 257},
#             {'post': 412},
#             {'post': 807},
#             {'post': 1238},
#             {'post': 1452},
#             {'post': 1526},
#             {'post': 1785},
#             {'post': 1959},
#             {'post': 1963}]},
#  {'_id': 30,
#   'posts': [{'post': 161},
#             {'post': 424},
#             {'post': 438},
#             {'post': 454},
#             {'post': 1653}]},
#  {'_id': -2,
#   'posts': [{'post': 430},
#             {'post': 982},
#             {'post': 1026},
#             {'post': 1290},
#             {'post': 2007}]},
#  {'_id': -1,
#   'posts': [{'post': 117},
#             {'post': 304},
#             {'post': 487},
#             {'post': 609},
#             {'post': 1065},
#             {'post': 1273},
#             {'post': 1530},
#             {'post': 1660},
#             {'post': 1707},
#             {'post': 1729},
#             {'post': 1730},
#             {'post': 1966},
#             {'post': 2006},
#             {'post': 2091},
#             {'post': 2159},
#             {'post': 2175}]},
#  {'_id': 17,
#   'posts': [{'post': 24},
#             {'post': 102},
#             {'post': 227},
#             {'post': 271},
#             {'post': 289},
#             {'post': 297},
#             {'post': 513},
#             {'post': 554},
#             {'post': 914},
#             {'post': 1297},
#             {'post': 1471}]},
#  {'_id': 22,
#   'posts': [{'post': 47},
#             {'post': 112},
#             {'post': 130},
#             {'post': 267},
#             {'post': 350},
#             {'post': 821},
#             {'post': 972},
#             {'post': 1366},
#             {'post': 1371},
#             {'post': 1958}]},
#  {'_id': 112, 'posts': [{'post': 142}, {'post': 402}]},
#  {'_id': 124, 'posts': [{'post': 331}]},
#  {'_id': 32, 'posts': [{'post': 170}, {'post': 201}, {'post': 619}]},
#  {'_id': 15,
#   'posts': [{'post': 74},
#             {'post': 107},
#             {'post': 383},
#             {'post': 479},
#             {'post': 988},
#             {'post': 996},
#             {'post': 1133},
#             {'post': 1644},
#             {'post': 1972}]},
#  {'_id': 50, 'posts': [{'post': 607}]},
#  {'_id': 44,
#   'posts': [{'post': 38}, {'post': 378}, {'post': 400}, {'post': 1487}]},
#  {'_id': 42,
#   'posts': [{'post': 1544}, {'post': 1648}, {'post': 2133}, {'post': 2184}]},
#  {'_id': 29,
#   'posts': [{'post': 7},
#             {'post': 146},
#             {'post': 162},
#             {'post': 476},
#             {'post': 803},
#             {'post': 1363}]},
#  {'_id': 41,
#   'posts': [{'post': 43}, {'post': 397}, {'post': 622}, {'post': 932}]},
#  {'_id': 79, 'posts': [{'post': 33}]},
#  {'_id': 14,
#   'posts': [{'post': 8},
#             {'post': 27},
#             {'post': 80},
#             {'post': 332},
#             {'post': 356},
#             {'post': 364},
#             {'post': 422},
#             {'post': 558},
#             {'post': 569},
#             {'post': 591},
#             {'post': 660},
#             {'post': 935},
#             {'post': 1015},
#             {'post': 1071},
#             {'post': 1184},
#             {'post': 1272},
#             {'post': 1448},
#             {'post': 1869},
#             {'post': 1952},
#             {'post': 1953},
#             {'post': 1960}]},
#  {'_id': 35, 'posts': [{'post': 309}, {'post': 560}]},
#  {'_id': -5, 'posts': [{'post': 959}]},
#  {'_id': 12,
#   'posts': [{'post': 9},
#             {'post': 25},
#             {'post': 76},
#             {'post': 82},
#             {'post': 111},
#             {'post': 179},
#             {'post': 223},
#             {'post': 249},
#             {'post': 272},
#             {'post': 340},
#             {'post': 346},
#             {'post': 348},
#             {'post': 358},
#             {'post': 368},
#             {'post': 372},
#             {'post': 374},
#             {'post': 386},
#             {'post': 453},
#             {'post': 480},
#             {'post': 588},
#             {'post': 611},
#             {'post': 739},
#             {'post': 777},
#             {'post': 782},
#             {'post': 873},
#             {'post': 881},
#             {'post': 910},
#             {'post': 915},
#             {'post': 960},
#             {'post': 984},
#             {'post': 993},
#             {'post': 1014},
#             {'post': 1020},
#             {'post': 1132},
#             {'post': 1138},
#             {'post': 1327},
#             {'post': 1404},
#             {'post': 1741},
#             {'post': 1792},
#             {'post': 1806},
#             {'post': 1910}]},
#  {'_id': 141, 'posts': [{'post': 36}]},
#  {'_id': 107, 'posts': [{'post': 94}]},
#  {'_id': 46, 'posts': [{'post': 103}, {'post': 460}, {'post': 461}]},
#  {'_id': 10,
#   'posts': [{'post': 16},
#             {'post': 83},
#             {'post': 84},
#             {'post': 110},
#             {'post': 169},
#             {'post': 221},
#             {'post': 250},
#             {'post': 255},
#             {'post': 269},
#             {'post': 285},
#             {'post': 287},
#             {'post': 313},
#             {'post': 316},
#             {'post': 318},
#             {'post': 365},
#             {'post': 393},
#             {'post': 447},
#             {'post': 457},
#             {'post': 512},
#             {'post': 540},
#             {'post': 772},
#             {'post': 841},
#             {'post': 854},
#             {'post': 899},
#             {'post': 944},
#             {'post': 961},
#             {'post': 1018},
#             {'post': 1134},
#             {'post': 1144},
#             {'post': 1284},
#             {'post': 1740},
#             {'post': 1860},
#             {'post': 1873},
#             {'post': 1919},
#             {'post': 2019},
#             {'post': 2194}]},
#  {'_id': 26,
#   'posts': [{'post': 136},
#             {'post': 380},
#             {'post': 450},
#             {'post': 492},
#             {'post': 552},
#             {'post': 1823}]},
#  {'_id': 61, 'posts': [{'post': 852}]},
#  {'_id': 60, 'posts': [{'post': 246}, {'post': 514}]},
#  {'_id': 3,
#   'posts': [{'post': 52},
#             {'post': 92},
#             {'post': 95},
#             {'post': 126},
#             {'post': 140},
#             {'post': 177},
#             {'post': 196},
#             {'post': 198},
#             {'post': 230},
#             {'post': 276},
#             {'post': 284},
#             {'post': 329},
#             {'post': 330},
#             {'post': 353},
#             {'post': 377},
#             {'post': 404},
#             {'post': 411},
#             {'post': 456},
#             {'post': 469},
#             {'post': 485},
#             {'post': 486},
#             {'post': 491},
#             {'post': 551},
#             {'post': 594},
#             {'post': 600},
#             {'post': 627},
#             {'post': 633},
#             {'post': 754},
#             {'post': 758},
#             {'post': 761},
#             {'post': 768},
#             {'post': 815},
#             {'post': 845},
#             {'post': 907},
#             {'post': 912},
#             {'post': 926},
#             {'post': 943},
#             {'post': 945},
#             {'post': 1003},
#             {'post': 1019},
#             {'post': 1025},
#             {'post': 1030},
#             {'post': 1034},
#             {'post': 1061},
#             {'post': 1064},
#             {'post': 1066},
#             {'post': 1122},
#             {'post': 1123},
#             {'post': 1139},
#             {'post': 1157},
#             {'post': 1175},
#             {'post': 1178},
#             {'post': 1179},
#             {'post': 1181},
#             {'post': 1186},
#             {'post': 1188},
#             {'post': 1193},
#             {'post': 1200},
#             {'post': 1204},
#             {'post': 1212},
#             {'post': 1214},
#             {'post': 1219},
#             {'post': 1223},
#             {'post': 1225},
#             {'post': 1233},
#             {'post': 1237},
#             {'post': 1243},
#             {'post': 1244},
#             {'post': 1259},
#             {'post': 1292},
#             {'post': 1304},
#             {'post': 1316},
#             {'post': 1318},
#             {'post': 1319},
#             {'post': 1324},
#             {'post': 1349},
#             {'post': 1353},
#             {'post': 1367},
#             {'post': 1372},
#             {'post': 1402},
#             {'post': 1407},
#             {'post': 1422},
#             {'post': 1429},
#             {'post': 1433},
#             {'post': 1449},
#             {'post': 1460},
#             {'post': 1470},
#             {'post': 1475},
#             {'post': 1484},
#             {'post': 1485},
#             {'post': 1486},
#             {'post': 1489},
#             {'post': 1490},
#             {'post': 1501},
#             {'post': 1507},
#             {'post': 1511},
#             {'post': 1577},
#             {'post': 1587},
#             {'post': 1602},
#             {'post': 1643},
#             {'post': 1662},
#             {'post': 1685},
#             {'post': 1692},
#             {'post': 1695},
#             {'post': 1723},
#             {'post': 1725},
#             {'post': 1733},
#             {'post': 1734},
#             {'post': 1753},
#             {'post': 1759},
#             {'post': 1762},
#             {'post': 1772},
#             {'post': 1782},
#             {'post': 1783},
#             {'post': 1788},
#             {'post': 1793},
#             {'post': 1812},
#             {'post': 1818},
#             {'post': 1821},
#             {'post': 1832},
#             {'post': 1843},
#             {'post': 1861},
#             {'post': 1866},
#             {'post': 1876},
#             {'post': 1880},
#             {'post': 1890},
#             {'post': 1908},
#             {'post': 1913},
#             {'post': 1925},
#             {'post': 1927},
#             {'post': 1934},
#             {'post': 1935},
#             {'post': 1936},
#             {'post': 1955},
#             {'post': 1961},
#             {'post': 1968},
#             {'post': 1982},
#             {'post': 1996},
#             {'post': 2005},
#             {'post': 2008},
#             {'post': 2024},
#             {'post': 2025},
#             {'post': 2029},
#             {'post': 2031},
#             {'post': 2035},
#             {'post': 2039},
#             {'post': 2055},
#             {'post': 2060},
#             {'post': 2061},
#             {'post': 2076},
#             {'post': 2082},
#             {'post': 2105},
#             {'post': 2109},
#             {'post': 2112},
#             {'post': 2157},
#             {'post': 2160},
#             {'post': 2161},
#             {'post': 2163},
#             {'post': 2164},
#             {'post': 2173},
#             {'post': 2176},
#             {'post': 2180},
#             {'post': 2183},
#             {'post': 2186},
#             {'post': 2188},
#             {'post': 2209},
#             {'post': 2212},
#             {'post': 2216},
#             {'post': 2217},
#             {'post': 2219},
#             {'post': 2236},
#             {'post': 2242},
#             {'post': 2243}]},
#  {'_id': 195, 'posts': [{'post': 204}]},
#  {'_id': 7,
#   'posts': [{'post': 32},
#             {'post': 42},
#             {'post': 91},
#             {'post': 108},
#             {'post': 141},
#             {'post': 155},
#             {'post': 224},
#             {'post': 238},
#             {'post': 277},
#             {'post': 286},
#             {'post': 292},
#             {'post': 317},
#             {'post': 328},
#             {'post': 366},
#             {'post': 373},
#             {'post': 399},
#             {'post': 401},
#             {'post': 418},
#             {'post': 434},
#             {'post': 452},
#             {'post': 468},
#             {'post': 547},
#             {'post': 550},
#             {'post': 565},
#             {'post': 602},
#             {'post': 604},
#             {'post': 735},
#             {'post': 746},
#             {'post': 762},
#             {'post': 784},
#             {'post': 795},
#             {'post': 851},
#             {'post': 916},
#             {'post': 940},
#             {'post': 942},
#             {'post': 950},
#             {'post': 954},
#             {'post': 968},
#             {'post': 970},
#             {'post': 1000},
#             {'post': 1012},
#             {'post': 1016},
#             {'post': 1069},
#             {'post': 1164},
#             {'post': 1222},
#             {'post': 1247},
#             {'post': 1296},
#             {'post': 1308},
#             {'post': 1320},
#             {'post': 1335},
#             {'post': 1342},
#             {'post': 1377},
#             {'post': 1378},
#             {'post': 1412},
#             {'post': 1494},
#             {'post': 1496},
#             {'post': 1506},
#             {'post': 1642},
#             {'post': 1652},
#             {'post': 1727},
#             {'post': 1748},
#             {'post': 1780},
#             {'post': 1826},
#             {'post': 1829},
#             {'post': 1889},
#             {'post': 1914},
#             {'post': 1957},
#             {'post': 1964},
#             {'post': 2016},
#             {'post': 2057},
#             {'post': 2152},
#             {'post': 2168},
#             {'post': 2244}]},
#  {'_id': 21,
#   'posts': [{'post': 37},
#             {'post': 192},
#             {'post': 323},
#             {'post': 446},
#             {'post': 930},
#             {'post': 953},
#             {'post': 969},
#             {'post': 1395}]},
#  {'_id': 19,
#   'posts': [{'post': 46},
#             {'post': 258},
#             {'post': 425},
#             {'post': 445},
#             {'post': 648},
#             {'post': 654},
#             {'post': 1326},
#             {'post': 1849},
#             {'post': 1971}]},
#  {'_id': 94, 'posts': [{'post': 225}]},
#  {'_id': 52, 'posts': [{'post': 376}]},
#  {'_id': 56, 'posts': [{'post': 1488}]},
#  {'_id': 38,
#   'posts': [{'post': 105},
#             {'post': 405},
#             {'post': 1661},
#             {'post': 1799},
#             {'post': 1800}]},
#  {'_id': 176, 'posts': [{'post': 197}]},
#  {'_id': 55, 'posts': [{'post': 145}]},
#  {'_id': 54, 'posts': [{'post': 335}]},
#  {'_id': -3,
#   'posts': [{'post': 325}, {'post': 345}, {'post': 1046}, {'post': 1973}]},
#  {'_id': 16,
#   'posts': [{'post': 34},
#             {'post': 96},
#             {'post': 256},
#             {'post': 275},
#             {'post': 764},
#             {'post': 808},
#             {'post': 853},
#             {'post': 1149},
#             {'post': 1325},
#             {'post': 1403},
#             {'post': 1464},
#             {'post': 1706},
#             {'post': 1739},
#             {'post': 1845},
#             {'post': 1907}]},
#  {'_id': -4, 'posts': [{'post': 1260}, {'post': 1348}]},
#  {'_id': 13,
#   'posts': [{'post': 18},
#             {'post': 75},
#             {'post': 104},
#             {'post': 189},
#             {'post': 194},
#             {'post': 206},
#             {'post': 210},
#             {'post': 229},
#             {'post': 252},
#             {'post': 575},
#             {'post': 593},
#             {'post': 909},
#             {'post': 999},
#             {'post': 1087},
#             {'post': 1126},
#             {'post': 1148},
#             {'post': 1224},
#             {'post': 1229},
#             {'post': 1322},
#             {'post': 1444},
#             {'post': 1479},
#             {'post': 1504},
#             {'post': 1846}]},
#  {'_id': 111, 'posts': [{'post': 151}]},
#  {'_id': 0,
#   'posts': [{'post': 14},
#             {'post': 15},
#             {'post': 19},
#             {'post': 20},
#             {'post': 21},
#             {'post': 22},
#             {'post': 85},
#             {'post': 86},
#             {'post': 98},
#             {'post': 99},
#             {'post': 113},
#             {'post': 114},
#             {'post': 115},
#             {'post': 116},
#             {'post': 124},
#             {'post': 125},
#             {'post': 128},
#             {'post': 143},
#             {'post': 144},
#             {'post': 163},
#             {'post': 164},
#             {'post': 165},
#             {'post': 166},
#             {'post': 172},
#             {'post': 173},
#             {'post': 182},
#             {'post': 183},
#             {'post': 184},
#             {'post': 185},
#             {'post': 186},
#             {'post': 213},
#             {'post': 214},
#             {'post': 215},
#             {'post': 216},
#             {'post': 218},
#             {'post': 219},
#             {'post': 239},
#             {'post': 240},
#             {'post': 241},
#             {'post': 242},
#             {'post': 248},
#             {'post': 251},
#             {'post': 279},
#             {'post': 281},
#             {'post': 282},
#             {'post': 283},
#             {'post': 295},
#             {'post': 296},
#             {'post': 305},
#             {'post': 306},
#             {'post': 307},
#             {'post': 326},
#             {'post': 327},
#             {'post': 349},
#             {'post': 369},
#             {'post': 388},
#             {'post': 389},
#             {'post': 396},
#             {'post': 408},
#             {'post': 409},
#             {'post': 436},
#             {'post': 449},
#             {'post': 493},
#             {'post': 494},
#             {'post': 495},
#             {'post': 496},
#             {'post': 497},
#             {'post': 498},
#             {'post': 499},
#             {'post': 500},
#             {'post': 507},
#             {'post': 516},
#             {'post': 517},
#             {'post': 518},
#             {'post': 519},
#             {'post': 520},
#             {'post': 521},
#             {'post': 522},
#             {'post': 523},
#             {'post': 524},
#             {'post': 525},
#             {'post': 526},
#             {'post': 527},
#             {'post': 528},
#             {'post': 529},
#             {'post': 530},
#             {'post': 531},
#             {'post': 532},
#             {'post': 533},
#             {'post': 570},
#             {'post': 577},
#             {'post': 578},
#             {'post': 582},
#             {'post': 583},
#             {'post': 584},
#             {'post': 585},
#             {'post': 589},
#             {'post': 590},
#             {'post': 596},
#             {'post': 597},
#             {'post': 598},
#             {'post': 605},
#             {'post': 606},
#             {'post': 612},
#             {'post': 613},
#             {'post': 615},
#             {'post': 616},
#             {'post': 630},
#             {'post': 631},
#             {'post': 638},
#             {'post': 639},
#             {'post': 640},
#             {'post': 641},
#             {'post': 642},
#             {'post': 643},
#             {'post': 644},
#             {'post': 645},
#             {'post': 646},
#             {'post': 647},
#             {'post': 649},
#             {'post': 650},
#             {'post': 651},
#             {'post': 652},
#             {'post': 655},
#             {'post': 656},
#             {'post': 657},
#             {'post': 658},
#             {'post': 661},
#             {'post': 662},
#             {'post': 666},
#             {'post': 667},
#             {'post': 669},
#             {'post': 670},
#             {'post': 671},
#             {'post': 672},
#             {'post': 673},
#             {'post': 674},
#             {'post': 675},
#             {'post': 676},
#             {'post': 677},
#             {'post': 678},
#             {'post': 679},
#             {'post': 680},
#             {'post': 681},
#             {'post': 682},
#             {'post': 683},
#             {'post': 684},
#             {'post': 685},
#             {'post': 686},
#             {'post': 687},
#             {'post': 688},
#             {'post': 689},
#             {'post': 690},
#             {'post': 691},
#             {'post': 692},
#             {'post': 693},
#             {'post': 694},
#             {'post': 695},
#             {'post': 696},
#             {'post': 697},
#             {'post': 698},
#             {'post': 699},
#             {'post': 700},
#             {'post': 701},
#             {'post': 702},
#             {'post': 703},
#             {'post': 704},
#             {'post': 705},
#             {'post': 706},
#             {'post': 707},
#             {'post': 708},
#             {'post': 709},
#             {'post': 710},
#             {'post': 711},
#             {'post': 712},
#             {'post': 713},
#             {'post': 714},
#             {'post': 715},
#             {'post': 716},
#             {'post': 717},
#             {'post': 718},
#             {'post': 719},
#             {'post': 720},
#             {'post': 721},
#             {'post': 722},
#             {'post': 723},
#             {'post': 724},
#             {'post': 725},
#             {'post': 726},
#             {'post': 727},
#             {'post': 728},
#             {'post': 729},
#             {'post': 730},
#             {'post': 736},
#             {'post': 737},
#             {'post': 740},
#             {'post': 741},
#             {'post': 748},
#             {'post': 749},
#             {'post': 750},
#             {'post': 751},
#             {'post': 787},
#             {'post': 789},
#             {'post': 797},
#             {'post': 798},
#             {'post': 801},
#             {'post': 802},
#             {'post': 820},
#             {'post': 824},
#             {'post': 825},
#             {'post': 826},
#             {'post': 827},
#             {'post': 828},
#             {'post': 829},
#             {'post': 830},
#             {'post': 831},
#             {'post': 833},
#             {'post': 834},
#             {'post': 842},
#             {'post': 843},
#             {'post': 847},
#             {'post': 848},
#             {'post': 856},
#             {'post': 857},
#             {'post': 860},
#             {'post': 861},
#             {'post': 862},
#             {'post': 863},
#             {'post': 864},
#             {'post': 865},
#             {'post': 866},
#             {'post': 867},
#             {'post': 868},
#             {'post': 869},
#             {'post': 877},
#             {'post': 878},
#             {'post': 882},
#             {'post': 883},
#             {'post': 884},
#             {'post': 885},
#             {'post': 886},
#             {'post': 887},
#             {'post': 888},
#             {'post': 889},
#             {'post': 890},
#             {'post': 891},
#             {'post': 892},
#             {'post': 893},
#             {'post': 900},
#             {'post': 904},
#             {'post': 918},
#             {'post': 919},
#             {'post': 920},
#             {'post': 921},
#             {'post': 922},
#             {'post': 923},
#             {'post': 924},
#             {'post': 925},
#             {'post': 928},
#             {'post': 929},
#             {'post': 964},
#             {'post': 965},
#             {'post': 974},
#             {'post': 975},
#             {'post': 976},
#             {'post': 977},
#             {'post': 986},
#             {'post': 987},
#             {'post': 989},
#             {'post': 990},
#             {'post': 997},
#             {'post': 998},
#             {'post': 1001},
#             {'post': 1002},
#             {'post': 1032},
#             {'post': 1033},
#             {'post': 1037},
#             {'post': 1038},
#             {'post': 1039},
#             {'post': 1041},
#             {'post': 1042},
#             {'post': 1044},
#             {'post': 1045},
#             {'post': 1048},
#             {'post': 1052},
#             {'post': 1067},
#             {'post': 1068},
#             {'post': 1074},
#             {'post': 1079},
#             {'post': 1080},
#             {'post': 1100},
#             {'post': 1103},
#             {'post': 1104},
#             {'post': 1108},
#             {'post': 1109},
#             {'post': 1110},
#             {'post': 1111},
#             {'post': 1152},
#             {'post': 1153},
#             {'post': 1161},
#             {'post': 1162},
#             {'post': 1167},
#             {'post': 1170},
#             {'post': 1189},
#             {'post': 1190},
#             {'post': 1191},
#             {'post': 1192},
#             {'post': 1201},
#             {'post': 1203},
#             {'post': 1205},
#             {'post': 1206},
#             {'post': 1208},
#             {'post': 1209},
#             {'post': 1210},
#             {'post': 1213},
#             {'post': 1215},
#             {'post': 1216},
#             {'post': 1246},
#             {'post': 1251},
#             {'post': 1254},
#             {'post': 1255},
#             {'post': 1256},
#             {'post': 1257},
#             {'post': 1266},
#             {'post': 1278},
#             {'post': 1280},
#             {'post': 1281},
#             {'post': 1287},
#             {'post': 1288},
#             {'post': 1289},
#             {'post': 1301},
#             {'post': 1302},
#             {'post': 1314},
#             {'post': 1315},
#             {'post': 1317},
#             {'post': 1331},
#             {'post': 1337},
#             {'post': 1338},
#             {'post': 1344},
#             {'post': 1356},
#             {'post': 1360},
#             {'post': 1364},
#             {'post': 1365},
#             {'post': 1370},
#             {'post': 1382},
#             {'post': 1383},
#             {'post': 1384},
#             {'post': 1385},
#             {'post': 1386},
#             {'post': 1387},
#             {'post': 1389},
#             {'post': 1390},
#             {'post': 1391},
#             {'post': 1392},
#             {'post': 1393},
#             {'post': 1394},
#             {'post': 1396},
#             {'post': 1397},
#             {'post': 1400},
#             {'post': 1401},
#             {'post': 1405},
#             {'post': 1406},
#             {'post': 1424},
#             {'post': 1430},
#             {'post': 1440},
#             {'post': 1442},
#             {'post': 1454},
#             {'post': 1462},
#             {'post': 1463},
#             {'post': 1480},
#             {'post': 1481},
#             {'post': 1500},
#             {'post': 1502},
#             {'post': 1508},
#             {'post': 1512},
#             {'post': 1513},
#             {'post': 1514},
#             {'post': 1515},
#             {'post': 1516},
#             {'post': 1517},
#             {'post': 1518},
#             {'post': 1519},
#             {'post': 1520},
#             {'post': 1521},
#             {'post': 1522},
#             {'post': 1523},
#             {'post': 1524},
#             {'post': 1525},
#             {'post': 1528},
#             {'post': 1529},
#             {'post': 1533},
#             {'post': 1535},
#             {'post': 1536},
#             {'post': 1537},
#             {'post': 1538},
#             {'post': 1540},
#             {'post': 1541},
#             {'post': 1548},
#             {'post': 1549},
#             {'post': 1553},
#             {'post': 1554},
#             {'post': 1556},
#             {'post': 1561},
#             {'post': 1562},
#             {'post': 1563},
#             {'post': 1564},
#             {'post': 1565},
#             {'post': 1566},
#             {'post': 1568},
#             {'post': 1569},
#             {'post': 1571},
#             {'post': 1572},
#             {'post': 1573},
#             {'post': 1574},
#             {'post': 1578},
#             {'post': 1579},
#             {'post': 1580},
#             {'post': 1581},
#             {'post': 1582},
#             {'post': 1583},
#             {'post': 1584},
#             {'post': 1585},
#             {'post': 1586},
#             {'post': 1591},
#             {'post': 1592},
#             {'post': 1595},
#             {'post': 1596},
#             {'post': 1603},
#             {'post': 1604},
#             {'post': 1605},
#             {'post': 1606},
#             {'post': 1607},
#             {'post': 1608},
#             {'post': 1609},
#             {'post': 1610},
#             {'post': 1611},
#             {'post': 1612},
#             {'post': 1614},
#             {'post': 1615},
#             {'post': 1616},
#             {'post': 1617},
#             {'post': 1619},
#             {'post': 1620},
#             {'post': 1621},
#             {'post': 1622},
#             {'post': 1623},
#             {'post': 1624},
#             {'post': 1625},
#             {'post': 1626},
#             {'post': 1627},
#             {'post': 1628},
#             {'post': 1629},
#             {'post': 1636},
#             {'post': 1637},
#             {'post': 1638},
#             {'post': 1639},
#             {'post': 1640},
#             {'post': 1641},
#             {'post': 1654},
#             {'post': 1655},
#             {'post': 1663},
#             {'post': 1666},
#             {'post': 1667},
#             {'post': 1669},
#             {'post': 1670},
#             {'post': 1671},
#             {'post': 1672},
#             {'post': 1673},
#             {'post': 1674},
#             {'post': 1675},
#             {'post': 1676},
#             {'post': 1677},
#             {'post': 1678},
#             {'post': 1679},
#             {'post': 1680},
#             {'post': 1681},
#             {'post': 1682},
#             {'post': 1683},
#             {'post': 1684},
#             {'post': 1688},
#             {'post': 1689},
#             {'post': 1690},
#             {'post': 1691},
#             {'post': 1693},
#             {'post': 1694},
#             {'post': 1696},
#             {'post': 1697},
#             {'post': 1698},
#             {'post': 1699},
#             {'post': 1700},
#             {'post': 1701},
#             {'post': 1702},
#             {'post': 1703},
#             {'post': 1708},
#             {'post': 1709},
#             {'post': 1710},
#             {'post': 1711},
#             {'post': 1712},
#             {'post': 1713},
#             {'post': 1714},
#             {'post': 1715},
#             {'post': 1716},
#             {'post': 1717},
#             {'post': 1718},
#             {'post': 1719},
#             {'post': 1755},
#             {'post': 1757},
#             {'post': 1760},
#             {'post': 1761},
#             {'post': 1763},
#             {'post': 1764},
#             {'post': 1776},
#             {'post': 1777},
#             {'post': 1831},
#             {'post': 1835},
#             {'post': 1836},
#             {'post': 1837},
#             {'post': 1838},
#             {'post': 1847},
#             {'post': 1848},
#             {'post': 1850},
#             {'post': 1851},
#             {'post': 1852},
#             {'post': 1853},
#             {'post': 1854},
#             {'post': 1855},
#             {'post': 1856},
#             {'post': 1857},
#             {'post': 1858},
#             {'post': 1859},
#             {'post': 1862},
#             {'post': 1863},
#             {'post': 1864},
#             {'post': 1865},
#             {'post': 1867},
#             {'post': 1892},
#             {'post': 1893},
#             {'post': 1894},
#             {'post': 1895},
#             {'post': 1896},
#             {'post': 1897},
#             {'post': 1899},
#             {'post': 1900},
#             {'post': 1915},
#             {'post': 1916},
#             {'post': 1920},
#             {'post': 1938},
#             {'post': 1939},
#             {'post': 1940},
#             {'post': 1941},
#             {'post': 1950},
#             {'post': 1951},
#             {'post': 1956},
#             {'post': 1994},
#             {'post': 1995},
#             {'post': 2004},
#             {'post': 2009},
#             {'post': 2020},
#             {'post': 2043},
#             {'post': 2044},
#             {'post': 2047},
#             {'post': 2048},
#             {'post': 2049},
#             {'post': 2054},
#             {'post': 2058},
#             {'post': 2062},
#             {'post': 2077},
#             {'post': 2087},
#             {'post': 2088},
#             {'post': 2096},
#             {'post': 2097},
#             {'post': 2114},
#             {'post': 2115},
#             {'post': 2118},
#             {'post': 2122},
#             {'post': 2126},
#             {'post': 2129},
#             {'post': 2137},
#             {'post': 2138},
#             {'post': 2140},
#             {'post': 2141},
#             {'post': 2143},
#             {'post': 2144},
#             {'post': 2145},
#             {'post': 2146},
#             {'post': 2147},
#             {'post': 2151},
#             {'post': 2158},
#             {'post': 2165},
#             {'post': 2166},
#             {'post': 2169},
#             {'post': 2170},
#             {'post': 2172},
#             {'post': 2177},
#             {'post': 2191},
#             {'post': 2192},
#             {'post': 2196},
#             {'post': 2199},
#             {'post': 2203},
#             {'post': 2206},
#             {'post': 2207},
#             {'post': 2224},
#             {'post': 2225},
#             {'post': 2226},
#             {'post': 2227}]},
#  {'_id': 40,
#   'posts': [{'post': 1},
#             {'post': 171},
#             {'post': 382},
#             {'post': 1539},
#             {'post': 1650}]},
#  {'_id': 47, 'posts': [{'post': 352}, {'post': 2130}]},
#  {'_id': 36, 'posts': [{'post': 1459}]},
#  {'_id': -8, 'posts': [{'post': 175}]},
#  {'_id': 37,
#   'posts': [{'post': 5}, {'post': 152}, {'post': 375}, {'post': 483}]},
#  {'_id': 2,
#   'posts': [{'post': 180},
#             {'post': 188},
#             {'post': 234},
#             {'post': 235},
#             {'post': 264},
#             {'post': 398},
#             {'post': 441},
#             {'post': 455},
#             {'post': 465},
#             {'post': 482},
#             {'post': 559},
#             {'post': 567},
#             {'post': 571},
#             {'post': 603},
#             {'post': 614},
#             {'post': 624},
#             {'post': 668},
#             {'post': 757},
#             {'post': 765},
#             {'post': 773},
#             {'post': 778},
#             {'post': 788},
#             {'post': 790},
#             {'post': 809},
#             {'post': 816},
#             {'post': 823},
#             {'post': 949},
#             {'post': 992},
#             {'post': 1009},
#             {'post': 1022},
#             {'post': 1023},
#             {'post': 1024},
#             {'post': 1035},
#             {'post': 1043},
#             {'post': 1051},
#             {'post': 1056},
#             {'post': 1057},
#             {'post': 1060},
#             {'post': 1063},
#             {'post': 1075},
#             {'post': 1082},
#             {'post': 1090},
#             {'post': 1095},
#             {'post': 1096},
#             {'post': 1097},
#             {'post': 1098},
#             {'post': 1099},
#             {'post': 1105},
#             {'post': 1112},
#             {'post': 1114},
#             {'post': 1116},
#             {'post': 1128},
#             {'post': 1129},
#             {'post': 1147},
#             {'post': 1154},
#             {'post': 1155},
#             {'post': 1165},
#             {'post': 1166},
#             {'post': 1169},
#             {'post': 1180},
#             {'post': 1183},
#             {'post': 1185},
#             {'post': 1187},
#             {'post': 1194},
#             {'post': 1196},
#             {'post': 1198},
#             {'post': 1218},
#             {'post': 1221},
#             {'post': 1226},
#             {'post': 1227},
#             {'post': 1230},
#             {'post': 1235},
#             {'post': 1258},
#             {'post': 1262},
#             {'post': 1265},
#             {'post': 1282},
#             {'post': 1283},
#             {'post': 1286},
#             {'post': 1293},
#             {'post': 1300},
#             {'post': 1309},
#             {'post': 1313},
#             {'post': 1323},
#             {'post': 1341},
#             {'post': 1347},
#             {'post': 1350},
#             {'post': 1381},
#             {'post': 1388},
#             {'post': 1414},
#             {'post': 1437},
#             {'post': 1443},
#             {'post': 1457},
#             {'post': 1467},
#             {'post': 1472},
#             {'post': 1473},
#             {'post': 1477},
#             {'post': 1478},
#             {'post': 1505},
#             {'post': 1551},
#             {'post': 1559},
#             {'post': 1575},
#             {'post': 1589},
#             {'post': 1613},
#             {'post': 1647},
#             {'post': 1687},
#             {'post': 1720},
#             {'post': 1722},
#             {'post': 1726},
#             {'post': 1728},
#             {'post': 1736},
#             {'post': 1742},
#             {'post': 1751},
#             {'post': 1773},
#             {'post': 1774},
#             {'post': 1787},
#             {'post': 1791},
#             {'post': 1796},
#             {'post': 1797},
#             {'post': 1808},
#             {'post': 1810},
#             {'post': 1817},
#             {'post': 1822},
#             {'post': 1868},
#             {'post': 1870},
#             {'post': 1871},
#             {'post': 1877},
#             {'post': 1884},
#             {'post': 1886},
#             {'post': 1903},
#             {'post': 1909},
#             {'post': 1922},
#             {'post': 1962},
#             {'post': 1967},
#             {'post': 1978},
#             {'post': 1980},
#             {'post': 1985},
#             {'post': 1988},
#             {'post': 1989},
#             {'post': 1990},
#             {'post': 1993},
#             {'post': 2014},
#             {'post': 2021},
#             {'post': 2023},
#             {'post': 2028},
#             {'post': 2051},
#             {'post': 2069},
#             {'post': 2079},
#             {'post': 2080},
#             {'post': 2085},
#             {'post': 2089},
#             {'post': 2093},
#             {'post': 2094},
#             {'post': 2098},
#             {'post': 2099},
#             {'post': 2104},
#             {'post': 2111},
#             {'post': 2113},
#             {'post': 2135},
#             {'post': 2142},
#             {'post': 2178},
#             {'post': 2195},
#             {'post': 2197},
#             {'post': 2202},
#             {'post': 2211},
#             {'post': 2215},
#             {'post': 2218},
#             {'post': 2221},
#             {'post': 2228},
#             {'post': 2233},
#             {'post': 2240}]},
#  {'_id': 31,
#   'posts': [{'post': 2},
#             {'post': 137},
#             {'post': 337},
#             {'post': 608},
#             {'post': 936},
#             {'post': 1374},
#             {'post': 2131}]},
#  {'_id': 58, 'posts': [{'post': 154}]},
#  {'_id': 68, 'posts': [{'post': 245}]},
#  {'_id': 51, 'posts': [{'post': 333}, {'post': 2185}]},
#  {'_id': 5,
#   'posts': [{'post': 17},
#             {'post': 44},
#             {'post': 77},
#             {'post': 78},
#             {'post': 79},
#             {'post': 81},
#             {'post': 106},
#             {'post': 158},
#             {'post': 174},
#             {'post': 212},
#             {'post': 236},
#             {'post': 263},
#             {'post': 278},
#             {'post': 294},
#             {'post': 338},
#             {'post': 354},
#             {'post': 394},
#             {'post': 395},
#             {'post': 403},
#             {'post': 410},
#             {'post': 416},
#             {'post': 421},
#             {'post': 428},
#             {'post': 442},
#             {'post': 464},
#             {'post': 510},
#             {'post': 564},
#             {'post': 573},
#             {'post': 599},
#             {'post': 623},
#             {'post': 636},
#             {'post': 664},
#             {'post': 738},
#             {'post': 752},
#             {'post': 780},
#             {'post': 792},
#             {'post': 796},
#             {'post': 817},
#             {'post': 818},
#             {'post': 840},
#             {'post': 850},
#             {'post': 859},
#             {'post': 876},
#             {'post': 911},
#             {'post': 941},
#             {'post': 958},
#             {'post': 1006},
#             {'post': 1008},
#             {'post': 1013},
#             {'post': 1021},
#             {'post': 1028},
#             {'post': 1036},
#             {'post': 1054},
#             {'post': 1113},
#             {'post': 1117},
#             {'post': 1151},
#             {'post': 1159},
#             {'post': 1163},
#             {'post': 1168},
#             {'post': 1176},
#             {'post': 1232},
#             {'post': 1270},
#             {'post': 1277},
#             {'post': 1299},
#             {'post': 1346},
#             {'post': 1375},
#             {'post': 1421},
#             {'post': 1451},
#             {'post': 1453},
#             {'post': 1455},
#             {'post': 1466},
#             {'post': 1476},
#             {'post': 1593},
#             {'post': 1630},
#             {'post': 1732},
#             {'post': 1744},
#             {'post': 1745},
#             {'post': 1778},
#             {'post': 1786},
#             {'post': 1801},
#             {'post': 1802},
#             {'post': 1809},
#             {'post': 1815},
#             {'post': 1816},
#             {'post': 1820},
#             {'post': 1827},
#             {'post': 1840},
#             {'post': 1906},
#             {'post': 1918},
#             {'post': 1924},
#             {'post': 1929},
#             {'post': 1932},
#             {'post': 1949},
#             {'post': 1954},
#             {'post': 1974},
#             {'post': 1984},
#             {'post': 2000},
#             {'post': 2003},
#             {'post': 2027},
#             {'post': 2033},
#             {'post': 2046},
#             {'post': 2056},
#             {'post': 2078},
#             {'post': 2092},
#             {'post': 2108},
#             {'post': 2148},
#             {'post': 2171},
#             {'post': 2179},
#             {'post': 2190},
#             {'post': 2201},
#             {'post': 2237},
#             {'post': 2238}]},
#  {'_id': 206, 'posts': [{'post': 40}]},
#  {'_id': 28,
#   'posts': [{'post': 10},
#             {'post': 12},
#             {'post': 121},
#             {'post': 231},
#             {'post': 298},
#             {'post': 786}]},
#  {'_id': 34,
#   'posts': [{'post': 93}, {'post': 147}, {'post': 763}, {'post': 1458}]},
#  {'_id': 24,
#   'posts': [{'post': 205},
#             {'post': 208},
#             {'post': 268},
#             {'post': 562},
#             {'post': 804},
#             {'post': 1435}]},
#  {'_id': 11,
#   'posts': [{'post': 51},
#             {'post': 60},
#             {'post': 118},
#             {'post': 156},
#             {'post': 168},
#             {'post': 207},
#             {'post': 299},
#             {'post': 302},
#             {'post': 315},
#             {'post': 336},
#             {'post': 478},
#             {'post': 556},
#             {'post': 581},
#             {'post': 629},
#             {'post': 632},
#             {'post': 653},
#             {'post': 731},
#             {'post': 756},
#             {'post': 771},
#             {'post': 783},
#             {'post': 805},
#             {'post': 858},
#             {'post': 894},
#             {'post': 913},
#             {'post': 917},
#             {'post': 1228},
#             {'post': 1411},
#             {'post': 1534},
#             {'post': 1557},
#             {'post': 1738},
#             {'post': 1943},
#             {'post': 1965},
#             {'post': 2012}]},
#  {'_id': 91, 'posts': [{'post': 90}]},
#  {'_id': 4,
#   'posts': [{'post': 61},
#             {'post': 132},
#             {'post': 211},
#             {'post': 220},
#             {'post': 243},
#             {'post': 254},
#             {'post': 301},
#             {'post': 320},
#             {'post': 339},
#             {'post': 343},
#             {'post': 344},
#             {'post': 347},
#             {'post': 357},
#             {'post': 359},
#             {'post': 360},
#             {'post': 371},
#             {'post': 381},
#             {'post': 385},
#             {'post': 414},
#             {'post': 427},
#             {'post': 437},
#             {'post': 451},
#             {'post': 458},
#             {'post': 459},
#             {'post': 502},
#             {'post': 505},
#             {'post': 506},
#             {'post': 511},
#             {'post': 555},
#             {'post': 574},
#             {'post': 586},
#             {'post': 601},
#             {'post': 618},
#             {'post': 637},
#             {'post': 732},
#             {'post': 733},
#             {'post': 759},
#             {'post': 776},
#             {'post': 779},
#             {'post': 781},
#             {'post': 785},
#             {'post': 800},
#             {'post': 814},
#             {'post': 819},
#             {'post': 832},
#             {'post': 839},
#             {'post': 846},
#             {'post': 874},
#             {'post': 898},
#             {'post': 946},
#             {'post': 947},
#             {'post': 955},
#             {'post': 979},
#             {'post': 1004},
#             {'post': 1010},
#             {'post': 1017},
#             {'post': 1055},
#             {'post': 1077},
#             {'post': 1084},
#             {'post': 1089},
#             {'post': 1091},
#             {'post': 1093},
#             {'post': 1118},
#             {'post': 1141},
#             {'post': 1156},
#             {'post': 1160},
#             {'post': 1177},
#             {'post': 1217},
#             {'post': 1239},
#             {'post': 1271},
#             {'post': 1291},
#             {'post': 1333},
#             {'post': 1369},
#             {'post': 1376},
#             {'post': 1379},
#             {'post': 1428},
#             {'post': 1456},
#             {'post': 1474},
#             {'post': 1482},
#             {'post': 1560},
#             {'post': 1567},
#             {'post': 1588},
#             {'post': 1597},
#             {'post': 1599},
#             {'post': 1631},
#             {'post': 1632},
#             {'post': 1664},
#             {'post': 1752},
#             {'post': 1756},
#             {'post': 1767},
#             {'post': 1779},
#             {'post': 1789},
#             {'post': 1794},
#             {'post': 1795},
#             {'post': 1798},
#             {'post': 1803},
#             {'post': 1814},
#             {'post': 1842},
#             {'post': 1878},
#             {'post': 1882},
#             {'post': 1888},
#             {'post': 1902},
#             {'post': 1904},
#             {'post': 1923},
#             {'post': 1933},
#             {'post': 1942},
#             {'post': 1946},
#             {'post': 1948},
#             {'post': 1969},
#             {'post': 2001},
#             {'post': 2015},
#             {'post': 2018},
#             {'post': 2030},
#             {'post': 2034},
#             {'post': 2036},
#             {'post': 2037},
#             {'post': 2038},
#             {'post': 2042},
#             {'post': 2045},
#             {'post': 2050},
#             {'post': 2059},
#             {'post': 2065},
#             {'post': 2084},
#             {'post': 2086},
#             {'post': 2095},
#             {'post': 2125},
#             {'post': 2153},
#             {'post': 2181},
#             {'post': 2193},
#             {'post': 2200},
#             {'post': 2205},
#             {'post': 2213},
#             {'post': 2230},
#             {'post': 2241}]},
#  {'_id': 66, 'posts': [{'post': 209}]},
#  {'_id': 18,
#   'posts': [{'post': 31},
#             {'post': 88},
#             {'post': 135},
#             {'post': 270},
#             {'post': 379},
#             {'post': 423},
#             {'post': 426},
#             {'post': 793},
#             {'post': 822},
#             {'post': 870},
#             {'post': 880},
#             {'post': 1298},
#             {'post': 1493}]},
#  {'_id': 23, 'posts': [{'post': 122}, {'post': 319}]},
#  {'_id': 119, 'posts': [{'post': 226}]},
#  {'_id': 25,
#   'posts': [{'post': 11},
#             {'post': 228},
#             {'post': 363},
#             {'post': 417},
#             {'post': 1234},
#             {'post': 1267},
#             {'post': 1434},
#             {'post': 1497}]}]

# %% [markdown]
# ### `$addToSet`
#
#  Devuelve un array de todos los valores únicos que resultan de aplicar una expresión a cada documento de un grupo.
#
#
# Este ejemplo obtiene el listado de `Tags` asociadas a cada tipo de licencia  `ContentLicense`.

# %%
license_and_tags: CommandCursor[dict[str, Any]] = db.posts.aggregate([
    { "$match" : {"PostTypeId": 1}},
    {"$limit": 1000},

    {'$group':{
            '_id':'$ContentLicense',
            'AllTags': { '$addToSet': "$Tags" }
        }
    }
])
pp(list(license_and_tags))
# Out:
# [{'AllTags': ['<angularjs><pdf>',
#               '<python><xml>',
#               '<git><conflictos>',
#               '<asp.net-mvc-5><asp.net-mvc><linq>',
#               '<python><web2py>',
#               '<c++><qt>',
#               '<java><apache-poi>',
#               '<c++><c++98>',
#               '<javascript><jquery><tinymce>',
#               '<validación><formularios><html5>',
#               '<bash><linux>',
#               '<javascript><ionic><parse.com>',
#               '<javascript><jquery><html5><asp.net-mvc-5>',
#               '<java><windows>',
#               '<python><ponyorm>',
#               '<javascript><c#><asp.net><asp.net-mvc>',
#               '<javascript><datetime><momentjs><firebase>',
#               '<pdf><latex><lyx>',
#               '<php><mysql><sql>',
#               '<sql><oracle-11g><sqlfiddle>',
#               '<android-studio>',
#               '<android><cordova>',
#               '<postgresql>',
#               '<windows-installer>',
#               '<java><gradle><intellij-idea><javadoc>',
#               '<angularjs-2.0><typescript><system.js>',
#               '<c#><asp.net><visual-studio><iis>',
#               '<html><asp.net><bootstrap>',
#               '<linux><vpn>',
#               '<java><base-de-datos><archivo-de-propiedades>',
#               '<javascript><jquery><html5>',
#               '<java><clase>',
#               '<entity-framework><linq>',
#               '<java><netbeans>',
#               '<java><poo>',
#               '<sql-server><funciones><casting>',
#               '<archivo><linux><rsync>',
#               '<sql><sqlite3><sqlite>',
#               '<string><c#>',
#               '<sublimetext>',
#               '<php><html>',
#               '<wordpress>',
#               '<java><drools><rabbit-mq>',
#               '<javascript><facebook><internet-explorer-11>',
#               '<regex><google-hoja-de-cálculo>',
#               '<string><c><manejo-de-memoria>',
#               '<json><mongodb><nosql>',
#               '<javascript><java><jquery>',
#               '<php><sql-server><laravel-5>',
#               '<c#><email><visual-studio-2015>',
#               '<php><apache>',
#               '<javascript><html><json><knockoutjs>',
#               '<javascript><jquery><angularjs>',
#               '<javascript><jquery><jquery-datepicker>',
#               '<java><java-ee><jsf>',
#               '<css><css3><filtros-css>',
#               '<java><dukescript>',
#               '<ios><swift2><objective-c>',
#               '<python><python-2.7>',
#               '<java><jsf>',
#               '<vb.net><asp.net-mvc><entity-framework><linq>',
#               '<html>',
#               '<sharepoint><powershell>',
#               '<django><api><djangorestframework><permisos>',
#               '<javascript><kendoui><knockoutjs>',
#               '<javascript><jquery><html5><asp.net-mvc><bootstrap>',
#               '<java><base-de-datos>',
#               '<ios><swift><swift2>',
#               '<javascript><jquery><thymeleaf>',
#               '<sql><oracle-11g><delphi>',
#               '<javascript><html5><indexeddb>',
#               '<php><formularios>',
#               '<xml><codificación><utf-8>',
#               '<html><html5><css><css3>',
#               '<c#><linux><apache><asp.net-core>',
#               '<json><wcf>',
#               '<java><android><android-studio><gradle>',
#               '<java><jpa>',
#               '<swift>',
#               '<java><netbeans><plugin>',
#               '<javascript><jquery><asp.net-mvc-5>',
#               '<windows>',
#               '<paso-por-valor><paso-por-referencia><lenguaje-agnóstico>',
#               '<c#><windows-forms><bitmap>',
#               '<java><android><google-maps>',
#               '<wolfram-mathematica>',
#               '<php><doctrine><doctrine2>',
#               '<ios><xcode><swift>',
#               '<c#><http><asp.net-web-api>',
#               '<netbeans>',
#               '<android><android-layout><unidades-de-medición>',
#               '<python><json><tweepy>',
#               '<latex>',
#               '<javascript><ember.js>',
#               '<c#><.net><revisión-de-código>',
#               '<javascript><meteor><iron-router>',
#               '<c#><sql><sql-server><entity-framework><code-first>',
#               '<asp.net-mvc><linq>',
#               '<netbeans><maven>',
#               '<c++><casting>',
#               '<java><jersey><swagger>',
#               '<sql-server>',
#               '<c#><mysql><genexus>',
#               '<html><html5>',
#               '<python><django><ordenamiento>',
#               '<php><timestamp>',
#               '<java><jsf><java-ee>',
#               '<php><mysql><bootstrap>',
#               '<delphi>',
#               '<java><android><json>',
#               '<python><excepciones>',
#               '<python><python-3.x><pdf><reportlab>',
#               '<entity-framework><linq-to-sql><dbml>',
#               '<javascript><comparaciones>',
#               '<python><xml><revisión-de-código>',
#               '<git><control-de-versiones>',
#               '<angularjs><spring-mvc><spring-security>',
#               '<swift><admob>',
#               '<php><mysql><mysqli>',
#               '<c++><c++11>',
#               '<javascript><sandbox><seguridad>',
#               '<java>',
#               '<javascript><java><servlets><socket>',
#               '<javascript><fullcalendar>',
#               '<pharo><smalltalk>',
#               '<programación-funcional><haskell><estructuras-de-datos>',
#               '<android><3d>',
#               '<asp.net-mvc-5><asp.net-mvc><asp.net-web-api>',
#               '<javascript><momentjs><underscorejs>',
#               '<android><json>',
#               '<hilos>',
#               '<django><django-models><django-admin><django-forms>',
#               '<json><angularjs><nodejs>',
#               '<git><visual-studio><nodejs><azure>',
#               '<r><ggplot2>',
#               '<c#><asp.net-mvc-5>',
#               '<javascript><underscorejs>',
#               '<android><cordova><ionic>',
#               '<json><swift2>',
#               '<android>',
#               '<c#><asp.net><aplicación-web>',
#               '<asp.net><entity-framework><asp.net-mvc><linq>',
#               '<swift><string>',
#               '<ios><xcode><swift><ios8>',
#               '<visual-studio><visual-studio-2015>',
#               '<nginx><angularjs>',
#               '<linux><bash>',
#               '<ios><swift2>',
#               '<javascript><bootstrap><bootstrap-carousel>',
#               '<string><php><str-replace>',
#               '<conda>',
#               '<java><android><php><json>',
#               '<php><angularjs><mysqli>',
#               '<google-app-engine><objectify><google-datastore>',
#               '<perl><booleano><conversión-de-tipos>',
#               '<vb.net><windows-forms>',
#               '<json><asp.net><ajax><vb.net>',
#               '<dns><iana>',
#               '<css><less>',
#               '<wpf><xaml>',
#               '<python><conda>',
#               '<git><github><git-push><git-fork>',
#               '<c#><xml><soap><wcf>',
#               '<php><yii2><i18n>',
#               '<docker>',
#               '<java><xml>',
#               '<c#><entity-framework>',
#               '<javascript><jquery><json>',
#               '<java><android>',
#               '<angularjs>',
#               '<linux><unix>',
#               '<javascript><jquery><asp.net>',
#               '<c#><asp.net-mvc-5><razor><asp.net-mvc>',
#               '<asp.net><bootstrap><vb.net>',
#               '<c++><makefile>',
#               '<ubuntu><nodejs><ec2><npm>',
#               '<javascript><angularjs>',
#               '<laravel><laravel-5>',
#               '<sequelize.js><pruebas-unitarias>',
#               '<git><git-commit><github><git-push><git-fork>',
#               '<ruby-on-rails><rspec>',
#               '<java><spring><alfresco>',
#               '<android><json><http><gradle>',
#               '<c#><conversión-de-tipos><tipos>',
#               '<spring><hibernate><jpa><spring-mvc>',
#               '<r><rodbc>',
#               '<jsf><primefaces>',
#               '<jquery><ajax><asp.net-mvc-5>',
#               '<doctrine><symfony2>',
#               '<javascript><google-apps-script><google-hoja-de-cálculo><google-forms>',
#               '<python><macos>',
#               '<php><codeigniter><codeigniter-3>',
#               '<sql><oracle>',
#               '<ios><objective-c><uiwebview><ios8>',
#               '<unity3d>',
#               '<c++><array>',
#               '<string><delphi><split>',
#               '<excel>',
#               '<php><laravel><laravel-5>',
#               '<oracle><sqlfiddle>',
#               '<json>',
#               '<c#><jquery><json><asp.net><ajax>',
#               '<c#><visual-studio>',
#               '<python><python-2.7><web2py>',
#               '<python><tkinter>',
#               '<mongodb><nosql>',
#               '<java><postgresql>',
#               '<javascript><html>',
#               '<python>',
#               '<html5><css><bootstrap><css3>',
#               '<postgresql><debian>',
#               '<css><bootstrap><laravel-5><pdf>',
#               '<ios><swift2><xcode>',
#               '<html><xpath>',
#               '<raku>',
#               '<ruby><ruby-on-rails>',
#               '<asp>',
#               '<python><archivo>',
#               '<android><php><json><mysql>',
#               '<c#><asp.net-web-api><automapper>',
#               '<mysql><sql>',
#               '<python><python-3.x><datetime>',
#               '<mongodb>',
#               '<php><joomla3>',
#               '<html5><bootstrap><apache>',
#               '<haskell><tipos><programación-funcional><scala>',
#               '<javascript><html5><css>',
#               '<android><android-studio>',
#               '<android-studio><gradle>',
#               '<ios><midi>',
#               '<java><spring><spring-mvc>',
#               '<api><nosql><couchdb>',
#               '<javascript><html5><bootstrap>',
#               '<reescritura-url><mod-rewrite>',
#               '<asp.net-mvc-5>',
#               '<angularjs><json><http><post>',
#               '<mysql><base-de-datos>',
#               '<javascript><c#><ajax><asp.net-mvc>',
#               '<html><facebook>',
#               '<java><archivo-de-propiedades><i18n>',
#               '<python><django><api><djangorestframework>',
#               '<oauth>',
#               '<javascript><html><css>',
#               '<java><java-ee><ide>',
#               '<bootstrap><ruby-on-rails><ruby>',
#               '<javascript><nodejs><depuración>',
#               '<jboss><seam><jboss-eap>',
#               '<java><try-catch>',
#               '<unix><dup>',
#               '<c#><xaml><uwp><binding><mvvm>',
#               '<javascript><google-apps-script><google-hoja-de-cálculo><google-forms><google-documentos>',
#               '<algoritmos><lenguaje-agnóstico><loops><condiciones>',
#               '<android><android-auto>',
#               '<ide><sublimetext><sublimetext3>',
#               '<c#><sql><asp.net-mvc><entity-framework>',
#               '<python><django><html><css>',
#               '<yii>',
#               '<python><django><nginx>',
#               '<wordpress><tinymce>',
#               '<c#><windows-forms>',
#               '<javascript><angularjs><ajax>',
#               '<javascript><android><swift><objective-c><uiwebview>',
#               '<linux><grep>',
#               '<java><spring-mvc><thymeleaf>',
#               '<php><mysql><html5><bootstrap>',
#               '<jsf>',
#               '<r><geolocalización>',
#               '<python><yield>',
#               '<perl><tipos><booleano>',
#               '<java><eclipse><swt>',
#               '<python><django>',
#               '<java><android><xml>',
#               '<mysql><phpmyadmin>',
#               '<ios><objective-c><swift>',
#               '<bash><shell>',
#               '<string><c>',
#               '<c++><java><rendimiento><optimización>',
#               '<java><java-ee>',
#               '<javascript><redondeo><amcharts>',
#               '<javascript><google-visualization>',
#               '<javascript><html5>',
#               '<c#><unity3d>',
#               '<c#><asp.net><asp.net-mvc><google-maps>',
#               '<java><soap><struts>',
#               '<javascript><android><ajax><cordova><jquery-mobile>',
#               '<javascript><html><google-maps><google-chrome>',
#               '<subversion><svn>',
#               '<sql>',
#               '<azure>',
#               '<javascript><angularjs><nodejs>',
#               '<java><android><bitmap>',
#               '<ios><xcode>',
#               '<php><laravel-5>',
#               '<meteor><cuenta-usuario>',
#               '<ionic>',
#               '<python><variables>',
#               '<spring-mvc><spring-roo><gvnix>',
#               '<html5><ajax><vb.net>',
#               '<windows-forms>',
#               '<haskell>',
#               '<android><android-softkeyboard>',
#               '<visual-studio><nuget>',
#               '<python><django><ec2>',
#               '<python><python-2.7><lista>',
#               '<python><django><django-models><users-roles>',
#               '<git><git-push>',
#               '<java><java-swing>',
#               '<php><optimización><poo>',
#               '<android><sqlite>',
#               '<c#><linq><excel>',
#               '<jquery><css>',
#               '<java><android><optimización><android-sqlite>',
#               '<perl><matrices-asociativas><ordenamiento>',
#               '<oracle><formularios><oracle-10g>',
#               '<typescript><aurelia.io><select2>',
#               '<plugin><wordpress>',
#               '<java><android><linux><windows>',
#               '<reactjs>',
#               '<ssms>',
#               '<javascript><html><xhtml>',
#               '<asp.net><windows><visual-studio><iis>',
#               '<php><angularjs><http><binding><servicio>',
#               '<css3><sass><gulp><gulp-sass>',
#               '<windows><directorioactivo><windows10><registro-windows>',
#               '<php><array>',
#               '<operador>',
#               '<nginx><logrotate><configuración>',
#               '<yii2>',
#               '<c#><linq><wcf>',
#               '<tsql>',
#               '<mysql><vagrant><puppet>',
#               '<python><django><python-3.x><django-models>',
#               '<linux>',
#               '<java><sql><oracle><jdbc>',
#               '<javascript><revisión-de-código>',
#               '<java><conversión-de-tipos><tipos>',
#               '<linux><c>',
#               '<java><windows><java-9>',
#               '<c#><xaml><uwp><mvvm>',
#               '<javascript><poo>',
#               '<python><python-3.x>',
#               '<android><admob>',
#               '<java><hibernate>',
#               '<matemáticas><coma-flotante><lenguaje-agnóstico>',
#               '<javascript><jquery><knockoutjs>',
#               '<asp.net>',
#               '<javascript><jquery><ajax><datatables>',
#               '<javascript><java><string><regex><lenguaje-agnóstico>',
#               '<spring-tool-suite>',
#               '<java><firebird>',
#               '<go>',
#               '<javascript><constantes>',
#               '<c#><jquery><ajax><asp.net-mvc-5><asp.net-mvc>',
#               '<swift><swift2><xcode><parse.com>',
#               '<c#><sharepoint><sharepoint-online>',
#               '<jquery><django><django-models><ajax>',
#               '<javascript><php><regex>',
#               '<php><poo>',
#               '<php><sql-server>',
#               '<javascript><jquery><html><css>',
#               '<swift2><spritekit>',
#               '<css><google-forms>',
#               '<python><django><python-3.x><celery>',
#               '<html><asp.net><vb.net>',
#               '<genexus><devices>',
#               '<archivo><windows><consola><proceso>',
#               '<javascript><regex>',
#               '<git>',
#               '<java><php><json>',
#               '<python><punteros>',
#               '<mercurial><control-de-versiones>',
#               '<javascript><jquery><api><google-drive>',
#               '<css><jsfiddle><scss>',
#               '<java><string><java-8><java-stream>',
#               '<google-apps-script><google-hoja-de-cálculo><optimización>',
#               '<html><.net>',
#               '<pouchdb>',
#               '<c#><xaml><uwp><sqlite3><binding>',
#               '<c++><string><tokens>',
#               '<directorioactivo><office365><smartcard><adfs>',
#               '<javascript><json><xml>',
#               '<java><genexus>',
#               '<spring><spring-roo><gvnix>',
#               '<java><localización>',
#               '<html5><sql-server><bootstrap><vb.net>',
#               '<json><visual-studio><asp.net-core>',
#               '<javascript><jquery><datatables>',
#               '<php><ajax><laravel><laravel-5>',
#               '<c++><c>',
#               '<swift2>',
#               '<apache><.htaccess><redirección><reescritura-url><mod-rewrite>',
#               '<c#><hilos>',
#               '<php><email>',
#               '<c>',
#               '<java><spring><test-ng>',
#               '<java><eclipse><maven>',
#               '<jquery><asp.net><asp.net-mvc-5><ajax>',
#               '<c><hilos>',
#               '<python><django><formularios>',
#               '<plsql><sqldeveloper>',
#               '<jquery><ajax><laravel-5>',
#               '<javascript><jquery><dom>',
#               '<fish>',
#               '<java><paso-por-valor><paso-por-referencia>',
#               '<css>',
#               '<.net><regex><vb.net>',
#               '<c++><string>',
#               '<css><html5><css3><3d><importación>',
#               '<oracle-10g><hql><jpa><seam>',
#               '<sql><oracle><oracle-10g>',
#               '<javascript><babeljs>',
#               '<clojure>',
#               '<django><django-models>',
#               '<linux><debian><ntfs>',
#               '<java><json><gson>',
#               '<java><android><admob>',
#               '<css><internet-explorer><internet-explorer-9>',
#               '<c++>',
#               '<javascript><jquery><angularjs><angular-directivas>',
#               '<sql><sql-server>',
#               '<php><yii2>',
#               '<sql><ms-access-2010>',
#               '<javascript><jasmine><momentjs>',
#               '<visual-studio><azure><visual-studio-2015>',
#               '<regex><notepad++>',
#               '<sql><visual-studio-2013>',
#               '<windows><sublimetext><sublimetext3>',
#               '<bash><linux><shell><sed><awk>',
#               '<asp.net-web-api>',
#               '<javascript><highcharts>',
#               '<c#><asp.net-mvc-5><asp.net-mvc><azure><azure-redis>',
#               '<sql><asp.net-mvc-5><azure>',
#               '<javascript><json><angularjs>',
#               '<swift2><iphone>',
#               '<python><python-2.7><clase><método>',
#               '<.net><entity-framework>',
#               '<javascript><jquery><typescript>',
#               '<git><github><github-pages>',
#               '<php><laravel>',
#               '<c#><asp.net><azure>',
#               '<c#><jquery><html><ajax>',
#               '<javascript><pdf><google-apps-script>',
#               '<shell>',
#               '<ios><swift>',
#               '<java><azul-zulu>',
#               '<javascript><nodejs>',
#               '<ios><formularios><objective-c>',
#               '<ios><objective-c>',
#               '<jquery><html><youtube>',
#               '<python><matplotlib><pyqt5><embebido>',
#               '<swift><objective-c><iphone>',
#               '<ruby-on-rails>',
#               '<python><django><python-3.x>',
#               '<bash>',
#               '<jquery><sql><ajax><entity-framework><.net>',
#               '<c#><xaml><windows-forms><wpf>',
#               '<c#><asp.net><sql-server>',
#               '<html><css><html5><css3>',
#               '<c#><.net><windows>',
#               '<asp.net><asp.net-mvc-5><asp.net-mvc><razor>',
#               '<javascript><json><string>',
#               '<base-de-datos>',
#               '<magento2>',
#               '<javascript><nodejs><pm2>',
#               '<as400>',
#               '<seo>',
#               '<html><css><bootstrap>',
#               '<javascript><parse.com>',
#               '<google-app-engine>',
#               '<php><wordpress>',
#               '<php><mysql>',
#               '<java><hilos><multitasking>',
#               '<java><android><avd>',
#               '<eclipse><ftp>',
#               '<python><matemáticas>',
#               '<java><spring><spring-mvc><spring-security>',
#               '<javascript><d3.js>',
#               '<oracle><revisión-de-código>',
#               '<html><css>',
#               '<c#><jquery><asp.net-mvc-5><asp.net>',
#               '<google-hoja-de-cálculo><formulas><formato-condicional>',
#               '<poo><funciones><estándares>',
#               '<java><alfresco>',
#               '<python><django><django-models>',
#               '<bash><regex>',
#               '<ruby-on-rails><ruby><vistas>',
#               '<oracle><oracle-11g><sqlfiddle>',
#               '<jquery><django><ajax>',
#               '<mysql><datetime><timestamp>',
#               '<mysql><windows><delphi>',
#               '<bash><archivo>',
#               '<android><android-layout>',
#               '<vpn><windows>',
#               '<javascript><php><html5>',
#               '<python><bottle>',
#               '<python><django><python-2.7>',
#               '<java><constructor><clase-abstracta><poo>',
#               '<javascript><jsp><cq5><aem>',
#               '<abap>',
#               '<python><ide><pycharm>',
#               '<nodejs><mongodb><express>',
#               '<jquery><bootstrap>',
#               '<asp.net><oauth><rest>',
#               '<android><arduino><socket><delphi><tcpip>',
#               '<c#><entity-framework><entity-framework-6>',
#               '<java><c++><punteros>',
#               '<c#><.net><asp.net><azure><azure-storage>',
#               '<python><python-3.x><poo>',
#               '<python><imagen>',
#               '<mysql><python><base-de-datos>',
#               '<python><python-3.x><tkinter>',
#               '<javascript><php><mysql>',
#               '<bash><zsh>',
#               '<.net><clickonce><deployment>',
#               '<entity-framework><asp.net-mvc><linq>',
#               '<apache>',
#               '<android><diálogo>',
#               '<php><sqlite3>',
#               '<javascript><jquery><html>',
#               '<c#><asp.net-mvc-5><.net><entity-framework>',
#               '<archivo><unix><grep><ascii>',
#               '<python><python-2.7><python-3.x>',
#               '<ajax><vb.net>',
#               '<c><arduino>',
#               '<nodejs><npm>',
#               '<javascript><knockoutjs>',
#               '<javascript><.net><signalr><real-time>',
#               '<java><dukescript><admob>',
#               '<oracle><oracle-11g>',
#               '<android><gradle>',
#               '<ios><xcode><swift><swift2>',
#               '<java><android><gradle>',
#               '<git><github>',
#               '<javascript><array>',
#               '<python><linux>',
#               '<visual-studio>',
#               '<java><java-ee><jsf><netbeans>',
#               '<mysql>',
#               '<javascript><jquery><asp.net><vb.net>',
#               '<javascript><html><vistas><backbone>',
#               '<java><bigdecimal><redondeo><double>',
#               '<php><facebook>',
#               '<javascript><ajax><promesas>',
#               '<android><google-newsstand-producer><rss>',
#               '<sql><oracle-11g>',
#               '<java><hibernate><sqlite3><sqlite>',
#               '<html><formularios>',
#               '<shell><unix>',
#               '<html><jquery-datepicker>',
#               '<html5><bootstrap>',
#               '<c><manejo-de-memoria>',
#               '<java><string><comparaciones>',
#               '<javascript><ecmascript-2015>',
#               '<html5><css3><bootstrap><wordpress>',
#               '<jquery><ajax><asp.net-web-api><razor>',
#               '<linux><apache>',
#               '<python><array><matplotlib><revisión-de-código><numpy>',
#               '<c#><xaml><uwp>',
#               '<ios><jquery><cordova>',
#               '<python><google-app-engine>',
#               '<nodejs>',
#               '<c#>',
#               '<python><linux><ubuntu><pygame>',
#               '<javascript><jquery>',
#               '<sql><oracle><oracle-11g>',
#               '<java><string><regex>',
#               '<java><io>',
#               '<python><django><djangorestframework>',
#               '<java><excel><apache-poi>',
#               '<array><perl>',
#               '<c#><wpf><xaml>',
#               '<php><sql>',
#               '<java><android><android-layout>',
#               '<jquery><html>',
#               '<ruby><bundler><gemfile>',
#               '<java><primefaces>',
#               '<android-studio><ubuntu><java>',
#               '<c#><.net><visual-studio>',
#               '<oracle><postgresql>',
#               '<javascript><jquery><php><ajax>',
#               '<python><python-2.7><funciones>',
#               '<doctrine><doctrine2>',
#               '<lista><elixir>',
#               '<javascript><jquery><eventos>',
#               '<php>',
#               '<google-datastore><google-app-engine><objectify>',
#               '<vb.net>',
#               '<java><hashmap>',
#               '<html><email><google-chrome>',
#               '<excel><vba>',
#               '<unity3d><webgl>',
#               '<c++><visual-studio-2010>',
#               '<sql><sql-server><tsql>',
#               '<swift><swift2>',
#               '<arduino>',
#               '<django><sql><postgresql>',
#               '<git><mercurial>',
#               '<java><xstream>',
#               '<nodejs><visual-studio-2015>',
#               '<soap><soapui><wcf><servicio>',
#               '<xaml><uwp>',
#               '<git><git-commit>',
#               '<mysql><linux><gpg>',
#               '<ios>',
#               '<nodejs><http>',
#               '<python><string><ordenamiento>',
#               '<javascript>',
#               '<php><sql><mysql><phpmyadmin><mysqli>',
#               '<javascript><jquery><html><html5>',
#               '<haskell><lista>',
#               '<ios><swift><xcode><iphone>',
#               '<css><sass><scss><webpack>',
#               '<javascript><google-apps-script><google-hoja-de-cálculo>',
#               '<java><oracle><base64>',
#               '<java><android><variables>',
#               '<sql-server><postgresql>',
#               '<html><css><google-chrome><internet-explorer>',
#               '<c#><linq>',
#               '<entity-framework><wcf>',
#               '<api><ruby><http><post>',
#               '<jquery><vb.net>',
#               '<javascript><array><object>',
#               '<asp.net><asp.net-mvc-5><razor>',
#               '<tcpip><tcp>',
#               '<ios><xcode><objective-c>',
#               '<javascript><google-maps>',
#               '<javascript><android><reactjs><react-native>',
#               '<java><thymeleaf>',
#               '<java><java-util-scanner>',
#               '<php><mysql><mysqli><seguridad>',
#               '<genexus>',
#               '<google-maps><angularjs><jasmine><karma-jasmine>',
#               '<python><numpy><array>',
#               '<go><tipos>',
#               '<json><asp.net-web-api>',
#               '<python><json><django><python-3.x><formularios>',
#               '<c#><.net>',
#               '<jvm><java>',
#               '<c#><asp.net-mvc><asp.net-web-api>',
#               '<php><codeigniter>',
#               '<java><eclipse><depuración><jboss>',
#               '<javascript><jquery><asincronismo>',
#               '<ios><swift><objective-c>',
#               '<c#><asp.net-mvc-5><razor>',
#               '<java><loops><operador-incremento>',
#               '<javascript><jquery><requirejs>',
#               '<javascript><html><asp>',
#               '<git><git-commit><git-push><control-de-versiones>',
#               '<python><linux><pip><ubuntu><python-2.7>',
#               '<java><java-ee><servlets>',
#               '<php><phpmyadmin><symfony2>',
#               '<c++><constructor>',
#               '<javascript><bookmarklet><gmail>',
#               '<asp.net><visual-studio-2010>',
#               '<mysql><java><spring><hibernate>',
#               '<typescript>',
#               '<c#><motor-de-juego><unity3d><2d>',
#               '<c#><uwp>',
#               '<c#><xaml><wpf>',
#               '<c#><asp.net><asp.net-web-api>',
#               '<nodejs><post><permisos>'],
#   '_id': 'CC BY-SA 3.0'},
#  {'AllTags': ['<c#><reflexión>',
#               '<javascript><validación><email><regex>',
#               '<java><android><navigationview>',
#               '<nodejs><loopback>',
#               '<python><django><python-3.x>',
#               '<c#>',
#               '<bash><verilog>',
#               '<python><python-3.x>',
#               '<java><ordenamiento><lista>',
#               '<.net><asp.net-web-api><asp.net>',
#               '<mysql><sql><join>',
#               '<archivo><fish><exists>',
#               '<java>',
#               '<asp.net><asp.net-mvc><librería><bower>',
#               '<javascript><google-apps-script><google-hoja-de-cálculo>',
#               '<sql-server><asp.net-mvc-5>',
#               '<python><django>',
#               '<c#><ofuscación>',
#               '<java><java-swing>',
#               '<php><html><api>',
#               '<javascript>',
#               '<c#><sql-server><windows-forms>',
#               '<python><django><django-models><base-de-datos>',
#               '<licencias><código-abierto>',
#               '<c++><c++11>',
#               '<python><pip><pillow>',
#               '<c#><.net><entity-framework><asp.net-core><model-view-controller>',
#               '<javascript><clausuras>',
#               '<java><android>',
#               '<python><bootstrap><django><python-3.x><select2>',
#               '<android><android-studio>',
#               '<git><git-push>',
#               '<base-de-datos><cálculo-relacional>',
#               '<select2><yii><yiibooster><cache>',
#               '<javascript><hapijs>',
#               '<git><git-merge>',
#               '<php><mysqli>',
#               '<python><django><python-2.7><utf-8><codificación>',
#               '<python><python-2.7>',
#               '<raku>',
#               '<java><seguridad><ingeniería-inversa>',
#               '<javascript><jquery><asincronismo>',
#               '<c#><asp.net><excel>',
#               '<java><android><android-intent><android-asynctask>',
#               '<xml>',
#               '<python><djangorestframework><django-models>',
#               '<javascript><jquery><asp.net-mvc>'],
#   '_id': 'CC BY-SA 4.0'}]

# %% [markdown]
# ### `$out`
#
# Este comando permite volcar el resultado de un pipeline de agregación en una nueva colección en la base de datos.
#
#
# Este ejemplo selecciona las publicaciones con `Score` mayor o igual a 40, las asocia con sus usuarios mediante un `$lookup`, extrae el nombre del usuario y almacena el resultado en una nueva colección llamada `stackoverflow_users`.

# %%
respuestas: CommandCursor[dict[str, Any]] = db.posts.aggregate( [
        { '$match': { 'Score' : {'$gte': 40}}},
        { '$lookup': {
            'from': "users",
            'localField': "OwnerUserId",
            'foreignField': "Id",
            'as': "owner"
          }
        },
        { '$unwind': '$owner'},
        { '$project' : {
             'username': '$owner.DisplayName'
          }
        },
        {'$out': "stackoverflow_users"}
      ])

# %% [markdown]
# Un documento de ejemplo de la colección generada `stackoverflow_users`:

# %%
pp(db.stackoverflow_users.find_one())
# Out:
# {'_id': ObjectId('69a8de13736d6c0569ed75a5'), 'username': 'Konamiman'}

# %%
db.stackoverflow_users.count_documents({})
# Out:
# 122

# %% [markdown]
# ### `$sort`
#
# Este comando permite ordenar todos los documentos en un orden y los devuyelve ordenados. Para ordenar ascendentemente se usa el valor 1, y -1 para ordenar descendentemente.
#
#
# Este ejemplo selecciona las publicaciones con `Score` mayor o igual a 40 y las ordena en orden ascencente, las asocia con sus usuarios mediante un `$lookup`, extrae el nombre del usuario.

# %%
respuestas: CommandCursor[dict[str, Any]] = db.posts.aggregate( [
        { '$match': { 'Score' : {'$gte': 40}}},
         { '$sort': { 'Score' : 1}},
        { '$lookup': {
            'from': "users",
            'localField': "OwnerUserId",
            'foreignField': "Id",
            'as': "owner"
          }
        },
        { '$unwind': '$owner'},
        { '$project' : {
              'Score': True,
             'username': '$owner.DisplayName'
          }
        }
      ])
respuestas_lst = list(respuestas)
pp(respuestas_lst)
# Out:
# [{'Score': 40,
#   '_id': ObjectId('69a8de13736d6c0569ed75a5'),
#   'username': 'Konamiman'},
#  {'Score': 40,
#   '_id': ObjectId('69a8de13736d6c0569ed7afd'),
#   'username': 'Raider'},
#  {'Score': 40,
#   '_id': ObjectId('69a8de13736d6c0569ed7b63'),
#   'username': 'Gerardo Martínez'},
#  {'Score': 40,
#   '_id': ObjectId('69a8de13736d6c0569ed76f1'),
#   'username': 'Paul Vargas'},
#  {'Score': 40,
#   '_id': ObjectId('69a8de13736d6c0569edac3e'),
#   'username': 'Jordi Castilla'},
#  {'Score': 40,
#   '_id': ObjectId('69a8de13736d6c0569ee7bf4'),
#   'username': 'g3rv4'},
#  {'Score': 40,
#   '_id': ObjectId('69a8de13736d6c0569edd3a1'),
#   'username': 'Mariano'},
#  {'Score': 40,
#   '_id': ObjectId('69a8de13736d6c0569ed7631'),
#   'username': 'fedorqui'},
#  {'Score': 40,
#   '_id': ObjectId('69a8de13736d6c0569edd5ae'),
#   'username': 'Mariano'},
#  {'Score': 40,
#   '_id': ObjectId('69a8de15736d6c0569f1391a'),
#   'username': 'Rutx1'},
#  {'Score': 41,
#   '_id': ObjectId('69a8de13736d6c0569eed97e'),
#   'username': 'Trauma'},
#  {'Score': 41,
#   '_id': ObjectId('69a8de13736d6c0569ed76ff'),
#   'username': 'osjerick'},
#  {'Score': 41,
#   '_id': ObjectId('69a8de13736d6c0569ed77c1'),
#   'username': 'Alvaro Montoro'},
#  {'Score': 41,
#   '_id': ObjectId('69a8de13736d6c0569ed75cc'),
#   'username': 'Angel Angel'},
#  {'Score': 41,
#   '_id': ObjectId('69a8de13736d6c0569ee76f8'),
#   'username': 'gbianchi'},
#  {'Score': 41,
#   '_id': ObjectId('69a8de13736d6c0569ed78e4'),
#   'username': 'Chofoteddy'},
#  {'Score': 41,
#   '_id': ObjectId('69a8de13736d6c0569ee6f27'),
#   'username': 'Mariano'},
#  {'Score': 41,
#   '_id': ObjectId('69a8de13736d6c0569ee54e5'),
#   'username': 'Alvaro Montoro'},
#  {'Score': 41,
#   '_id': ObjectId('69a8de13736d6c0569eddaab'),
#   'username': 'Facu Arg'},
#  {'Score': 42,
#   '_id': ObjectId('69a8de13736d6c0569ef412e'),
#   'username': 'lalengua'},
#  {'Score': 42,
#   '_id': ObjectId('69a8de13736d6c0569edcdea'),
#   'username': 'Juan Pinzón'},
#  {'Score': 42,
#   '_id': ObjectId('69a8de13736d6c0569ed7b01'),
#   'username': 'Wilfredo'},
#  {'Score': 42,
#   '_id': ObjectId('69a8de13736d6c0569ed7d3d'),
#   'username': 'Peter Olson'},
#  {'Score': 42,
#   '_id': ObjectId('69a8de13736d6c0569ed7d12'),
#   'username': 'Dylan Meeus'},
#  {'Score': 42,
#   '_id': ObjectId('69a8de13736d6c0569ed7b62'),
#   'username': 'Gerardo Martínez'},
#  {'Score': 43,
#   '_id': ObjectId('69a8de13736d6c0569edf105'),
#   'username': 'Cristina Carrasco'},
#  {'Score': 43,
#   '_id': ObjectId('69a8de14736d6c0569f06fb8'),
#   'username': 'Nicolas Oñate'},
#  {'Score': 44,
#   '_id': ObjectId('69a8de13736d6c0569ed7ac9'),
#   'username': 'jasilva'},
#  {'Score': 44,
#   '_id': ObjectId('69a8de13736d6c0569ed76ed'),
#   'username': 'Jorgesys'},
#  {'Score': 44,
#   '_id': ObjectId('69a8de13736d6c0569ed75c7'),
#   'username': 'Carlos Muñoz'},
#  {'Score': 44,
#   '_id': ObjectId('69a8de13736d6c0569ed7702'),
#   'username': 'Guillermo Ruiz'},
#  {'Score': 45,
#   '_id': ObjectId('69a8de14736d6c0569f06a92'),
#   'username': 'Tux9000'},
#  {'Score': 45,
#   '_id': ObjectId('69a8de13736d6c0569eeefb1'),
#   'username': 'FJSevilla'},
#  {'Score': 46,
#   '_id': ObjectId('69a8de13736d6c0569ed7738'),
#   'username': 'Angel Angel'},
#  {'Score': 46,
#   '_id': ObjectId('69a8de13736d6c0569ed7737'),
#   'username': 'Angel Angel'},
#  {'Score': 46,
#   '_id': ObjectId('69a8de13736d6c0569edc008'),
#   'username': 'Alvaro Montoro'},
#  {'Score': 46,
#   '_id': ObjectId('69a8de13736d6c0569ed75f4'),
#   'username': 'Mosty Mostacho'},
#  {'Score': 47,
#   '_id': ObjectId('69a8de13736d6c0569ee04d5'),
#   'username': 'Goerman'},
#  {'Score': 47,
#   '_id': ObjectId('69a8de13736d6c0569ed7d10'),
#   'username': 'Danilo '},
#  {'Score': 47,
#   '_id': ObjectId('69a8de13736d6c0569ed76d5'),
#   'username': 'rnrneverdies'},
#  {'Score': 48,
#   '_id': ObjectId('69a8de13736d6c0569ee574a'),
#   'username': 'Pikoh'},
#  {'Score': 49,
#   '_id': ObjectId('69a8de13736d6c0569edd3a2'),
#   'username': 'Mariano'},
#  {'Score': 50,
#   '_id': ObjectId('69a8de13736d6c0569ed77b3'),
#   'username': 'Arie Litovsky'},
#  {'Score': 50,
#   '_id': ObjectId('69a8de13736d6c0569edb847'),
#   'username': 'PaperBirdMaster'},
#  {'Score': 51,
#   '_id': ObjectId('69a8de13736d6c0569ed76c2'),
#   'username': 'rnrneverdies'},
#  {'Score': 51,
#   '_id': ObjectId('69a8de13736d6c0569ed7d3e'),
#   'username': 'Peter Olson'},
#  {'Score': 52,
#   '_id': ObjectId('69a8de13736d6c0569ee7dee'),
#   'username': 'A. Cedano'},
#  {'Score': 52,
#   '_id': ObjectId('69a8de13736d6c0569ef4676'),
#   'username': 'Pablo Lozano'},
#  {'Score': 52,
#   '_id': ObjectId('69a8de13736d6c0569ef8c24'),
#   'username': 'Revolucion for Monica'},
#  {'Score': 52,
#   '_id': ObjectId('69a8de13736d6c0569eea6e2'),
#   'username': 'A. Cedano'},
#  {'Score': 52,
#   '_id': ObjectId('69a8de13736d6c0569ed76eb'),
#   'username': 'Jordi Castilla'},
#  {'Score': 52,
#   '_id': ObjectId('69a8de13736d6c0569edf106'),
#   'username': 'Cristina Carrasco'},
#  {'Score': 54,
#   '_id': ObjectId('69a8de13736d6c0569ed76c4'),
#   'username': 'Anonymous Coward'},
#  {'Score': 54,
#   '_id': ObjectId('69a8de13736d6c0569ee0020'),
#   'username': 'Jorgesys'},
#  {'Score': 55,
#   '_id': ObjectId('69a8de13736d6c0569ed761d'),
#   'username': 'Hewbot'},
#  {'Score': 55,
#   '_id': ObjectId('69a8de13736d6c0569edcb42'),
#   'username': 'Juan Pinzón'},
#  {'Score': 56,
#   '_id': ObjectId('69a8de14736d6c0569f06fba'),
#   'username': 'abulafia'},
#  {'Score': 56,
#   '_id': ObjectId('69a8de13736d6c0569ed7aca'),
#   'username': 'jasilva'},
#  {'Score': 57,
#   '_id': ObjectId('69a8de13736d6c0569ee3c21'),
#   'username': 'Dev. Joel'},
#  {'Score': 58,
#   '_id': ObjectId('69a8de14736d6c0569f0e023'),
#   'username': 'ordago'},
#  {'Score': 58,
#   '_id': ObjectId('69a8de13736d6c0569ee3c20'),
#   'username': 'Jorge Arturo Juarez'},
#  {'Score': 58,
#   '_id': ObjectId('69a8de13736d6c0569ed7623'),
#   'username': 'Carlos Muñoz'},
#  {'Score': 59,
#   '_id': ObjectId('69a8de13736d6c0569ed9594'),
#   'username': 'Geovanny Vargas'},
#  {'Score': 59,
#   '_id': ObjectId('69a8de13736d6c0569edd5af'),
#   'username': 'Mariano'},
#  {'Score': 60,
#   '_id': ObjectId('69a8de13736d6c0569ed7674'),
#   'username': 'Marcos Crispino'},
#  {'Score': 60,
#   '_id': ObjectId('69a8de13736d6c0569ed7760'),
#   'username': 'Fili Santillán'},
#  {'Score': 61,
#   '_id': ObjectId('69a8de13736d6c0569ee7701'),
#   'username': 'fredyfx'},
#  {'Score': 61,
#   '_id': ObjectId('69a8de13736d6c0569ee15d7'),
#   'username': 'D.Bulten'},
#  {'Score': 61,
#   '_id': ObjectId('69a8de13736d6c0569ee4db7'),
#   'username': 'Jorius'},
#  {'Score': 61,
#   '_id': ObjectId('69a8de14736d6c0569f06acb'),
#   'username': 'abulafia'},
#  {'Score': 61,
#   '_id': ObjectId('69a8de13736d6c0569ed7896'),
#   'username': 'ccsakuweb'},
#  {'Score': 62,
#   '_id': ObjectId('69a8de13736d6c0569ee574b'),
#   'username': 'Pikoh'},
#  {'Score': 62,
#   '_id': ObjectId('69a8de13736d6c0569edc0f2'),
#   'username': 'Juan Pinzón'},
#  {'Score': 64,
#   '_id': ObjectId('69a8de13736d6c0569edb85a'),
#   'username': 'devconcept'},
#  {'Score': 65,
#   '_id': ObjectId('69a8de13736d6c0569edcb4e'),
#   'username': 'devconcept'},
#  {'Score': 65,
#   '_id': ObjectId('69a8de13736d6c0569edac42'),
#   'username': 'dddenis'},
#  {'Score': 65,
#   '_id': ObjectId('69a8de13736d6c0569eddad1'),
#   'username': 'FJSevilla'},
#  {'Score': 66,
#   '_id': ObjectId('69a8de13736d6c0569ed7652'),
#   'username': 'Peter Olson'},
#  {'Score': 68,
#   '_id': ObjectId('69a8de13736d6c0569ed7673'),
#   'username': 'jpganz18'},
#  {'Score': 70,
#   '_id': ObjectId('69a8de13736d6c0569eea68c'),
#   'username': 'A. Cedano'},
#  {'Score': 71,
#   '_id': ObjectId('69a8de13736d6c0569ee4db1'),
#   'username': 'A. Cedano'},
#  {'Score': 76,
#   '_id': ObjectId('69a8de13736d6c0569edd716'),
#   'username': 'NPN328'},
#  {'Score': 76, '_id': ObjectId('69a8de13736d6c0569ee3c1e'), 'username': 'ESCM'},
#  {'Score': 77,
#   '_id': ObjectId('69a8de13736d6c0569ede86a'),
#   'username': 'Francisco Romero'},
#  {'Score': 78,
#   '_id': ObjectId('69a8de13736d6c0569ee287b'),
#   'username': 'Dev 200'},
#  {'Score': 79,
#   '_id': ObjectId('69a8de13736d6c0569eea6f2'),
#   'username': 'Pablo Lozano'},
#  {'Score': 79,
#   '_id': ObjectId('69a8de13736d6c0569ed75c2'),
#   'username': 'jachguate'},
#  {'Score': 80, '_id': ObjectId('69a8de13736d6c0569edb854'), 'username': 'Shaz'},
#  {'Score': 82,
#   '_id': ObjectId('69a8de13736d6c0569ef4677'),
#   'username': 'Pablo Lozano'},
#  {'Score': 86,
#   '_id': ObjectId('69a8de13736d6c0569ee2881'),
#   'username': 'A. Cedano'},
#  {'Score': 86,
#   '_id': ObjectId('69a8de13736d6c0569ee125e'),
#   'username': 'Joacer'},
#  {'Score': 88,
#   '_id': ObjectId('69a8de13736d6c0569edf7af'),
#   'username': 'SJuan76'},
#  {'Score': 89,
#   '_id': ObjectId('69a8de13736d6c0569ee7a05'),
#   'username': 'Jorgesys'},
#  {'Score': 89,
#   '_id': ObjectId('69a8de13736d6c0569edc0f7'),
#   'username': 'Jesus Angulo'},
#  {'Score': 90,
#   '_id': ObjectId('69a8de13736d6c0569ed98bd'),
#   'username': 'Alvaro Montoro'},
#  {'Score': 90,
#   '_id': ObjectId('69a8de13736d6c0569ee163d'),
#   'username': 'A. Cedano'},
#  {'Score': 91,
#   '_id': ObjectId('69a8de13736d6c0569ee0021'),
#   'username': 'Jorgesys'},
#  {'Score': 91,
#   '_id': ObjectId('69a8de13736d6c0569ed75e8'),
#   'username': 'Mosty Mostacho'},
#  {'Score': 93, '_id': ObjectId('69a8de13736d6c0569ee365d'), 'username': 'Phi'},
#  {'Score': 94,
#   '_id': ObjectId('69a8de13736d6c0569ed7661'),
#   'username': 'Jordi Castilla'},
#  {'Score': 94,
#   '_id': ObjectId('69a8de13736d6c0569ee773e'),
#   'username': 'lois6b'},
#  {'Score': 101,
#   '_id': ObjectId('69a8de13736d6c0569ed98be'),
#   'username': 'Alvaro Montoro'},
#  {'Score': 106,
#   '_id': ObjectId('69a8de13736d6c0569ee36ba'),
#   'username': 'gugadev'},
#  {'Score': 107, '_id': ObjectId('69a8de13736d6c0569ed75ec'), 'username': 'Jcl'},
#  {'Score': 108,
#   '_id': ObjectId('69a8de13736d6c0569edcde4'),
#   'username': 'Black Sheep'},
#  {'Score': 111,
#   '_id': ObjectId('69a8de13736d6c0569ed7620'),
#   'username': 'Hewbot'},
#  {'Score': 112,
#   '_id': ObjectId('69a8de13736d6c0569ed761a'),
#   'username': 'Mariano'},
#  {'Score': 112,
#   '_id': ObjectId('69a8de13736d6c0569ed7704'),
#   'username': 'Peter Olson'},
#  {'Score': 113,
#   '_id': ObjectId('69a8de13736d6c0569edd725'),
#   'username': 'FJSevilla'},
#  {'Score': 113,
#   '_id': ObjectId('69a8de13736d6c0569edf7b0'),
#   'username': 'SJuan76'},
#  {'Score': 116, '_id': ObjectId('69a8de13736d6c0569edcdf6'), 'username': 'ABu'},
#  {'Score': 117,
#   '_id': ObjectId('69a8de13736d6c0569ee126a'),
#   'username': 'A. Cedano'},
#  {'Score': 118,
#   '_id': ObjectId('69a8de13736d6c0569ede86b'),
#   'username': 'Francisco Romero'},
#  {'Score': 119,
#   '_id': ObjectId('69a8de13736d6c0569ed7662'),
#   'username': 'Jordi Castilla'},
#  {'Score': 124,
#   '_id': ObjectId('69a8de13736d6c0569ed76c0'),
#   'username': 'Jordi Castilla'},
#  {'Score': 141,
#   '_id': ObjectId('69a8de13736d6c0569ed75c5'),
#   'username': 'jachguate'},
#  {'Score': 173,
#   '_id': ObjectId('69a8de13736d6c0569ee76ce'),
#   'username': 'Alvaro Montoro'},
#  {'Score': 176,
#   '_id': ObjectId('69a8de13736d6c0569ed7649'),
#   'username': 'Peter Olson'},
#  {'Score': 195,
#   '_id': ObjectId('69a8de13736d6c0569ed764d'),
#   'username': 'Konamiman'},
#  {'Score': 206,
#   '_id': ObjectId('69a8de13736d6c0569ed75c9'),
#   'username': 'jachguate'},
#  {'Score': 219,
#   '_id': ObjectId('69a8de13736d6c0569edae18'),
#   'username': 'Alvaro Montoro'},
#  {'Score': 232,
#   '_id': ObjectId('69a8de13736d6c0569edae17'),
#   'username': 'Alvaro Montoro'}]

# %% [markdown]
# ## Ejemplos básicos de agregación

# %% [markdown]
# ### Ejemplo 1: Asociación usuarios con Tags
#
# Con Agregación, vamos a construir una colección que asocia un usuario con los tags que ha usado en todas sus preguntas.
#
# *Por cuestiones de rendimiento vamos a limitar la agregación a 500 elementos.*

# %%
user_tags: CommandCursor[dict[str, Any]] = db.posts.aggregate([
        { "$match" : {"PostTypeId": 1}},

        {"$limit": 500},

        { '$lookup': {
            'from': "users",
            'localField': "OwnerUserId",
            'foreignField': "Id",
            'as': "owner"
          }
        },

        {'$project':{
            'Tags': True,
            'userid' : {'$arrayElemAt' : ['$owner.Id', 0]},
        }},

        {'$group':{
            '_id':'$userid',
            'AllTags': { '$addToSet': "$Tags" }
        }}
])

user_tags_lst = list(user_tags)
pp(user_tags_lst)
# Out:
# [{'AllTags': ['<java><android><avd>'], '_id': 1592},
#  {'AllTags': ['<git><control-de-versiones>', '<reactjs>'], '_id': 75},
#  {'AllTags': ['<ios><swift2>'], '_id': 1784},
#  {'AllTags': ['<html><html5>',
#               '<r><ggplot2>',
#               '<linux><debian><ntfs>',
#               '<latex>',
#               '<python><macos>'],
#   '_id': 271},
#  {'AllTags': ['<android><arduino><socket><delphi><tcpip>',
#               '<delphi>',
#               '<javascript><jquery>',
#               '<mysql><datetime><timestamp>',
#               '<sql><oracle><oracle-10g>',
#               '<mysql><sql><join>'],
#   '_id': 21},
#  {'AllTags': ['<wpf><xaml>', '<c#><reflexión>', '<c#><wpf><xaml>'], '_id': 92},
#  {'AllTags': ['<git><git-commit>',
#               '<java><hilos><multitasking>',
#               '<java>',
#               '<tcpip><tcp>',
#               '<java><android>'],
#   '_id': 1943},
#  {'AllTags': ['<c#>'], '_id': 2325},
#  {'AllTags': ['<javascript>'], '_id': 2113},
#  {'AllTags': ['<javascript><html><xhtml>', '<sql><ms-access-2010>'],
#   '_id': 120},
#  {'AllTags': ['<raku>', '<archivo><linux><rsync>'], '_id': 632},
#  {'AllTags': ['<java><excel><apache-poi>', '<java><apache-poi>'], '_id': 1809},
#  {'AllTags': ['<java><try-catch>'], '_id': 261},
#  {'AllTags': ['<jquery><django><django-models><ajax>'], '_id': 2394},
#  {'AllTags': ['<bash><shell>'], '_id': 2222},
#  {'AllTags': ['<angularjs>'], '_id': 1996},
#  {'AllTags': ['<api><ruby><http><post>', '<ruby-on-rails><ruby><vistas>'],
#   '_id': 29},
#  {'AllTags': ['<genexus>'], '_id': 725},
#  {'AllTags': ['<json><asp.net-web-api>',
#               '<sql><sql-server><tsql>',
#               '<javascript><angularjs>'],
#   '_id': 2256},
#  {'AllTags': ['<android><google-newsstand-producer><rss>'], '_id': 95},
#  {'AllTags': ['<html><formularios>', '<javascript><jquery>'], '_id': 2224},
#  {'AllTags': ['<ssms>'], '_id': 1905},
#  {'AllTags': ['<c#><.net><asp.net><azure><azure-storage>'], '_id': 1482},
#  {'AllTags': ['<javascript><jquery><datatables>',
#               '<javascript><.net><signalr><real-time>'],
#   '_id': 547},
#  {'AllTags': ['<java><primefaces>'], '_id': 2453},
#  {'AllTags': ['<javascript><pdf><google-apps-script>'], '_id': 1360},
#  {'AllTags': ['<c#>'], '_id': 72},
#  {'AllTags': ['<perl><tipos><booleano>',
#               '<perl><matrices-asociativas><ordenamiento>'],
#   '_id': 288},
#  {'AllTags': ['<c++><visual-studio-2010>'], '_id': 2236},
#  {'AllTags': ['<plugin><wordpress>'], '_id': 533},
#  {'AllTags': ['<ruby-on-rails>'], '_id': 2349},
#  {'AllTags': ['<php><sql-server>', '<java><android>', '<git>'], '_id': 1914},
#  {'AllTags': ['<sql-server><asp.net-mvc-5>'], '_id': 1203},
#  {'AllTags': ['<javascript>',
#               '<javascript><json><angularjs>',
#               '<javascript><jquery><json>',
#               '<visual-studio><nuget>',
#               '<javascript><json><xml>',
#               '<javascript><jquery>'],
#   '_id': 1839},
#  {'AllTags': ['<html><css>', '<java>', '<git><git-commit>'], '_id': 260},
#  {'AllTags': ['<typescript><aurelia.io><select2>',
#               '<javascript><jquery><typescript>',
#               '<c#><jquery><ajax><asp.net-mvc-5><asp.net-mvc>'],
#   '_id': 629},
#  {'AllTags': ['<wolfram-mathematica>'], '_id': 1623},
#  {'AllTags': ['<c#><xaml><windows-forms><wpf>',
#               '<javascript><jquery>',
#               '<c#><windows-forms>'],
#   '_id': 2238},
#  {'AllTags': ['<javascript><jquery><json>'], '_id': 731},
#  {'AllTags': ['<java><android><linux><windows>'], '_id': 2379},
#  {'AllTags': ['<c#><windows-forms>', '<c#><sql-server><windows-forms>'],
#   '_id': 531},
#  {'AllTags': ['<c#><sharepoint><sharepoint-online>'], '_id': 78},
#  {'AllTags': ['<javascript><jquery><html5>'], '_id': 2367},
#  {'AllTags': ['<javascript><android><reactjs><react-native>'], '_id': 27},
#  {'AllTags': ['<python><web2py>'], '_id': 908},
#  {'AllTags': ['<java><jsf><java-ee>'], '_id': 2357},
#  {'AllTags': ['<java><firebird>'], '_id': 1687},
#  {'AllTags': ['<c#><asp.net-mvc-5><razor><asp.net-mvc>',
#               '<c#><asp.net-mvc-5><razor>',
#               '<html5><css><bootstrap><css3>'],
#   '_id': 225},
#  {'AllTags': ['<vb.net><windows-forms>', '<c#><asp.net-mvc-5><razor>'],
#   '_id': 1168},
#  {'AllTags': ['<string><php><str-replace>', '<poo><funciones><estándares>'],
#   '_id': 217},
#  {'AllTags': ['<c#><windows-forms>'], '_id': 1840},
#  {'AllTags': ['<json><visual-studio><asp.net-core>'], '_id': 211},
#  {'AllTags': ['<php><yii2><i18n>'], '_id': 1055},
#  {'AllTags': ['<java><hibernate><sqlite3><sqlite>'], '_id': 1972},
#  {'AllTags': ['<java><android><admob>'], '_id': 2163},
#  {'AllTags': ['<php><poo>'], '_id': 659},
#  {'AllTags': ['<c#><motor-de-juego><unity3d><2d>', '<c#><unity3d>'],
#   '_id': 2257},
#  {'AllTags': ['<java><android>'], '_id': 2034},
#  {'AllTags': ['<javascript><validación><email><regex>',
#               '<php><array>',
#               '<xml><codificación><utf-8>'],
#   '_id': 127},
#  {'AllTags': ['<php><doctrine><doctrine2>', '<laravel><laravel-5>'],
#   '_id': 360},
#  {'AllTags': ['<soap><soapui><wcf><servicio>'], '_id': 325},
#  {'AllTags': ['<string><c#>', '<javascript><nodejs>'], '_id': 149},
#  {'AllTags': ['<java><dukescript>',
#               '<unity3d>',
#               '<c#><unity3d>',
#               '<oracle><sqlfiddle>',
#               '<javascript><jquery><json>',
#               '<java><dukescript><admob>',
#               '<css><jsfiddle><scss>',
#               '<javascript>',
#               '<html>',
#               '<jboss><seam><jboss-eap>',
#               '<java><sql><oracle><jdbc>',
#               '<java>',
#               '<oracle-10g><hql><jpa><seam>',
#               '<netbeans>',
#               '<git><git-commit><github><git-push><git-fork>',
#               '<oracle><oracle-11g><sqlfiddle>',
#               '<java><eclipse><depuración><jboss>',
#               '<javascript><html><json><knockoutjs>',
#               '<css>',
#               '<java><netbeans><plugin>',
#               '<java><archivo-de-propiedades><i18n>',
#               '<css><html5><css3><3d><importación>',
#               '<netbeans><maven>',
#               '<oracle><oracle-11g>'],
#   '_id': 342},
#  {'AllTags': ['<c><hilos>',
#               '<json><mongodb><nosql>',
#               '<java><constructor><clase-abstracta><poo>',
#               '<mysql><java><spring><hibernate>',
#               '<javascript><nodejs><depuración>',
#               '<c><manejo-de-memoria>'],
#   '_id': 187},
#  {'AllTags': ['<python><numpy><array>', '<python><yield>'], '_id': 74},
#  {'AllTags': ['<javascript><facebook><internet-explorer-11>'], '_id': 1583},
#  {'AllTags': ['<c#><windows-forms>'], '_id': 1577},
#  {'AllTags': ['<java><oracle><base64>'], '_id': 1555},
#  {'AllTags': ['<ios><xcode><swift><swift2>',
#               '<ios><xcode><swift><ios8>',
#               '<ios><swift><swift2>',
#               '<ios><swift><xcode><iphone>',
#               '<ios><xcode><swift>'],
#   '_id': 1527},
#  {'AllTags': ['<java><json><gson>'], '_id': 143},
#  {'AllTags': ['<java><soap><struts>', '<git>'], '_id': 417},
#  {'AllTags': ['<c#><.net><entity-framework><asp.net-core><model-view-controller>'],
#   '_id': 298},
#  {'AllTags': ['<typescript>'], '_id': 20},
#  {'AllTags': ['<.net><entity-framework>'], '_id': 921},
#  {'AllTags': ['<linux><c>',
#               '<linux><grep>',
#               '<git><github><git-push><git-fork>',
#               '<git><github>'],
#   '_id': 2013},
#  {'AllTags': ['<javascript><angularjs>',
#               '<paso-por-valor><paso-por-referencia><lenguaje-agnóstico>',
#               '<.net><clickonce><deployment>',
#               '<java><java-ee><servlets>',
#               '<java><spring><spring-mvc>'],
#   '_id': None},
#  {'AllTags': ['<php>', '<php><sql>'], '_id': 2392},
#  {'AllTags': ['<ios>', '<ios><xcode>'], '_id': 233},
#  {'AllTags': ['<php><optimización><poo>'], '_id': 1507},
#  {'AllTags': ['<android-studio><ubuntu><java>'], '_id': 2172},
#  {'AllTags': ['<php><sql><mysql><phpmyadmin><mysqli>'], '_id': 2262},
#  {'AllTags': ['<javascript><jquery>'], '_id': 2156},
#  {'AllTags': ['<mysql><windows><delphi>',
#               '<sql><oracle><oracle-11g>',
#               '<sql><oracle-11g><sqlfiddle>',
#               '<google-hoja-de-cálculo><formulas><formato-condicional>',
#               '<sql><oracle>',
#               '<archivo><windows><consola><proceso>'],
#   '_id': 1184},
#  {'AllTags': ['<python><variables>'], '_id': 218},
#  {'AllTags': ['<git><visual-studio><nodejs><azure>',
#               '<visual-studio><azure><visual-studio-2015>'],
#   '_id': 398},
#  {'AllTags': ['<ios><objective-c><swift>'], '_id': 270},
#  {'AllTags': ['<javascript><jquery><dom>',
#               '<javascript><array><object>',
#               '<php><timestamp>'],
#   '_id': 132},
#  {'AllTags': ['<mysql><phpmyadmin>'], '_id': 1007},
#  {'AllTags': ['<ios><swift><swift2>', '<swift2>'], '_id': 1513},
#  {'AllTags': ['<matemáticas><coma-flotante><lenguaje-agnóstico>'], '_id': 416},
#  {'AllTags': ['<html5><bootstrap>'], '_id': 1827},
#  {'AllTags': ['<archivo><unix><grep><ascii>',
#               '<git><git-commit>',
#               '<bash><archivo>',
#               '<bash><zsh>',
#               '<bash><linux><shell><sed><awk>'],
#   '_id': 83},
#  {'AllTags': ['<python><django><python-3.x><django-models>'], '_id': 1270},
#  {'AllTags': ['<javascript><jquery><html><html5>'], '_id': 250},
#  {'AllTags': ['<python><django>'], '_id': 816},
#  {'AllTags': ['<javascript>', '<javascript><ember.js>'], '_id': 430},
#  {'AllTags': ['<c#><ofuscación>'], '_id': 1941},
#  {'AllTags': ['<eclipse><ftp>'], '_id': 2387},
#  {'AllTags': ['<javascript><angularjs>'], '_id': 1407},
#  {'AllTags': ['<android><android-auto>'], '_id': 546},
#  {'AllTags': ['<asp.net><visual-studio-2010>', '<jquery><vb.net>'],
#   '_id': 1399},
#  {'AllTags': ['<php><mysql><mysqli>'], '_id': 1746},
#  {'AllTags': ['<swift><swift2>'], '_id': 2282},
#  {'AllTags': ['<javascript><jquery><jquery-datepicker>',
#               '<c#><conversión-de-tipos><tipos>',
#               '<java><conversión-de-tipos><tipos>',
#               '<git>'],
#   '_id': 2027},
#  {'AllTags': ['<azure>'], '_id': 348},
#  {'AllTags': ['<php><laravel>'], '_id': 2087},
#  {'AllTags': ['<python><python-2.7>', '<hilos>'], '_id': 870},
#  {'AllTags': ['<angularjs><json><http><post>'], '_id': 2136},
#  {'AllTags': ['<windows>'], '_id': 1119},
#  {'AllTags': ['<java><android><android-intent><android-asynctask>',
#               '<java><android><optimización><android-sqlite>'],
#   '_id': 206},
#  {'AllTags': ['<spring><spring-roo><gvnix>'], '_id': 701},
#  {'AllTags': ['<javascript><android><ajax><cordova><jquery-mobile>'],
#   '_id': 2041},
#  {'AllTags': ['<php><codeigniter><codeigniter-3>'], '_id': 2304},
#  {'AllTags': ['<nodejs><post><permisos>'], '_id': 2327},
#  {'AllTags': ['<c#><asp.net-web-api><automapper>'], '_id': 1188},
#  {'AllTags': ['<genexus>'], '_id': 676},
#  {'AllTags': ['<python><matplotlib><pyqt5><embebido>'], '_id': 801},
#  {'AllTags': ['<javascript>'], '_id': 366},
#  {'AllTags': ['<c++><c++11>',
#               '<c++><c>',
#               '<c++><string>',
#               '<c++>',
#               '<c++><string><tokens>',
#               '<c++><casting>'],
#   '_id': 24},
#  {'AllTags': ['<java><base-de-datos><archivo-de-propiedades>'], '_id': 2293},
#  {'AllTags': ['<java><android><android-layout>', '<java><android>'],
#   '_id': 1870},
#  {'AllTags': ['<javascript><html><google-maps><google-chrome>',
#               '<javascript><json><string>',
#               '<c#><.net>',
#               '<spring><hibernate><jpa><spring-mvc>',
#               '<javascript>',
#               '<python><matemáticas>',
#               '<oauth>'],
#   '_id': 2004},
#  {'AllTags': ['<javascript>'], '_id': 2352},
#  {'AllTags': ['<python><conda>', '<conda>', '<python><django>'], '_id': 353},
#  {'AllTags': ['<javascript><jquery><asincronismo>',
#               '<javascript><java><jquery>',
#               '<java><thymeleaf>',
#               '<javascript><jquery><thymeleaf>',
#               '<java><alfresco>',
#               '<java><jpa>'],
#   '_id': 400},
#  {'AllTags': ['<json><swift2>'], '_id': 1913},
#  {'AllTags': ['<jsf><primefaces>'], '_id': 1948},
#  {'AllTags': ['<git>',
#               '<licencias><código-abierto>',
#               '<c++><c++11>',
#               '<c++><array>',
#               '<c#>',
#               '<javascript>'],
#   '_id': 25},
#  {'AllTags': ['<oracle><formularios><oracle-10g>'], '_id': 1390},
#  {'AllTags': ['<git><git-merge>', '<git><git-push>', '<git>'], '_id': 555},
#  {'AllTags': ['<java><java-ee><ide>'], '_id': 167},
#  {'AllTags': ['<python><django><python-2.7>'], '_id': 1274},
#  {'AllTags': ['<javascript><angularjs>', '<javascript><jquery><angularjs>'],
#   '_id': 1505},
#  {'AllTags': ['<mysql><sql>'], '_id': 90},
#  {'AllTags': ['<html><html5><css><css3>'], '_id': 2295},
#  {'AllTags': ['<java><localización>',
#               '<java><c++><punteros>',
#               '<java>',
#               '<java><paso-por-valor><paso-por-referencia>',
#               '<c++><makefile>',
#               '<c++><java><rendimiento><optimización>',
#               '<c++>',
#               '<java><clase>',
#               '<c++><constructor>'],
#   '_id': 301},
#  {'AllTags': ['<select2><yii><yiibooster><cache>'], '_id': 1076},
#  {'AllTags': ['<bash><shell>', '<python><python-2.7><lista>'], '_id': 1965},
#  {'AllTags': ['<javascript>'], '_id': 2346},
#  {'AllTags': ['<javascript><jquery>',
#               '<javascript><google-maps>',
#               '<magento2>',
#               '<javascript><array>',
#               '<php>',
#               '<javascript><php><regex>',
#               '<php><yii2>',
#               '<php><joomla3>',
#               '<bash><linux>',
#               '<javascript><ecmascript-2015>',
#               '<html><xpath>',
#               '<javascript><poo>',
#               '<javascript><html><css>',
#               '<javascript>',
#               '<git>',
#               '<javascript><html>'],
#   '_id': 729},
#  {'AllTags': ['<.net><asp.net-web-api><asp.net>',
#               '<javascript><jasmine><momentjs>',
#               '<javascript><angularjs><ajax>',
#               '<c#>',
#               '<google-maps><angularjs><jasmine><karma-jasmine>',
#               '<javascript><angularjs>'],
#   '_id': 23},
#  {'AllTags': ['<mysql><sql>'], '_id': 660},
#  {'AllTags': ['<android><android-softkeyboard>',
#               '<android><android-layout><unidades-de-medición>'],
#   '_id': 305},
#  {'AllTags': ['<javascript><jquery><api><google-drive>'], '_id': 1947},
#  {'AllTags': ['<api><nosql><couchdb>'], '_id': 2186},
#  {'AllTags': ['<mysql><vagrant><puppet>', '<git>', '<javascript>'], '_id': 399},
#  {'AllTags': ['<.net><regex><vb.net>'], '_id': 745},
#  {'AllTags': ['<django><api><djangorestframework><permisos>'], '_id': 901},
#  {'AllTags': ['<excel><vba>'], '_id': 749},
#  {'AllTags': ['<ios><jquery><cordova>'], '_id': 239},
#  {'AllTags': ['<asp.net><asp.net-mvc><librería><bower>',
#               '<javascript><kendoui><knockoutjs>',
#               '<javascript><knockoutjs>'],
#   '_id': 35},
#  {'AllTags': ['<python><xml>'], '_id': 2059},
#  {'AllTags': ['<abap>'], '_id': 1098},
#  {'AllTags': ['<genexus>'], '_id': 728},
#  {'AllTags': ['<dns><iana>'], '_id': 307},
#  {'AllTags': ['<django><sql><postgresql>'], '_id': 371},
#  {'AllTags': ['<seo>'], '_id': 2208},
#  {'AllTags': ['<xml>'], '_id': 1776},
#  {'AllTags': ['<python><python-2.7><python-3.x>'], '_id': 2540},
#  {'AllTags': ['<html5><css3><bootstrap><wordpress>'], '_id': 1389},
#  {'AllTags': ['<javascript><html>'], '_id': 1788},
#  {'AllTags': ['<ios><objective-c>',
#               '<ios><xcode><objective-c>',
#               '<ios><swift2><xcode>'],
#   '_id': 1499},
#  {'AllTags': ['<ruby-on-rails><rspec>', '<ubuntu><nodejs><ec2><npm>'],
#   '_id': 631},
#  {'AllTags': ['<mongodb><nosql>'], '_id': 2133},
#  {'AllTags': ['<javascript><clausuras>', '<ios><objective-c><uiwebview><ios8>'],
#   '_id': 965},
#  {'AllTags': ['<javascript><html5><indexeddb>'], '_id': 1173},
#  {'AllTags': ['<php><laravel-5>'], '_id': 1545},
#  {'AllTags': ['<c#><asp.net-mvc-5>'], '_id': 2036},
#  {'AllTags': ['<javascript><html><vistas><backbone>'], '_id': 1037},
#  {'AllTags': ['<swift2>'], '_id': 2137},
#  {'AllTags': ['<java><string><comparaciones>',
#               '<java>',
#               '<algoritmos><lenguaje-agnóstico><loops><condiciones>',
#               '<javascript><array>',
#               '<java><string><java-8><java-stream>',
#               '<javascript><jquery><html>',
#               '<java><bigdecimal><redondeo><double>',
#               '<javascript><comparaciones>',
#               '<java><loops><operador-incremento>',
#               '<java><string><regex>'],
#   '_id': 517},
#  {'AllTags': ['<javascript><google-apps-script><google-hoja-de-cálculo><google-forms>',
#               '<javascript><google-apps-script><google-hoja-de-cálculo><google-forms><google-documentos>',
#               '<javascript><bookmarklet><gmail>',
#               '<css><google-forms>',
#               '<javascript><google-apps-script><google-hoja-de-cálculo>'],
#   '_id': 65},
#  {'AllTags': ['<python><djangorestframework><django-models>',
#               '<python><django><django-models><users-roles>',
#               '<python><django>',
#               '<python><django><python-3.x><django-models>',
#               '<django><django-models>'],
#   '_id': 1005},
#  {'AllTags': ['<java><postgresql>'], '_id': 2019},
#  {'AllTags': ['<vb.net>'], '_id': 2531},
#  {'AllTags': ['<ide><sublimetext><sublimetext3>',
#               '<python><python-3.x>',
#               '<meteor><cuenta-usuario>'],
#   '_id': 292},
#  {'AllTags': ['<lista><elixir>', '<ios><xcode>'], '_id': 37},
#  {'AllTags': ['<python><django><ordenamiento>'], '_id': 535},
#  {'AllTags': ['<git>'], '_id': 1798},
#  {'AllTags': ['<tsql>'], '_id': 1859},
#  {'AllTags': ['<c#><uwp>', '<xaml><uwp>'], '_id': 2230},
#  {'AllTags': ['<vpn><windows>'], '_id': 813},
#  {'AllTags': ['<ios><formularios><objective-c>'], '_id': 160},
#  {'AllTags': ['<c#><visual-studio>'], '_id': 1092},
#  {'AllTags': ['<yii>'], '_id': 1365},
#  {'AllTags': ['<java><android><navigationview>',
#               '<java><hibernate>',
#               '<mongodb>',
#               '<java><jersey><swagger>',
#               '<java><android>'],
#   '_id': 608},
#  {'AllTags': ['<linux><vpn>'], '_id': 1303},
#  {'AllTags': ['<python><python-2.7>', '<python><archivo>'], '_id': 2152},
#  {'AllTags': ['<c#><jquery><asp.net-mvc-5><asp.net>'], '_id': 2247},
#  {'AllTags': ['<c#><.net>'], '_id': 2488},
#  {'AllTags': ['<directorioactivo><office365><smartcard><adfs>'], '_id': 717},
#  {'AllTags': ['<clojure>'], '_id': 252},
#  {'AllTags': ['<perl><booleano><conversión-de-tipos>',
#               '<pouchdb>',
#               '<javascript><sandbox><seguridad>',
#               '<javascript><jquery><eventos>',
#               '<array><perl>',
#               '<javascript><nodejs>',
#               '<go>',
#               '<go><tipos>',
#               '<git>'],
#   '_id': 22},
#  {'AllTags': ['<android><php><json><mysql>'], '_id': 2539},
#  {'AllTags': ['<c++>'], '_id': 1997},
#  {'AllTags': ['<programación-funcional><haskell><estructuras-de-datos>',
#               '<archivo><fish><exists>',
#               '<python><python-3.x>',
#               '<pharo><smalltalk>'],
#   '_id': 302},
#  {'AllTags': ['<sql><sql-server>'], '_id': 77},
#  {'AllTags': ['<python>'], '_id': 1575},
#  {'AllTags': ['<php><ajax><laravel><laravel-5>'], '_id': 73},
#  {'AllTags': ['<java><android><bitmap>'], '_id': 846},
#  {'AllTags': ['<sequelize.js><pruebas-unitarias>'], '_id': 345},
#  {'AllTags': ['<mongodb><nosql>'], '_id': 1725},
#  {'AllTags': ['<android><cordova><ionic>',
#               '<nginx><logrotate><configuración>',
#               '<python><python-3.x><pdf><reportlab>',
#               '<python><python-3.x><datetime>',
#               '<javascript><jquery><asincronismo>',
#               '<haskell>',
#               '<haskell><lista>',
#               '<python><python-2.7>',
#               '<javascript><array>',
#               '<python><django><python-3.x><celery>',
#               '<mercurial><control-de-versiones>',
#               '<python><excepciones>',
#               '<python>',
#               '<python><django>',
#               '<python><linux><pip><ubuntu><python-2.7>',
#               '<validación><formularios><html5>',
#               '<python><python-2.7><funciones>',
#               '<python><archivo>',
#               '<python><python-2.7><clase><método>',
#               '<mysql><python><base-de-datos>',
#               '<bash><linux>'],
#   '_id': 100},
#  {'AllTags': ['<swift>'], '_id': 1881},
#  {'AllTags': ['<genexus>'], '_id': 2335},
#  {'AllTags': ['<git><git-commit>'], '_id': 299},
#  {'AllTags': ['<java><io>'], '_id': 2399},
#  {'AllTags': ['<python><string><ordenamiento>'], '_id': 2235},
#  {'AllTags': ['<r><rodbc>'], '_id': 1543},
#  {'AllTags': ['<python><pip><pillow>'], '_id': 783},
#  {'AllTags': ['<c++><c++11>', '<c++>', '<c++><qt>', '<c#><.net>'], '_id': 463},
#  {'AllTags': ['<ios><objective-c>'], '_id': 403},
#  {'AllTags': ['<genexus><devices>'], '_id': 722},
#  {'AllTags': ['<javascript>'], '_id': 872},
#  {'AllTags': ['<jquery><html><youtube>'], '_id': 238},
#  {'AllTags': ['<sql><oracle>', '<jvm><java>'], '_id': 264},
#  {'AllTags': ['<bash><verilog>', '<python><punteros>', '<python><imagen>'],
#   '_id': 389},
#  {'AllTags': ['<java><spring><spring-mvc><spring-security>'], '_id': 2288},
#  {'AllTags': ['<python><python-2.7>'], '_id': 2338},
#  {'AllTags': ['<javascript>'], '_id': 1547},
#  {'AllTags': ['<java><android>', '<java><android><json>'], '_id': 1958},
#  {'AllTags': ['<python>'], '_id': 2234},
#  {'AllTags': ['<javascript><jquery><asp.net-mvc-5>',
#               '<javascript><jquery><html>'],
#   '_id': 2366},
#  {'AllTags': ['<javascript><angularjs>'], '_id': 2509},
#  {'AllTags': ['<javascript><datetime><momentjs><firebase>',
#               '<javascript><momentjs><underscorejs>',
#               '<javascript><underscorejs>'],
#   '_id': 636}]

# %% [markdown]
# ### Ejemplo 2: Asociación Tags con usuarios
#
# Ahora, dado un ID de tag, qué usuarios han hecho preguntas de ese tag.
#
# *De nuevo limitamos la búsqueda a 500 documentos*.

# %%
tags_users: CommandCursor[dict[str, Any]] = db.posts.aggregate( [
        { "$match" : {"PostTypeId": 1}},

        {"$limit": 500},

        { '$lookup': {
            'from': "users",
            'localField': "OwnerUserId",
            'foreignField': "Id",
            'as': "owner"
          }
        },

        {'$project':{
            'Tags': True,
            'userid' : {'$arrayElemAt' : ['$owner.Id', 0]},
        }},

        {'$group':{
            '_id':'$Tags',
            'AllUsers': { '$addToSet': "$userid" }
        }}
    ])

tags_users_lst = list(tags_users)
pp(tags_users_lst)
# Out:
# [{'AllUsers': [100], '_id': '<haskell>'},
#  {'AllUsers': [75], '_id': '<git><control-de-versiones>'},
#  {'AllUsers': [22], '_id': '<array><perl>'},
#  {'AllUsers': [965], '_id': '<javascript><clausuras>'},
#  {'AllUsers': [92], '_id': '<c#><reflexión>'},
#  {'AllUsers': [342], '_id': '<jboss><seam><jboss-eap>'},
#  {'AllUsers': [531, 2238, 1577, 1840], '_id': '<c#><windows-forms>'},
#  {'AllUsers': [1575, 2234, 100], '_id': '<python>'},
#  {'AllUsers': [2027], '_id': '<javascript><jquery><jquery-datepicker>'},
#  {'AllUsers': [1809], '_id': '<java><apache-poi>'},
#  {'AllUsers': [1399], '_id': '<asp.net><visual-studio-2010>'},
#  {'AllUsers': [1555], '_id': '<java><oracle><base64>'},
#  {'AllUsers': [2019], '_id': '<java><postgresql>'},
#  {'AllUsers': [2262], '_id': '<php><sql><mysql><phpmyadmin><mysqli>'},
#  {'AllUsers': [250], '_id': '<javascript><jquery><html><html5>'},
#  {'AllUsers': [160], '_id': '<ios><formularios><objective-c>'},
#  {'AllUsers': [1958], '_id': '<java><android><json>'},
#  {'AllUsers': [517], '_id': '<java><string><comparaciones>'},
#  {'AllUsers': [2036], '_id': '<c#><asp.net-mvc-5>'},
#  {'AllUsers': [100], '_id': '<haskell><lista>'},
#  {'AllUsers': [398], '_id': '<visual-studio><azure><visual-studio-2015>'},
#  {'AllUsers': [1545], '_id': '<php><laravel-5>'},
#  {'AllUsers': [23], '_id': '<javascript><jasmine><momentjs>'},
#  {'AllUsers': [92], '_id': '<wpf><xaml>'},
#  {'AllUsers': [25], '_id': '<c++><array>'},
#  {'AllUsers': [608], '_id': '<java><jersey><swagger>'},
#  {'AllUsers': [342], '_id': '<unity3d>'},
#  {'AllUsers': [261], '_id': '<java><try-catch>'},
#  {'AllUsers': [345], '_id': '<sequelize.js><pruebas-unitarias>'},
#  {'AllUsers': [2208], '_id': '<seo>'},
#  {'AllUsers': [21], '_id': '<mysql><datetime><timestamp>'},
#  {'AllUsers': [608], '_id': '<java><android><navigationview>'},
#  {'AllUsers': [342], '_id': '<java><dukescript><admob>'},
#  {'AllUsers': [729, 1788], '_id': '<javascript><html>'},
#  {'AllUsers': [301], '_id': '<c++><java><rendimiento><optimización>'},
#  {'AllUsers': [292], '_id': '<ide><sublimetext><sublimetext3>'},
#  {'AllUsers': [1941], '_id': '<c#><ofuscación>'},
#  {'AllUsers': [908], '_id': '<python><web2py>'},
#  {'AllUsers': [1184], '_id': '<mysql><windows><delphi>'},
#  {'AllUsers': [2399], '_id': '<java><io>'},
#  {'AllUsers': [400], '_id': '<java><alfresco>'},
#  {'AllUsers': [729], '_id': '<javascript><php><regex>'},
#  {'AllUsers': [342], '_id': '<oracle><oracle-11g><sqlfiddle>'},
#  {'AllUsers': [], '_id': '<java><spring><spring-mvc>'},
#  {'AllUsers': [555], '_id': '<git><git-merge>'},
#  {'AllUsers': [1513, 1527], '_id': '<ios><swift><swift2>'},
#  {'AllUsers': [65],
#   '_id': '<javascript><google-apps-script><google-hoja-de-cálculo><google-forms>'},
#  {'AllUsers': [1184],
#   '_id': '<google-hoja-de-cálculo><formulas><formato-condicional>'},
#  {'AllUsers': [2366, 517], '_id': '<javascript><jquery><html>'},
#  {'AllUsers': [636], '_id': '<javascript><datetime><momentjs><firebase>'},
#  {'AllUsers': [92], '_id': '<c#><wpf><xaml>'},
#  {'AllUsers': [632], '_id': '<raku>'},
#  {'AllUsers': [264, 1184], '_id': '<sql><oracle>'},
#  {'AllUsers': [233], '_id': '<ios>'},
#  {'AllUsers': [870], '_id': '<hilos>'},
#  {'AllUsers': [517], '_id': '<java><string><java-8><java-stream>'},
#  {'AllUsers': [1972], '_id': '<java><hibernate><sqlite3><sqlite>'},
#  {'AllUsers': [400], '_id': '<javascript><jquery><thymeleaf>'},
#  {'AllUsers': [921], '_id': '<.net><entity-framework>'},
#  {'AllUsers': [342], '_id': '<java><dukescript>'},
#  {'AllUsers': [206], '_id': '<java><android><optimización><android-sqlite>'},
#  {'AllUsers': [2136], '_id': '<angularjs><json><http><post>'},
#  {'AllUsers': [342], '_id': '<html>'},
#  {'AllUsers': [1914], '_id': '<php><sql-server>'},
#  {'AllUsers': [1913], '_id': '<json><swift2>'},
#  {'AllUsers': [288], '_id': '<perl><matrices-asociativas><ordenamiento>'},
#  {'AllUsers': [271], '_id': '<linux><debian><ntfs>'},
#  {'AllUsers': [1005], '_id': '<python><djangorestframework><django-models>'},
#  {'AllUsers': [24], '_id': '<c++><string>'},
#  {'AllUsers': [100], '_id': '<android><cordova><ionic>'},
#  {'AllUsers': [23], '_id': '<.net><asp.net-web-api><asp.net>'},
#  {'AllUsers': [353], '_id': '<python><conda>'},
#  {'AllUsers': [1943, 2034, 1958, 1914, 1870, 608], '_id': '<java><android>'},
#  {'AllUsers': [187], '_id': '<c><hilos>'},
#  {'AllUsers': [729], '_id': '<javascript><google-maps>'},
#  {'AllUsers': [631], '_id': '<ruby-on-rails><rspec>'},
#  {'AllUsers': [2366], '_id': '<javascript><jquery><asp.net-mvc-5>'},
#  {'AllUsers': [167], '_id': '<java><java-ee><ide>'},
#  {'AllUsers': [965], '_id': '<ios><objective-c><uiwebview><ios8>'},
#  {'AllUsers': [100], '_id': '<mercurial><control-de-versiones>'},
#  {'AllUsers': [37], '_id': '<lista><elixir>'},
#  {'AllUsers': [1543], '_id': '<r><rodbc>'},
#  {'AllUsers': [1037], '_id': '<javascript><html><vistas><backbone>'},
#  {'AllUsers': [90, 660], '_id': '<mysql><sql>'},
#  {'AllUsers': [1592], '_id': '<java><android><avd>'},
#  {'AllUsers': [24], '_id': '<c++><casting>'},
#  {'AllUsers': [430], '_id': '<javascript><ember.js>'},
#  {'AllUsers': [400], '_id': '<java><jpa>'},
#  {'AllUsers': [2256], '_id': '<json><asp.net-web-api>'},
#  {'AllUsers': [348], '_id': '<azure>'},
#  {'AllUsers': [1527], '_id': '<ios><xcode><swift><ios8>'},
#  {'AllUsers': [2256], '_id': '<sql><sql-server><tsql>'},
#  {'AllUsers': [729, 100, 517], '_id': '<javascript><array>'},
#  {'AllUsers': [100, 2338, 2152, 870], '_id': '<python><python-2.7>'},
#  {'AllUsers': [463], '_id': '<c++><qt>'},
#  {'AllUsers': [531], '_id': '<c#><sql-server><windows-forms>'},
#  {'AllUsers': [2367], '_id': '<javascript><jquery><html5>'},
#  {'AllUsers': [1870], '_id': '<java><android><android-layout>'},
#  {'AllUsers': [2357], '_id': '<java><jsf><java-ee>'},
#  {'AllUsers': [305], '_id': '<android><android-layout><unidades-de-medición>'},
#  {'AllUsers': [1499], '_id': '<ios><xcode><objective-c>'},
#  {'AllUsers': [1173], '_id': '<javascript><html5><indexeddb>'},
#  {'AllUsers': [2247], '_id': '<c#><jquery><asp.net-mvc-5><asp.net>'},
#  {'AllUsers': [292, 302], '_id': '<python><python-3.x>'},
#  {'AllUsers': [342], '_id': '<java><archivo-de-propiedades><i18n>'},
#  {'AllUsers': [2224], '_id': '<html><formularios>'},
#  {'AllUsers': [517], '_id': '<java><string><regex>'},
#  {'AllUsers': [1203], '_id': '<sql-server><asp.net-mvc-5>'},
#  {'AllUsers': [2335, 728, 676, 725], '_id': '<genexus>'},
#  {'AllUsers': [271], '_id': '<latex>'},
#  {'AllUsers': [1482], '_id': '<c#><.net><asp.net><azure><azure-storage>'},
#  {'AllUsers': [100], '_id': '<mysql><python><base-de-datos>'},
#  {'AllUsers': [2027], '_id': '<java><conversión-de-tipos><tipos>'},
#  {'AllUsers': [2379], '_id': '<java><android><linux><windows>'},
#  {'AllUsers': [1007], '_id': '<mysql><phpmyadmin>'},
#  {'AllUsers': [342], '_id': '<git><git-commit><github><git-push><git-fork>'},
#  {'AllUsers': [187], '_id': '<java><constructor><clase-abstracta><poo>'},
#  {'AllUsers': [301], '_id': '<c++><makefile>'},
#  {'AllUsers': [2540], '_id': '<python><python-2.7><python-3.x>'},
#  {'AllUsers': [301], '_id': '<c++><constructor>'},
#  {'AllUsers': [517], '_id': '<java><bigdecimal><redondeo><double>'},
#  {'AllUsers': [65], '_id': '<javascript><bookmarklet><gmail>'},
#  {'AllUsers': [78], '_id': '<c#><sharepoint><sharepoint-online>'},
#  {'AllUsers': [731, 342, 1839], '_id': '<javascript><jquery><json>'},
#  {'AllUsers': [225], '_id': '<html5><css><bootstrap><css3>'},
#  {'AllUsers': [100], '_id': '<python><python-3.x><datetime>'},
#  {'AllUsers': [2013], '_id': '<linux><grep>'},
#  {'AllUsers': [2004], '_id': '<python><matemáticas>'},
#  {'AllUsers': [342], '_id': '<javascript><html><json><knockoutjs>'},
#  {'AllUsers': [872,
#                366,
#                2004,
#                2113,
#                1839,
#                729,
#                342,
#                25,
#                1547,
#                399,
#                2346,
#                2352,
#                430],
#   '_id': '<javascript>'},
#  {'AllUsers': [517],
#   '_id': '<algoritmos><lenguaje-agnóstico><loops><condiciones>'},
#  {'AllUsers': [187], '_id': '<mysql><java><spring><hibernate>'},
#  {'AllUsers': [360], '_id': '<laravel><laravel-5>'},
#  {'AllUsers': [100], '_id': '<validación><formularios><html5>'},
#  {'AllUsers': [35], '_id': '<javascript><knockoutjs>'},
#  {'AllUsers': [2163], '_id': '<java><android><admob>'},
#  {'AllUsers': [225, 1168], '_id': '<c#><asp.net-mvc-5><razor>'},
#  {'AllUsers': [342], '_id': '<oracle><oracle-11g>'},
#  {'AllUsers': [270], '_id': '<ios><objective-c><swift>'},
#  {'AllUsers': [389], '_id': '<bash><verilog>'},
#  {'AllUsers': [], '_id': '<java><java-ee><servlets>'},
#  {'AllUsers': [264], '_id': '<jvm><java>'},
#  {'AllUsers': [631], '_id': '<ubuntu><nodejs><ec2><npm>'},
#  {'AllUsers': [],
#   '_id': '<paso-por-valor><paso-por-referencia><lenguaje-agnóstico>'},
#  {'AllUsers': [1184], '_id': '<archivo><windows><consola><proceso>'},
#  {'AllUsers': [555], '_id': '<git><git-push>'},
#  {'AllUsers': [239], '_id': '<ios><jquery><cordova>'},
#  {'AllUsers': [400], '_id': '<javascript><java><jquery>'},
#  {'AllUsers': [417], '_id': '<java><soap><struts>'},
#  {'AllUsers': [636], '_id': '<javascript><momentjs><underscorejs>'},
#  {'AllUsers': [24], '_id': '<c++><string><tokens>'},
#  {'AllUsers': [2295], '_id': '<html><html5><css><css3>'},
#  {'AllUsers': [305], '_id': '<android><android-softkeyboard>'},
#  {'AllUsers': [729], '_id': '<php><joomla3>'},
#  {'AllUsers': [75], '_id': '<reactjs>'},
#  {'AllUsers': [1948], '_id': '<jsf><primefaces>'},
#  {'AllUsers': [83], '_id': '<bash><linux><shell><sed><awk>'},
#  {'AllUsers': [77], '_id': '<sql><sql-server>'},
#  {'AllUsers': [2392, 729], '_id': '<php>'},
#  {'AllUsers': [533], '_id': '<plugin><wordpress>'},
#  {'AllUsers': [217], '_id': '<poo><funciones><estándares>'},
#  {'AllUsers': [211], '_id': '<json><visual-studio><asp.net-core>'},
#  {'AllUsers': [29], '_id': '<api><ruby><http><post>'},
#  {'AllUsers': [1274], '_id': '<python><django><python-2.7>'},
#  {'AllUsers': [1687], '_id': '<java><firebird>'},
#  {'AllUsers': [225], '_id': '<c#><asp.net-mvc-5><razor><asp.net-mvc>'},
#  {'AllUsers': [342], '_id': '<css><jsfiddle><scss>'},
#  {'AllUsers': [1943], '_id': '<tcpip><tcp>'},
#  {'AllUsers': [1499, 403], '_id': '<ios><objective-c>'},
#  {'AllUsers': [302], '_id': '<archivo><fish><exists>'},
#  {'AllUsers': [389], '_id': '<python><punteros>'},
#  {'AllUsers': [2230], '_id': '<c#><uwp>'},
#  {'AllUsers': [149, 22], '_id': '<javascript><nodejs>'},
#  {'AllUsers': [1527], '_id': '<ios><xcode><swift><swift2>'},
#  {'AllUsers': [2387], '_id': '<eclipse><ftp>'},
#  {'AllUsers': [517], '_id': '<javascript><comparaciones>'},
#  {'AllUsers': [2004], '_id': '<javascript><html><google-maps><google-chrome>'},
#  {'AllUsers': [21], '_id': '<delphi>'},
#  {'AllUsers': [629], '_id': '<javascript><jquery><typescript>'},
#  {'AllUsers': [21], '_id': '<mysql><sql><join>'},
#  {'AllUsers': [517], '_id': '<java><loops><operador-incremento>'},
#  {'AllUsers': [1092], '_id': '<c#><visual-studio>'},
#  {'AllUsers': [547], '_id': '<javascript><.net><signalr><real-time>'},
#  {'AllUsers': [749], '_id': '<excel><vba>'},
#  {'AllUsers': [22], '_id': '<go>'},
#  {'AllUsers': [353], '_id': '<conda>'},
#  {'AllUsers': [2041],
#   '_id': '<javascript><android><ajax><cordova><jquery-mobile>'},
#  {'AllUsers': [2059], '_id': '<python><xml>'},
#  {'AllUsers': [2282], '_id': '<swift><swift2>'},
#  {'AllUsers': [1776], '_id': '<xml>'},
#  {'AllUsers': [1005], '_id': '<django><django-models>'},
#  {'AllUsers': [1076], '_id': '<select2><yii><yiibooster><cache>'},
#  {'AllUsers': [187], '_id': '<json><mongodb><nosql>'},
#  {'AllUsers': [1360], '_id': '<javascript><pdf><google-apps-script>'},
#  {'AllUsers': [2327], '_id': '<nodejs><post><permisos>'},
#  {'AllUsers': [2349], '_id': '<ruby-on-rails>'},
#  {'AllUsers': [22], '_id': '<pouchdb>'},
#  {'AllUsers': [400], '_id': '<java><thymeleaf>'},
#  {'AllUsers': [143], '_id': '<java><json><gson>'},
#  {'AllUsers': [342], '_id': '<oracle-10g><hql><jpa><seam>'},
#  {'AllUsers': [729], '_id': '<html><xpath>'},
#  {'AllUsers': [629], '_id': '<c#><jquery><ajax><asp.net-mvc-5><asp.net-mvc>'},
#  {'AllUsers': [271], '_id': '<html><html5>'},
#  {'AllUsers': [2186], '_id': '<api><nosql><couchdb>'},
#  {'AllUsers': [2236], '_id': '<c++><visual-studio-2010>'},
#  {'AllUsers': [2293], '_id': '<java><base-de-datos><archivo-de-propiedades>'},
#  {'AllUsers': [271], '_id': '<python><macos>'},
#  {'AllUsers': [100], '_id': '<python><python-2.7><funciones>'},
#  {'AllUsers': [83], '_id': '<bash><zsh>'},
#  {'AllUsers': [100, 2152], '_id': '<python><archivo>'},
#  {'AllUsers': [100], '_id': '<python><python-2.7><clase><método>'},
#  {'AllUsers': [729], '_id': '<magento2>'},
#  {'AllUsers': [1881], '_id': '<swift>'},
#  {'AllUsers': [729], '_id': '<javascript><ecmascript-2015>'},
#  {'AllUsers': [1499], '_id': '<ios><swift2><xcode>'},
#  {'AllUsers': [132], '_id': '<javascript><array><object>'},
#  {'AllUsers': [2013], '_id': '<git><github><git-push><git-fork>'},
#  {'AllUsers': [1809], '_id': '<java><excel><apache-poi>'},
#  {'AllUsers': [2392], '_id': '<php><sql>'},
#  {'AllUsers': [298],
#   '_id': '<c#><.net><entity-framework><asp.net-core><model-view-controller>'},
#  {'AllUsers': [1005], '_id': '<python><django><django-models><users-roles>'},
#  {'AllUsers': [132], '_id': '<php><timestamp>'},
#  {'AllUsers': [74], '_id': '<python><numpy><array>'},
#  {'AllUsers': [2172], '_id': '<android-studio><ubuntu><java>'},
#  {'AllUsers': [65], '_id': '<css><google-forms>'},
#  {'AllUsers': [629], '_id': '<typescript><aurelia.io><select2>'},
#  {'AllUsers': [127], '_id': '<php><array>'},
#  {'AllUsers': [801], '_id': '<python><matplotlib><pyqt5><embebido>'},
#  {'AllUsers': [701], '_id': '<spring><spring-roo><gvnix>'},
#  {'AllUsers': [371], '_id': '<django><sql><postgresql>'},
#  {'AllUsers': [783], '_id': '<python><pip><pillow>'},
#  {'AllUsers': [23], '_id': '<javascript><angularjs><ajax>'},
#  {'AllUsers': [1399], '_id': '<jquery><vb.net>'},
#  {'AllUsers': [1390], '_id': '<oracle><formularios><oracle-10g>'},
#  {'AllUsers': [100], '_id': '<python><python-3.x><pdf><reportlab>'},
#  {'AllUsers': [722], '_id': '<genexus><devices>'},
#  {'AllUsers': [1527], '_id': '<ios><xcode><swift>'},
#  {'AllUsers': [301], '_id': '<java><localización>'},
#  {'AllUsers': [342], '_id': '<netbeans><maven>'},
#  {'AllUsers': [22], '_id': '<perl><booleano><conversión-de-tipos>'},
#  {'AllUsers': [149], '_id': '<string><c#>'},
#  {'AllUsers': [2256, 1407, 2509, 23, 1505], '_id': '<javascript><angularjs>'},
#  {'AllUsers': [22], '_id': '<go><tipos>'},
#  {'AllUsers': [1827], '_id': '<html5><bootstrap>'},
#  {'AllUsers': [1839], '_id': '<visual-studio><nuget>'},
#  {'AllUsers': [2004, 463, 2488], '_id': '<c#><.net>'},
#  {'AllUsers': [399], '_id': '<mysql><vagrant><puppet>'},
#  {'AllUsers': [342], '_id': '<netbeans>'},
#  {'AllUsers': [1303], '_id': '<linux><vpn>'},
#  {'AllUsers': [389], '_id': '<python><imagen>'},
#  {'AllUsers': [2004], '_id': '<javascript><json><string>'},
#  {'AllUsers': [100, 729], '_id': '<bash><linux>'},
#  {'AllUsers': [302],
#   '_id': '<programación-funcional><haskell><estructuras-de-datos>'},
#  {'AllUsers': [120], '_id': '<javascript><html><xhtml>'},
#  {'AllUsers': [95], '_id': '<android><google-newsstand-producer><rss>'},
#  {'AllUsers': [608], '_id': '<java><hibernate>'},
#  {'AllUsers': [1188], '_id': '<c#><asp.net-web-api><automapper>'},
#  {'AllUsers': [25, 72, 23, 2325], '_id': '<c#>'},
#  {'AllUsers': [288], '_id': '<perl><tipos><booleano>'},
#  {'AllUsers': [2027], '_id': '<c#><conversión-de-tipos><tipos>'},
#  {'AllUsers': [2013], '_id': '<git><github>'},
#  {'AllUsers': [1839], '_id': '<javascript><json><angularjs>'},
#  {'AllUsers': [1839], '_id': '<javascript><json><xml>'},
#  {'AllUsers': [608], '_id': '<mongodb>'},
#  {'AllUsers': [2133, 1725], '_id': '<mongodb><nosql>'},
#  {'AllUsers': [342], '_id': '<oracle><sqlfiddle>'},
#  {'AllUsers': [659], '_id': '<php><poo>'},
#  {'AllUsers': [2288], '_id': '<java><spring><spring-mvc><spring-security>'},
#  {'AllUsers': [24], '_id': '<c++><c>'},
#  {'AllUsers': [187], '_id': '<c><manejo-de-memoria>'},
#  {'AllUsers': [2087], '_id': '<php><laravel>'},
#  {'AllUsers': [260], '_id': '<html><css>'},
#  {'AllUsers': [360], '_id': '<php><doctrine><doctrine2>'},
#  {'AllUsers': [29], '_id': '<ruby-on-rails><ruby><vistas>'},
#  {'AllUsers': [2304], '_id': '<php><codeigniter><codeigniter-3>'},
#  {'AllUsers': [292], '_id': '<meteor><cuenta-usuario>'},
#  {'AllUsers': [2230], '_id': '<xaml><uwp>'},
#  {'AllUsers': [2238], '_id': '<c#><xaml><windows-forms><wpf>'},
#  {'AllUsers': [302], '_id': '<pharo><smalltalk>'},
#  {'AllUsers': [301], '_id': '<java><paso-por-valor><paso-por-referencia>'},
#  {'AllUsers': [325], '_id': '<soap><soapui><wcf><servicio>'},
#  {'AllUsers': [307], '_id': '<dns><iana>'},
#  {'AllUsers': [233, 37], '_id': '<ios><xcode>'},
#  {'AllUsers': [342], '_id': '<css><html5><css3><3d><importación>'},
#  {'AllUsers': [2257, 342], '_id': '<c#><unity3d>'},
#  {'AllUsers': [1184], '_id': '<sql><oracle-11g><sqlfiddle>'},
#  {'AllUsers': [2453], '_id': '<java><primefaces>'},
#  {'AllUsers': [816, 353, 1005, 100], '_id': '<python><django>'},
#  {'AllUsers': [342], '_id': '<java><netbeans><plugin>'},
#  {'AllUsers': [813], '_id': '<vpn><windows>'},
#  {'AllUsers': [1098], '_id': '<abap>'},
#  {'AllUsers': [1270, 1005],
#   '_id': '<python><django><python-3.x><django-models>'},
#  {'AllUsers': [301], '_id': '<java><clase>'},
#  {'AllUsers': [83, 1943, 260, 299], '_id': '<git><git-commit>'},
#  {'AllUsers': [22], '_id': '<javascript><jquery><eventos>'},
#  {'AllUsers': [35], '_id': '<javascript><kendoui><knockoutjs>'},
#  {'AllUsers': [271], '_id': '<r><ggplot2>'},
#  {'AllUsers': [846], '_id': '<java><android><bitmap>'},
#  {'AllUsers': [1798, 22, 1914, 729, 25, 417, 399, 555, 2027], '_id': '<git>'},
#  {'AllUsers': [400, 100], '_id': '<javascript><jquery><asincronismo>'},
#  {'AllUsers': [35], '_id': '<asp.net><asp.net-mvc><librería><bower>'},
#  {'AllUsers': [729], '_id': '<javascript><html><css>'},
#  {'AllUsers': [132], '_id': '<javascript><jquery><dom>'},
#  {'AllUsers': [2235], '_id': '<python><string><ordenamiento>'},
#  {'AllUsers': [1119], '_id': '<windows>'},
#  {'AllUsers': [342], '_id': '<css>'},
#  {'AllUsers': [127], '_id': '<xml><codificación><utf-8>'},
#  {'AllUsers': [1623], '_id': '<wolfram-mathematica>'},
#  {'AllUsers': [1507], '_id': '<php><optimización><poo>'},
#  {'AllUsers': [218], '_id': '<python><variables>'},
#  {'AllUsers': [546], '_id': '<android><android-auto>'},
#  {'AllUsers': [1055], '_id': '<php><yii2><i18n>'},
#  {'AllUsers': [1365], '_id': '<yii>'},
#  {'AllUsers': [252], '_id': '<clojure>'},
#  {'AllUsers': [1168], '_id': '<vb.net><windows-forms>'},
#  {'AllUsers': [2013], '_id': '<linux><c>'},
#  {'AllUsers': [24, 25, 463], '_id': '<c++><c++11>'},
#  {'AllUsers': [1905], '_id': '<ssms>'},
#  {'AllUsers': [729], '_id': '<php><yii2>'},
#  {'AllUsers': [2222, 1965], '_id': '<bash><shell>'},
#  {'AllUsers': [1746], '_id': '<php><mysql><mysqli>'},
#  {'AllUsers': [2531], '_id': '<vb.net>'},
#  {'AllUsers': [20], '_id': '<typescript>'},
#  {'AllUsers': [1859], '_id': '<tsql>'},
#  {'AllUsers': [65],
#   '_id': '<javascript><google-apps-script><google-hoja-de-cálculo><google-forms><google-documentos>'},
#  {'AllUsers': [22], '_id': '<javascript><sandbox><seguridad>'},
#  {'AllUsers': [74], '_id': '<python><yield>'},
#  {'AllUsers': [217], '_id': '<string><php><str-replace>'},
#  {'AllUsers': [2004], '_id': '<oauth>'},
#  {'AllUsers': [100], '_id': '<python><linux><pip><ubuntu><python-2.7>'},
#  {'AllUsers': [100], '_id': '<python><excepciones>'},
#  {'AllUsers': [65],
#   '_id': '<javascript><google-apps-script><google-hoja-de-cálculo>'},
#  {'AllUsers': [187], '_id': '<javascript><nodejs><depuración>'},
#  {'AllUsers': [238], '_id': '<jquery><html><youtube>'},
#  {'AllUsers': [398], '_id': '<git><visual-studio><nodejs><azure>'},
#  {'AllUsers': [100], '_id': '<nginx><logrotate><configuración>'},
#  {'AllUsers': [1505], '_id': '<javascript><jquery><angularjs>'},
#  {'AllUsers': [745], '_id': '<.net><regex><vb.net>'},
#  {'AllUsers': [120], '_id': '<sql><ms-access-2010>'},
#  {'AllUsers': [21], '_id': '<sql><oracle><oracle-10g>'},
#  {'AllUsers': [1997, 24, 301, 463], '_id': '<c++>'},
#  {'AllUsers': [729, 1839, 2224, 21, 2156, 2238], '_id': '<javascript><jquery>'},
#  {'AllUsers': [73], '_id': '<php><ajax><laravel><laravel-5>'},
#  {'AllUsers': [632], '_id': '<archivo><linux><rsync>'},
#  {'AllUsers': [1965], '_id': '<python><python-2.7><lista>'},
#  {'AllUsers': [83], '_id': '<archivo><unix><grep><ascii>'},
#  {'AllUsers': [301], '_id': '<java><c++><punteros>'},
#  {'AllUsers': [2004], '_id': '<spring><hibernate><jpa><spring-mvc>'},
#  {'AllUsers': [301, 1943, 517, 260, 342], '_id': '<java>'},
#  {'AllUsers': [2257], '_id': '<c#><motor-de-juego><unity3d><2d>'},
#  {'AllUsers': [], '_id': '<.net><clickonce><deployment>'},
#  {'AllUsers': [1947], '_id': '<javascript><jquery><api><google-drive>'},
#  {'AllUsers': [1996], '_id': '<angularjs>'},
#  {'AllUsers': [342], '_id': '<java><sql><oracle><jdbc>'},
#  {'AllUsers': [206],
#   '_id': '<java><android><android-intent><android-asynctask>'},
#  {'AllUsers': [2137, 1513], '_id': '<swift2>'},
#  {'AllUsers': [636], '_id': '<javascript><underscorejs>'},
#  {'AllUsers': [416], '_id': '<matemáticas><coma-flotante><lenguaje-agnóstico>'},
#  {'AllUsers': [901], '_id': '<django><api><djangorestframework><permisos>'},
#  {'AllUsers': [1583], '_id': '<javascript><facebook><internet-explorer-11>'},
#  {'AllUsers': [729], '_id': '<javascript><poo>'},
#  {'AllUsers': [1784], '_id': '<ios><swift2>'},
#  {'AllUsers': [1184], '_id': '<sql><oracle><oracle-11g>'},
#  {'AllUsers': [547], '_id': '<javascript><jquery><datatables>'},
#  {'AllUsers': [717], '_id': '<directorioactivo><office365><smartcard><adfs>'},
#  {'AllUsers': [342], '_id': '<java><eclipse><depuración><jboss>'},
#  {'AllUsers': [2394], '_id': '<jquery><django><django-models><ajax>'},
#  {'AllUsers': [2539], '_id': '<android><php><json><mysql>'},
#  {'AllUsers': [21], '_id': '<android><arduino><socket><delphi><tcpip>'},
#  {'AllUsers': [23], '_id': '<google-maps><angularjs><jasmine><karma-jasmine>'},
#  {'AllUsers': [1527], '_id': '<ios><swift><xcode><iphone>'},
#  {'AllUsers': [27], '_id': '<javascript><android><reactjs><react-native>'},
#  {'AllUsers': [1389], '_id': '<html5><css3><bootstrap><wordpress>'},
#  {'AllUsers': [100], '_id': '<python><django><python-3.x><celery>'},
#  {'AllUsers': [1943], '_id': '<java><hilos><multitasking>'},
#  {'AllUsers': [83], '_id': '<bash><archivo>'},
#  {'AllUsers': [25], '_id': '<licencias><código-abierto>'},
#  {'AllUsers': [127], '_id': '<javascript><validación><email><regex>'},
#  {'AllUsers': [535], '_id': '<python><django><ordenamiento>'}]

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# ### Ejercicio 1: Encontrar las diez primeras preguntas realizadas y mostrar las respuestas aceptadas para las mismas. Mostrar el título de la pregunta y la respuesta dada.

# %%
pipeline = [
    {"$match": {"PostTypeId": 1, "AcceptedAnswerId": {"$exists": True}}},   # seleccionar preguntas

    {"$limit": 10},                  # diez primeras

    {
        "$lookup": {
            "from": "posts",
            "localField": "AcceptedAnswerId",
            "foreignField": "Id",
            "as": "answer"
        }
    },

    {
        "$project": {
            "_id": 0,
            "answer": {"$arrayElemAt": ["$answer.Body", 0]},
            "question": "$Body"
        }
    }
]

results = list(db.posts.aggregate(pipeline))

for r in results:
    print("Respuesta:", r["question"])
    print("Pregunta:", r["answer"])
    print("-"*50)
# Out:
# Respuesta: <p>Estoy creando un servicio usando <em>ASP.NET WebApi</em>. Quiero añadir soporte para la negociación del tipo de contenido basado en extensiones en el <em>URI</em>, así que he añadido lo siguiente al código de inicialización del servicio:</p><br/><br/><pre><code>public static class WebApiConfig<br/>{<br/>  public static void Register(HttpConfiguration config)<br/>  {<br/>    config.Formatters.JsonFormatter.AddUriPathExtensionMapping("json", "application/json");<br/>    config.Formatters.XmlFormatter.AddUriPathExtensionMapping("xml", "application/xml");<br/>  }<br/>}<br/></code></pre><br/><br/><p>Para que esto funcione necesito crear dos rutas para cada acción del controlador (estoy usando exclusivamente enrutamiento basado en atributos):</p><br/><br/><pre><code>[Route("item/{id}/details")]<br/>[Route("item/{id}/details.{ext}")]<br/>[HttpGet]<br/>public ItemDetail[] GetItemDetails(int id)<br/>{<br/>  return itemsService.GetItemDetails(id);<br/>}<br/><br/>[Route("item/{name}")]<br/>[Route("item/{name}.{ext}")]<br/>[HttpPost]<br/>public int CreateItem(string name)<br/>{<br/>  return itemsService.Create(name);<br/>}<br/></code></pre><br/><br/><p>Esto queda feo y hace que el código sea innecesariamente largo, así que investigué una forma de añadir la ruta con la extensión, automáticamente cuando se crea la ruta normal. Como resultado desarrollé una implementación personalizada de <code>IDirectRouteProvider</code> que puedo usar al registrar los atributos de ruta:</p><br/><br/><pre><code>config.MapHttpAttributeRoutes(new AutomaticExtensionRouteProvider());<br/></code></pre><br/><br/><p>El código del proveedor personalizado es:</p><br/><br/><pre><code>public class AutomaticExtensionRouteProvider : DefaultDirectRouteProvider<br/>{<br/>    protected override IReadOnlyList&lt;RouteEntry&gt; GetActionDirectRoutes(<br/>      HttpActionDescriptor actionDescriptor,<br/>      IReadOnlyList&lt;IDirectRouteFactory&gt; factories,<br/>      IInlineConstraintResolver constraintResolver)<br/>    {<br/>        var result = base.GetActionDirectRoutes(actionDescriptor, factories, constraintResolver);<br/>        var list = new List&lt;RouteEntry&gt;(result);<br/>        foreach(var route in result.Where(r =&gt; !r.Route.RouteTemplate.EndsWith(".{ext}")))<br/>        {<br/>            var newTemplate = route.Route.RouteTemplate + ".{ext}";<br/>            if (!result.Any(r =&gt; r.Route.RouteTemplate == newTemplate))<br/>            {<br/>                var entry = new RouteEntry(null, new HttpRoute(newTemplate,<br/>                    new HttpRouteValueDictionary(route.Route.Defaults),<br/>                    new HttpRouteValueDictionary(route.Route.Constraints),<br/>                    new HttpRouteValueDictionary(route.Route.DataTokens)));<br/>                list.Add(entry);<br/>            }<br/>        }<br/>        return list.AsReadOnly();<br/>    }<br/>}<br/></code></pre><br/><br/><p>El problema es que esto funciona bien, pero falla en un caso: <strong>Cuando la última parte de la ruta es un parámetro sin restricciones</strong>. Así pues, en el ejemplo anterior, la creación de rutas para <code>GetItemDetails</code> funciona, pero para <code>CreateItem</code> lanza lo siguiente:</p><br/><br/><pre><code>System.InvalidOperationException: Multiple actions were found that match the request: <br/>CreateItem on type FooBar.Api.Controllers.ItemsController<br/>CreateItem on type FooBar.Api.Controllers.ItemsController<br/>   at System.Web.Http.Controllers.ApiControllerActionSelector.ActionSelectorCacheItem.SelectAction(HttpControllerContext controllerContext)<br/>   at System.Web.Http.Controllers.ApiControllerActionSelector.SelectAction(HttpControllerContext controllerContext)<br/></code></pre><br/><br/><p>Me imagino de dónde puede venir el problema: Una cadena arbitraria cumple los patrones <code>{name}</code> y <code>{name}.{ext}</code>, por lo que el motor de <em>WebApi</em> se confunde al intentar seleccionar la ruta adecuada. <strong ...
# Pregunta: <p>He encontrado la solución.</p><br/><br/><p>Resulta que las rutas tienen asignada una <strong>precedencia</strong> numérica asignada, que el motor de enrutamiento de WebApi usa para decidir qué ruta usar en caso de conflicto. Las rutas creadas automáticamente para una misma acción siempre tienen una precedencia distinta, ¡pero la ruta que yo estaba creando manualmente tenía la misma precedencia que la ya existente!</p><br/><br/><p>Así pues la solución es añadir lo siguiente a <code>GetActionDirectRoutes</code>, inmediatamente después de <code>new RouteEntry</code>:</p><br/><br/><pre><code>entry.Route.DataTokens["precedence"] = <br/>    ((decimal)route.Route.DataTokens["precedence"]) - 0.1M;<br/></code></pre><br/>
# --------------------------------------------------
# Respuesta: <p>Luego de ver cierto código, me he dado cuenta que utilizan este estilo:</p><br/><br/><pre><code>aStr:=tblAcct.FieldByName('Name').Text;<br/></code></pre><br/><br/><p>Parece trabajar bien, pero yo había utilizado hasta ahora:</p><br/><br/><pre><code>aStr:=tblAcct.FieldByName('Name').AsString;<br/></code></pre><br/><br/><p>He utilizado ambos al cargar un TMemo y no parece haber diferencia alguna.</p><br/><br/><pre><code>aMemo.Lines.Text:=tblAcct.FieldByName('History').Text;<br/>aMemo.Lines.Text:=tblAcct.FieldByName('History').AsString;<br/></code></pre><br/><br/><p>¿Hay alguna razón por la que deba utilizar una y no la otra? ¿Cuál es esa razón?</p><br/><br/><p>Normalmente, para un memo, utilizo:</p><br/><br/><pre><code>aMemo.Lines.Assign(tblAcct.FieldByName('History'))<br/></code></pre><br/><br/><p>Y esto trabaja bien también.</p><br/>
# Pregunta: <p>Antes de responder directamente la respuesta, hablaremos de las propiedades relevantes de TField y sus descendientes.</p><br/><br/><h1><code>Text</code>/<code>DisplayText</code></h1><br/><br/><p>Ambas propiedades sirven para obtener una representación textual del valor del campo para su uso en la Interfaz de Usuario. <br/>El propósito de la propiedad <code>Text</code> es el de obtener una representación textual del campo cuándo está siendo editado en un control asociado a datos (Data Aware), en contraste con la propiedad <code>DisplayText</code> que proporciona el valor del campo con formato de visualización para el usuario, por ejemplo, puede contener caracteres de puntuación u otra decoración al valor plano. (1234.50 en contraste con 1,234.50).</p><br/><br/><p>En otras palabras, un <code>TdbEdit</code> o controles similares, mostrarán el valor de <code>DisplayText</code> cuándo no están siendo editados, y al recibir el foco, cambiarán el valor al de la propiedad <code>Text</code> y es este valor el que el usuario "edita". Un TdbLabel solamente tira de la propiedad <code>DisplayText</code>, ya que no es editable.</p><br/><br/><p>La documentación para <code>Text</code> dice:</p><br/><br/><blockquote><br/>  <p>Contains the string to display in a data-aware control when the field is in edit mode</p><br/></blockquote><br/><br/><p>Un ejemplo típico es un <code>TFloatField</code> con la propiedad <code>Currency</code> establecida a <code>True</code>. La propiedad DisplayText te devuelve el string con el número conteniendo separadores de miles, el separador decimal y el símbolo de la moneda. La propiedad Text, te devuelve una cadena que no contiene separadores de miles ni símbolo de moneda.</p><br/><br/><pre><code>begin<br/>  MyFloatField.Currency := True;<br/>  MyFloatField.AsFloat := 1234.56;<br/>  A := MyFloatField.Text; //'1234.56'<br/>  B := MyFloatField.DisplayText; //'$1,234.56', depends on your locale<br/>  ShowMessage(A + #13 + B);<br/>end;<br/></code></pre><br/><br/><p>El comportamiento de ambas propiedades puede ser personalizado escribiendo un manejador de eventos para <code>OnGetText</code>, dónde se puede escribir la lógica para convertir el valor del campo en una de ambas representaciones textuales. El parámetro booleano <code>DisplayText</code> indica si la cadena solicitada es para representar el valor en la interfaz de usuario o para edición. </p><br/><br/><p>De esta manera, podemos lograr que la representación en la interfaz de usuario para un campo entero con valor 1 sea 'uno', y su valor para edición sea 'one'</p><br/><br/><h1><code>AsString</code></h1><br/><br/><p>Por otro lado, la propiedad AsString utiliza una conversión plana entre el tipo de dato base del campo y una cadena de caracteres. Cada descendiente de <code>TField</code> implementa el método virtual <code>GetAsString</code> que típicamente utiliza funciones de la RTL para realizar la conversión. Siguiendo con el ejemplo de TFloatField, esta clase llama a la función FloatToStr() para realizar la conversión.</p><br/><br/><h1>La respuesta</h1><br/><br/><p>Dicho todo esto, la respuesta a la pregunta sería:</p><br/><br/><p>AsString retorna usualmente el mismo valor que retorna la propiedad Text, siempre que no haya un manejador de evento para OnGetText, pero la representación podría ser diferente si hubiese un manejador de evento o un descendiente no estándar de TField.</p><br/><br/><p>Con la información dada, no puede decirse cuál es más apropiado, ya que esto depende de cuál es el uso que se le dará al valor retornado. Si se está utilizando para mostrar valores en la Interfaz de usuario, como se muestra en los ejemplos de código proporcionados, mi consejo es que utilices la propiedad <code>DisplayText</code>.</p><br/>
# --------------------------------------------------
# Respuesta: <p>¿Cuál es la forma más eficiente de separar un string en <code>c++</code>? como el que se muestra en el código, el cual contiene espacios entre las palabras, este es el método que yo estoy usando actualmente.</p><br/><br/><pre><code>#include &lt;iostream&gt;<br/>#include &lt;sstream&gt;<br/><br/>int main(int argc, char** argv){<br/><br/>    std::string str("Texto para dividir");<br/>    std::istringstream isstream(str);<br/><br/>    while(!isstream.eof()){<br/><br/>        std::string tempStr;<br/><br/>        isstream &gt;&gt; tempStr;<br/><br/>        std::cout &lt;&lt; tempStr &lt;&lt; std::endl;<br/>    }<br/><br/>    return 0;<br/>}<br/></code></pre><br/>
# Pregunta: <p>Normalmente lo eficiente y lo bonito no suelen ir dados de la mano. El código bonito suele tener código excesivo (al menos 'por detrás'), pero en ese caso lo que prima es la legibilidad del código... cuando se persigue la eficiencia lo que se acaba consiguiendo es código menos legible... pero más eficiente (en esto habría que especificiar si la eficiencia se refiere a velocidad de ejecución o a consumo de memoria).</p><br/><br/><p>Bueno, ya te han puesto códigos bonitos yo te pongo uno que tira por la vía de la rapidez. ¿Cómo de rápido? pues más o menos un 30%-40% más rápido que la opción del <code>istringstream</code>........ claro que el código ya no queda tan bonito:</p><br/><br/><pre><code>std::vector&lt;std::string&gt;<br/>split_iterator(const std::string&amp; str)<br/>{<br/>  std::vector&lt;std::string&gt; resultado;<br/><br/>  std::string::const_iterator itBegin = str.begin();<br/>  std::string::const_iterator itEnd   = str.end();<br/><br/>  int numItems = 1;<br/>  for( std::string::const_iterator it = itBegin; it!=itEnd; ++it )<br/>    numItems += *it==' ';<br/><br/>  resultado.reserve(numItems);<br/><br/>  for( std::string::const_iterator it = itBegin; it!=itEnd; ++it )<br/>  {<br/>    if( *it == ' ' )<br/>    {<br/>      resultado.push_back(std::string(itBegin,it));<br/>      itBegin = it+1;<br/>    }<br/>  }<br/><br/>  if( itBegin != itEnd )<br/>    resultado.push_back(std::string(itBegin,itEnd));<br/><br/>  return resultado;<br/>}<br/></code></pre><br/><br/><p>En este caso uso iteradores, lo que evita el sobrecoste de crear y llamar a los métodos <code>istringstream</code>. Además como optimización adicional, antes de separar el <code>string</code> precalculo el número total de elementos. De esta forma evito que el vector tenga que llamar a <code>realloc</code> continuamente.</p><br/><br/><p>Un saludo</p><br/>
# --------------------------------------------------
# Respuesta: <p>¿Cómo estar seguro o qué pautas seguir a la hora de usar los moldes explícitos  en <code>C++</code>?</p><br/><br/><p>Por lo que entiendo al usar los <code>moldes</code> le estamos pidiendo al compilador que pase de la comprobación de tipos, y eso no creo que sea muy bueno si uno no sabe exactamente qué molde usar. Por eso quería saber qué guías usan o cosas a tener en cuenta para decidirse por un tipo de molde u otro a la hora de modelar los datos, para determinadas situaciones, y así saber cuándo es seguro usar uno u otro.</p><br/><br/><ol><br/><li><code>const_cast</code></li><br/><li><code>static_cast</code></li><br/><li><code>dynamic_cast</code></li><br/><li><code>reinterpret_cast</code></li><br/></ol><br/>
# Pregunta: <p><strong><code>static_cast</code></strong></p><br/><br/><p>es la conversión utilizada por defecto. En este tipo de conversión se comprueba, en tiempo de compilación, que los tipos origen y destino son compatibles, de ahí lo de <em>static</em>. Quizás, las dos principales ventajas de este tipo de conversión son:</p><br/><br/><ul><br/><li>La conversión es tan rápida como su homóloga de C</li><br/><li>La conversión únicamente es posible entre tipos compatibles</li><br/></ul><br/><br/><p>Al usar <code>static_cast</code> nos podemos encontrar con dos inconvenientes:</p><br/><br/><ul><br/><li><p>Como no realiza chequeos de herencia, podemos acabar teniendo punteros no válidos.</p><br/><br/><pre><code>class A<br/>{<br/>  // ...<br/>};<br/><br/>class B : public A<br/>{<br/>  // ...<br/>};<br/><br/>class C : public A<br/>{<br/>  // ...<br/>};<br/><br/>A* ptr = new B;<br/>C* ptr2 = static_cast&lt;C*&gt;(ptr); // Compila pero no es correcto<br/></code></pre></li><br/><li><p>No funciona con herencias virtuales:</p><br/><br/><pre><code>class A<br/>{ };<br/><br/>class B : public virtual A<br/>{ };<br/><br/>A* ptrA = new B;<br/>B* ptrB = static_cast&lt;B*&gt;(ptrA); // Error en compilación<br/></code></pre></li><br/></ul><br/><br/><p><strong><code>dynamic_cast</code></strong></p><br/><br/><p>Esta conversión sirve precisamente para solucionar los problemas que hemos comentado de <code>static_cast</code>. Este tipo de conversión nos garantiza que la conversión se realiza sí y sólo sí el objeto es del tipo de destino. Para conseguir este resultado realiza una serie de chequeos internos, por lo que este tipo de conversión es sensiblemente más lenta que <code>static_cast</code>.</p><br/><br/><pre><code>class A<br/>{<br/>  // ...<br/>};<br/><br/>class B : public A<br/>{<br/>  // ...<br/>};<br/><br/>class C : public A<br/>{<br/>  // ...<br/>};<br/><br/>A* ptrA = new B;<br/>C* ptrC = dynamic_cast&lt;C*&gt;(ptrA); // ptrC == nullptr<br/>B* ptrB = dynamic_cast&lt;B*&gt;(ptrA); // ptrB == ptrA<br/><br/>C&amp; refC = dynamic_cast&lt;C&amp;&gt;(*ptrA); // excepción std::bad_cast<br/>B&amp; refB = dynamic_cast&lt;B&amp;&gt;(*ptrA); // OK<br/></code></pre><br/><br/><p>Este tipo de conversión se utiliza básicamente cuando tenemos polimorfismo de por medio. No tiene sentido utilizarla en otros ámbitos. Hay que tener en cuenta que si tenemos herencia múltiple y se producen ambigüedades (se hereda dos veces de la misma clase) podemos tener problemas al utilizar este tipo de conversión.</p><br/><br/><p>También hay que tener en cuenta que <code>dynamic_cast</code> únicamente es capaz de comprobar la herencia "hacia abajo", luego no es capaz de realizar conversiones transversales:</p><br/><br/><pre><code>class A<br/>{<br/>  // ...<br/>};<br/><br/>class B<br/>{<br/>  // ...<br/>};<br/><br/>class C : public A, public B<br/>{<br/>  // ...<br/>};<br/><br/>A* ptrA = new C;<br/>B* ptrB = dynamic_cast&lt;B*&gt;(ptrA); // Error de compilación, aunque C es también de tipo B<br/></code></pre><br/><br/><p><strong><code>const_cast</code></strong></p><br/><br/><p>Es una conversión que permite eliminar el modificador <code>const</code> de una referencia o un puntero. Esta conversión puede sernos de utilidad si necesitamos llamar a métodos <code>no-const</code> de un objeto que nos viene como <code>const</code>. El peligro que se esconde tras este tipo de conversiones es que no está permitido modificar objetos que se han creado como constantes, luego retirar su modificador <code>const</code> puede provocar resultados indeterminados en nuestra aplicación.</p><br/><br/><pre><code>const std::string texto_const = "TEST";<br/><br/>texto_const.at(0) = 't'; // Error de compilación<br/><br/>std::string* ptr_no_const = const_cast&lt;std::string*&gt;(&amp;texto_const);<br/>ptr_no_const-&gt;at(0) = 't'; // resultado indeterminado<br/></code></pre><br/><br/><p><strong><code>reinterpret_cast</code></strong></p><br/><br/><p>Representa el último grupo de conversiones de este capít ...
# --------------------------------------------------
# Respuesta: <p>Para un proyecto web en el que estoy participando usamos el componente <a href="http://angular-ui.github.io/angular-google-maps" rel="noreferrer">Angular Google Maps</a>. Este es el código <code>JavaScript</code> que hace referencia al componente y lo inicializa:</p><br/><br/><pre><code>var configureGoogleMaps = function(uiGmapGoogleMapApiProvider) {<br/>    uiGmapGoogleMapApiProvider.configure({<br/>        libraries: 'geometry,visualization'<br/>    });<br/>}<br/>configureGoogleMaps.$inject = ['uiGmapGoogleMapApiProvider'];<br/><br/>angular<br/>    .module('shTools.Map', ['uiGmapgoogle-maps'])<br/>    .directive('map', mapDirective)<br/>    .config(configureGoogleMaps);<br/></code></pre><br/><br/><p>donde <code>mapDirective</code> define un elemento HTML que contiene el componente de Google Maps.</p><br/><br/><p>Esto está funcionando como se espera. El problema es que cuando ejecuto un simple test usando <code>Jasmine</code> con <code>Karma</code>, obtengo el error <code>Unknown provider: uiGmapGoogleMapApiProvider</code>. Por alguna razón no está siendo capaz de encontrar el proveedor.</p><br/><br/><p>He intentado crear un <code>mock</code> para forzar la creación de un proveedor con ese nombre, pero no ha funcionado:</p><br/><br/><pre><code>angular.module('uiGmapgoogle-maps', [])<br/>    .value('uiGmapGoogleMapApiProvider', {<br/>        configure: function() {}<br/>    });<br/></code></pre><br/><br/><p>¿Qué podría estar pasando aquí?</p><br/>
# Pregunta: <p>Los proveedores de AngularJs de inyectan de forma distinta al resto de servicios por lo que también hay que inyectarlos de forma especial cuando escribes las pruebas con Jasmine. </p><br/><br/><p>La forma de hacerlo consiste en crear un módulo falso en el que se inyecta el proveedor </p><br/><br/><pre><code>beforeEach(function () {   <br/>     // Módulo falso donde se inyecta el proveedor<br/>     angular.module('testApp', function () {})<br/>       .config(['bilingualButtonConfigProvider', function (provider) {<br/>         bilingualButtonConfigProvider = provider;<br/>       }]);<br/>     // Inicializar módulos<br/>     module('myApp', 'testApp');<br/>});<br/></code></pre><br/><br/><p>Puedes ver el ejemplo completo <a href="http://jsfiddle.net/ff7y1xmr/" rel="noreferrer">aquí</a></p><br/><br/><p>También dejo unos enlaces interesantes:</p><br/><br/><ul><br/><li><a href="http://benclinkinbeard.com/posts/creating-configurable-angular-directives-with-providers/" rel="noreferrer">Creating Configurable Angular Directives with Providers</a>: en este artículo se puede aprender un poco más del comportamiento de los proveedores</li><br/><li><a href="http://jsfiddle.net/eitanp461/qTvMz/" rel="noreferrer">Testing  angular providers with Jasmine</a>: Otro ejemplo en JsFiddle de pruebas con proveedores (es en el que me he basado yo)</li><br/></ul><br/><br/><p>Espero que te ayude</p><br/>
# --------------------------------------------------
# Respuesta: <p>Dado el siguiente código en TypeScript</p><br/><br/><pre><code>class Persona {<br/>    constructor(public nombre: string, public apellido: string) {<br/>    }<br/><br/>    nombreCompleto1 = () =&gt; {<br/>        return this.nombre + " " + this.apellido;<br/>    }<br/><br/>    nombreCompleto2() {<br/>        return this.nombre + " " + this.apellido;<br/>    }<br/>}<br/><br/>var p = new Persona("Juan", "Pérez");<br/><br/>console.log(p.nombreCompleto1());<br/>console.log(p.nombreCompleto2());<br/></code></pre><br/><br/><p>Como se puede ver los métodos <code>nombreCompleto1</code> y <code>nombreCompleto2</code> hacen lo mismo pero están declarados ligeramente diferente.</p><br/><br/><p>Al ejecutarlo en los dos casos se obtiene el resultado esperado:</p><br/><br/><pre><br/>Juan Pérez<br/>Juan Pérez<br/></pre><br/><br/><p>¿Cuál es la diferencia entre las dos declaraciones si los dos hacen los mismo y cuál es la forma adecuada de declararlo?</p><br/>
# Pregunta: <p>En el primer caso:</p><br/><br/><pre><code>nombreCompleto1 = () =&gt; {<br/>    return this.nombre + " " + this.apellido;<br/>}<br/></code></pre><br/><br/><p>estás creando un <em>método de instancia</em>, es equivalente a ejecutar <code>this.nombreCompleto1 = function() {...}</code> en JavaScript.</p><br/><br/><p>En el segundo caso:</p><br/><br/><pre><code>nombreCompleto2() {<br/>    return this.nombre + " " + this.apellido;<br/>}<br/></code></pre><br/><br/><p>estás creando un <em>método de prototipo</em>, es equivalente a <code>Persona.prototype.nombreCompleto2 = function() {...}</code> en JavaScript.</p><br/><br/><p>En general es preferible crear métodos de prototipo: en tal caso el método se define una sola vez, mientras que los métodos de instancia se crean una vez por instancia, consumiendo más memoria.</p><br/><br/><p>Más información: <a href="http://www.johnpapa.net/typescriptpost3" rel="noreferrer">TypeScript Classes and Interfaces</a></p><br/>
# --------------------------------------------------
# Respuesta: <p>Hoy, en mi trabajo, escribí algo así, en Perl:</p><br/><br/><pre><code>my @x = qw( 1 2 3 4 5 );<br/>splice(@x, 10);<br/></code></pre><br/><br/><p>y produjo el error:</p><br/><br/><blockquote><br/>  <p>splice() offset past end of array at ./x line X.</p><br/></blockquote><br/><br/><p>Pero en mi laptop personal, no hay ningún error así. Ya sé que <a href="https://stackoverflow.com/a/3346640/13860">es fácil suprimir el mensaje (en Inglés)</a> con <code>no warnings 'misc';</code>, pero mi pregunta es:</p><br/><br/><p>¿Por qué la diferencia entre las versiones de Perl?</p><br/><br/><p>En el trabajo, veo el mensaje con Perl 5.14, y en mi equipo personal no lo veo con Perl 5.20.  ¿Cuando lo cambió, y por qué?</p><br/>
# Pregunta: <p>Como ya mencioné yo no uso Perl, pero mirando la documentación en una parte de ella dice lo siguiente:</p><br/><br/><blockquote><br/>  <p>"Si el desplazamiento es más allá del final de la matriz, Perl emite<br/>  una advertencia, y (Perl) empalma/splice en el extremo de la matriz."</p><br/></blockquote><br/><br/><p><em>...If OFFSET is past the end of the array, Perl issues a warning, and splices at the end of the array.</em></p><br/><br/><p>De echo he revisado en varias versiones y es lo mismo por lo menos la documentación advierten sobre el <em>warning</em>.</p><br/><br/><p>Aquí le dejo los links (en Inglés); </p><br/><br/><ul><br/><li><p><a href="http://perldoc.perl.org/5.16.2/functions/splice.html" rel="noreferrer" title="http://perldoc.perl.org/5.16.2/functions/splice.html">Perl v 5.16.2</a></p></li><br/><li><p><a href="http://perldoc.perl.org/5.20.0/functions/splice.html" rel="noreferrer" title="http://perldoc.perl.org/5.20.0/functions/splice.html">Perl v 5.20.0</a></p></li><br/><li><p><a href="http://perldoc.perl.org/functions/splice.html" rel="noreferrer" title="http://perldoc.perl.org/functions/splice.html">Perl v 5.22</a></p></li><br/></ul><br/><br/><p>Según lo anterior lo normal es el <em>warning</em>, pero por lo que se puede ver en el siguiente link, no en todas las versiones es así y también depende del OS.</p><br/><br/><p><a href="http://www.nntp.perl.org/group/perl.perl5.porters/2013/04/msg201134.html" rel="noreferrer">http://www.nntp.perl.org/group/perl.perl5.porters/2013/04/msg201134.html</a></p><br/><br/><p>Creo que eso ocurre entre la <code>5.14</code> y <code>5.16</code> en algunos sistemas, aquí puede ver la notificación de bug pero quizás también le suceda a usted en la <code>5.20</code> debido a su OS y no es que haya cambiado algo. </p><br/><br/><p><a href="https://rt.perl.org/Public/Bug/Display.html?id=117729" rel="noreferrer">https://rt.perl.org/Public/Bug/Display.html?id=117729</a></p><br/>
# --------------------------------------------------
# Respuesta: <p>Estoy tratando de descargar el simulador de <code>iOS 8.4</code> en <code>Xcode 7</code> y me devuelve este error: </p><br/><br/><blockquote><br/>  <p>Could not download and install ios 8.4. Authorization is required to install the packages.</p><br/></blockquote><br/><br/><p>Antes de eso ingresé mi password de usuario.</p><br/>
# Pregunta: <p>Para realizar esta operación, ejecuta <code>Xcode</code> como <code>root</code> con el comando <a href="https://es.wikipedia.org/wiki/Sudo" rel="nofollow"><code>sudo</code></a> e instala dentro de esa sesión:</p><br/><br/><pre><code>sudo /Applications/Xcode.app/Contents/MacOS/Xcode<br/></code></pre><br/><br/><p>Una vez hayas instalados debes salir e iniciar normalmente.</p><br/><br/><p>Debes tener precaución si tienes proyectos abiertos cuando usas sudo para lanzar Xcode.</p><br/>
# --------------------------------------------------
# Respuesta: <p>Si defino un rango como el siguiente,</p><br/><br/><pre><code>rango = 1..5<br/></code></pre><br/><br/><p>¿Hay una manera de convertirlo a lista?</p><br/>
# Pregunta: <p>Creo que <a href="https://hexdocs.pm/elixir/Enum.html#to_list/1" rel="noreferrer">esto</a> es lo que usted esta buscando</p><br/><br/><p><strong>to_list (colección)</strong></p><br/><br/><p><strong><em>Convierte la colección a una lista</em></strong></p><br/><br/><pre><code>iex&gt; Enum.to_list 1..5<br/>[1, 2, 3, 4, 5]<br/></code></pre><br/><br/><p>espero le ayude</p><br/>
# --------------------------------------------------
# Respuesta: <p>¿Cómo se hace para mostrar una Vista (view) de Rails sin mostrar el layout de la aplicación para un usuario registrado y otro layout para un visitante? ¿Se puede?</p><br/>
# Pregunta: <p>Podes cambiar el layout para un controlador o una acción del controlador, una manera de mostrar una vista con otro layout cuando el usuario no esta registrado seria así:</p><br/><br/><pre><code>class MyController &lt; ApplicationController<br/><br/>  def my_action<br/>    if current_user.nil?<br/>      render layout: "new_user_layout"<br/>    else<br/>      render layout: "member_layout"<br/>    end<br/>  end<br/><br/>end<br/></code></pre><br/><br/><p>Para cambiar el layout de todos los controladores que heredan de ApplicationController seria lo siguiente:</p><br/><br/><pre><code>class ApplicationController &lt; ActionController::Base<br/>  layout :users_layout<br/><br/>  private<br/>    def users_layout<br/>      current_user.nil? ? "new_user_layout" : "member_layout"<br/>    end<br/><br/>end <br/></code></pre><br/><br/><p>En las <a href="http://guides.rubyonrails.org/layouts_and_rendering.html">guias de rails</a> podes encontrar más información sobre layouts.</p><br/>
# --------------------------------------------------

# %% [markdown]
# ### Ejercicio 2: Encontrar las diez primeras repuestas realizadas y mostrar la pregunta correspondiente. Mostrar la respuesta dada y el título de la pregunta.

# %%
pipeline = [
    {"$match": {"PostTypeId": 2}},   # seleccionar respuestas

    {"$limit": 10},                  # diez primeras

    {
        "$lookup": {
            "from": "posts",
            "localField": "ParentId",
            "foreignField": "Id",
            "as": "question"
        }
    },

    {
        "$project": {
            "_id": 0,
            "question": {"$arrayElemAt": ["$question.Body", 0]},
            "answer": "$Body"
        }
    }
]

results = list(db.posts.aggregate(pipeline))

for r in results:
    print("Respuesta:", r["answer"])
    print("Pregunta:", r["question"])
    print("-"*50)
# Out:
# Respuesta: <p>He encontrado la solución.</p><br/><br/><p>Resulta que las rutas tienen asignada una <strong>precedencia</strong> numérica asignada, que el motor de enrutamiento de WebApi usa para decidir qué ruta usar en caso de conflicto. Las rutas creadas automáticamente para una misma acción siempre tienen una precedencia distinta, ¡pero la ruta que yo estaba creando manualmente tenía la misma precedencia que la ya existente!</p><br/><br/><p>Así pues la solución es añadir lo siguiente a <code>GetActionDirectRoutes</code>, inmediatamente después de <code>new RouteEntry</code>:</p><br/><br/><pre><code>entry.Route.DataTokens["precedence"] = <br/>    ((decimal)route.Route.DataTokens["precedence"]) - 0.1M;<br/></code></pre><br/>
# Pregunta: <p>Estoy creando un servicio usando <em>ASP.NET WebApi</em>. Quiero añadir soporte para la negociación del tipo de contenido basado en extensiones en el <em>URI</em>, así que he añadido lo siguiente al código de inicialización del servicio:</p><br/><br/><pre><code>public static class WebApiConfig<br/>{<br/>  public static void Register(HttpConfiguration config)<br/>  {<br/>    config.Formatters.JsonFormatter.AddUriPathExtensionMapping("json", "application/json");<br/>    config.Formatters.XmlFormatter.AddUriPathExtensionMapping("xml", "application/xml");<br/>  }<br/>}<br/></code></pre><br/><br/><p>Para que esto funcione necesito crear dos rutas para cada acción del controlador (estoy usando exclusivamente enrutamiento basado en atributos):</p><br/><br/><pre><code>[Route("item/{id}/details")]<br/>[Route("item/{id}/details.{ext}")]<br/>[HttpGet]<br/>public ItemDetail[] GetItemDetails(int id)<br/>{<br/>  return itemsService.GetItemDetails(id);<br/>}<br/><br/>[Route("item/{name}")]<br/>[Route("item/{name}.{ext}")]<br/>[HttpPost]<br/>public int CreateItem(string name)<br/>{<br/>  return itemsService.Create(name);<br/>}<br/></code></pre><br/><br/><p>Esto queda feo y hace que el código sea innecesariamente largo, así que investigué una forma de añadir la ruta con la extensión, automáticamente cuando se crea la ruta normal. Como resultado desarrollé una implementación personalizada de <code>IDirectRouteProvider</code> que puedo usar al registrar los atributos de ruta:</p><br/><br/><pre><code>config.MapHttpAttributeRoutes(new AutomaticExtensionRouteProvider());<br/></code></pre><br/><br/><p>El código del proveedor personalizado es:</p><br/><br/><pre><code>public class AutomaticExtensionRouteProvider : DefaultDirectRouteProvider<br/>{<br/>    protected override IReadOnlyList&lt;RouteEntry&gt; GetActionDirectRoutes(<br/>      HttpActionDescriptor actionDescriptor,<br/>      IReadOnlyList&lt;IDirectRouteFactory&gt; factories,<br/>      IInlineConstraintResolver constraintResolver)<br/>    {<br/>        var result = base.GetActionDirectRoutes(actionDescriptor, factories, constraintResolver);<br/>        var list = new List&lt;RouteEntry&gt;(result);<br/>        foreach(var route in result.Where(r =&gt; !r.Route.RouteTemplate.EndsWith(".{ext}")))<br/>        {<br/>            var newTemplate = route.Route.RouteTemplate + ".{ext}";<br/>            if (!result.Any(r =&gt; r.Route.RouteTemplate == newTemplate))<br/>            {<br/>                var entry = new RouteEntry(null, new HttpRoute(newTemplate,<br/>                    new HttpRouteValueDictionary(route.Route.Defaults),<br/>                    new HttpRouteValueDictionary(route.Route.Constraints),<br/>                    new HttpRouteValueDictionary(route.Route.DataTokens)));<br/>                list.Add(entry);<br/>            }<br/>        }<br/>        return list.AsReadOnly();<br/>    }<br/>}<br/></code></pre><br/><br/><p>El problema es que esto funciona bien, pero falla en un caso: <strong>Cuando la última parte de la ruta es un parámetro sin restricciones</strong>. Así pues, en el ejemplo anterior, la creación de rutas para <code>GetItemDetails</code> funciona, pero para <code>CreateItem</code> lanza lo siguiente:</p><br/><br/><pre><code>System.InvalidOperationException: Multiple actions were found that match the request: <br/>CreateItem on type FooBar.Api.Controllers.ItemsController<br/>CreateItem on type FooBar.Api.Controllers.ItemsController<br/>   at System.Web.Http.Controllers.ApiControllerActionSelector.ActionSelectorCacheItem.SelectAction(HttpControllerContext controllerContext)<br/>   at System.Web.Http.Controllers.ApiControllerActionSelector.SelectAction(HttpControllerContext controllerContext)<br/></code></pre><br/><br/><p>Me imagino de dónde puede venir el problema: Una cadena arbitraria cumple los patrones <code>{name}</code> y <code>{name}.{ext}</code>, por lo que el motor de <em>WebApi</em> se confunde al intentar seleccionar la ruta adecuada. <strong> ...
# --------------------------------------------------
# Respuesta: <p><code>.AsString</code> devuelve el mismo "<em>string</em>" que la propiedad <code>.Text</code> si no existe ningún controlador de eventos "Event Handler", <code>OnGetText</code>, pero de existir uno puede darse el caso de ser diferente, o quizás un descendiente en <code>TField</code> que no sea el estándar podría ocasionar que fuera diferente.</p><br/><br/><p>Saludos y espero ayude.</p><br/><br/><p>P.D: Sobre si hay una razón para usar una u otra no sabría decirle con total certeza eso dependería del uso que tenga previsto para el valor de retorno.</p><br/>
# Pregunta: <p>Luego de ver cierto código, me he dado cuenta que utilizan este estilo:</p><br/><br/><pre><code>aStr:=tblAcct.FieldByName('Name').Text;<br/></code></pre><br/><br/><p>Parece trabajar bien, pero yo había utilizado hasta ahora:</p><br/><br/><pre><code>aStr:=tblAcct.FieldByName('Name').AsString;<br/></code></pre><br/><br/><p>He utilizado ambos al cargar un TMemo y no parece haber diferencia alguna.</p><br/><br/><pre><code>aMemo.Lines.Text:=tblAcct.FieldByName('History').Text;<br/>aMemo.Lines.Text:=tblAcct.FieldByName('History').AsString;<br/></code></pre><br/><br/><p>¿Hay alguna razón por la que deba utilizar una y no la otra? ¿Cuál es esa razón?</p><br/><br/><p>Normalmente, para un memo, utilizo:</p><br/><br/><pre><code>aMemo.Lines.Assign(tblAcct.FieldByName('History'))<br/></code></pre><br/><br/><p>Y esto trabaja bien también.</p><br/>
# --------------------------------------------------
# Respuesta: <p>Lo de elegancia es algo difícil de decir, es cuestión de gustos. Pero la legibilidad del código siempre es importante. Por eso, este código se puede simplificar así: (a mi me parece más legible)</p><br/><br/><pre><code>std::string tempStr;<br/>while(isstream &gt;&gt; tempStr) {<br/>    std::cout &lt;&lt; tempStr &lt;&lt; std::endl;<br/>}<br/></code></pre><br/><br/><p>Con lo cual, metiendo todo en una función quedaría algo así:</p><br/><br/><pre><code>std::vector&lt;std::string&gt; split_istringstream(std::string str) {<br/>    std::vector&lt;std::string&gt; resultado;<br/>    std::istringstream isstream(str);<br/>    std::string palabra;<br/><br/>    while(isstream &gt;&gt; palabra){<br/>        resultado.push_back(palabra);<br/>    }<br/><br/>    return resultado;<br/>}<br/></code></pre><br/><br/><p>Otra alternativa, que incluso permite definir el delimitador (el operador >> de <code>istringstream</code> solo divide la cadena por los espacios - ASCII 32) es utilizar <a href="http://es.cppreference.com/w/cpp/string/basic_string/getline" rel="noreferrer">std::getline</a>. </p><br/><br/><pre><code>std::vector&lt;std::string&gt; split_getline(std::string str, char delim) {<br/>    std::vector&lt;std::string&gt; resultado;<br/>    std::istringstream isstream(str);<br/>    std::string palabra;<br/><br/>    while(std::getline(isstream, palabra, delim)){<br/>        resultado.push_back(palabra);<br/>    }<br/><br/>    return resultado;<br/>}<br/></code></pre><br/><br/><p>Aquí abajo te dejo una comparativa entre ambas opciones, son prácticamente iguales en eficiencia, dejando de un lado los vectores, reservan prácticamente la misma memoria.</p><br/><br/><p><a href="http://cpp.sh/3jtw" rel="noreferrer">http://cpp.sh/3jtw</a></p><br/>
# Pregunta: <p>¿Cuál es la forma más eficiente de separar un string en <code>c++</code>? como el que se muestra en el código, el cual contiene espacios entre las palabras, este es el método que yo estoy usando actualmente.</p><br/><br/><pre><code>#include &lt;iostream&gt;<br/>#include &lt;sstream&gt;<br/><br/>int main(int argc, char** argv){<br/><br/>    std::string str("Texto para dividir");<br/>    std::istringstream isstream(str);<br/><br/>    while(!isstream.eof()){<br/><br/>        std::string tempStr;<br/><br/>        isstream &gt;&gt; tempStr;<br/><br/>        std::cout &lt;&lt; tempStr &lt;&lt; std::endl;<br/>    }<br/><br/>    return 0;<br/>}<br/></code></pre><br/>
# --------------------------------------------------
# Respuesta: <p>Antes de responder directamente la respuesta, hablaremos de las propiedades relevantes de TField y sus descendientes.</p><br/><br/><h1><code>Text</code>/<code>DisplayText</code></h1><br/><br/><p>Ambas propiedades sirven para obtener una representación textual del valor del campo para su uso en la Interfaz de Usuario. <br/>El propósito de la propiedad <code>Text</code> es el de obtener una representación textual del campo cuándo está siendo editado en un control asociado a datos (Data Aware), en contraste con la propiedad <code>DisplayText</code> que proporciona el valor del campo con formato de visualización para el usuario, por ejemplo, puede contener caracteres de puntuación u otra decoración al valor plano. (1234.50 en contraste con 1,234.50).</p><br/><br/><p>En otras palabras, un <code>TdbEdit</code> o controles similares, mostrarán el valor de <code>DisplayText</code> cuándo no están siendo editados, y al recibir el foco, cambiarán el valor al de la propiedad <code>Text</code> y es este valor el que el usuario "edita". Un TdbLabel solamente tira de la propiedad <code>DisplayText</code>, ya que no es editable.</p><br/><br/><p>La documentación para <code>Text</code> dice:</p><br/><br/><blockquote><br/>  <p>Contains the string to display in a data-aware control when the field is in edit mode</p><br/></blockquote><br/><br/><p>Un ejemplo típico es un <code>TFloatField</code> con la propiedad <code>Currency</code> establecida a <code>True</code>. La propiedad DisplayText te devuelve el string con el número conteniendo separadores de miles, el separador decimal y el símbolo de la moneda. La propiedad Text, te devuelve una cadena que no contiene separadores de miles ni símbolo de moneda.</p><br/><br/><pre><code>begin<br/>  MyFloatField.Currency := True;<br/>  MyFloatField.AsFloat := 1234.56;<br/>  A := MyFloatField.Text; //'1234.56'<br/>  B := MyFloatField.DisplayText; //'$1,234.56', depends on your locale<br/>  ShowMessage(A + #13 + B);<br/>end;<br/></code></pre><br/><br/><p>El comportamiento de ambas propiedades puede ser personalizado escribiendo un manejador de eventos para <code>OnGetText</code>, dónde se puede escribir la lógica para convertir el valor del campo en una de ambas representaciones textuales. El parámetro booleano <code>DisplayText</code> indica si la cadena solicitada es para representar el valor en la interfaz de usuario o para edición. </p><br/><br/><p>De esta manera, podemos lograr que la representación en la interfaz de usuario para un campo entero con valor 1 sea 'uno', y su valor para edición sea 'one'</p><br/><br/><h1><code>AsString</code></h1><br/><br/><p>Por otro lado, la propiedad AsString utiliza una conversión plana entre el tipo de dato base del campo y una cadena de caracteres. Cada descendiente de <code>TField</code> implementa el método virtual <code>GetAsString</code> que típicamente utiliza funciones de la RTL para realizar la conversión. Siguiendo con el ejemplo de TFloatField, esta clase llama a la función FloatToStr() para realizar la conversión.</p><br/><br/><h1>La respuesta</h1><br/><br/><p>Dicho todo esto, la respuesta a la pregunta sería:</p><br/><br/><p>AsString retorna usualmente el mismo valor que retorna la propiedad Text, siempre que no haya un manejador de evento para OnGetText, pero la representación podría ser diferente si hubiese un manejador de evento o un descendiente no estándar de TField.</p><br/><br/><p>Con la información dada, no puede decirse cuál es más apropiado, ya que esto depende de cuál es el uso que se le dará al valor retornado. Si se está utilizando para mostrar valores en la Interfaz de usuario, como se muestra en los ejemplos de código proporcionados, mi consejo es que utilices la propiedad <code>DisplayText</code>.</p><br/>
# Pregunta: <p>Luego de ver cierto código, me he dado cuenta que utilizan este estilo:</p><br/><br/><pre><code>aStr:=tblAcct.FieldByName('Name').Text;<br/></code></pre><br/><br/><p>Parece trabajar bien, pero yo había utilizado hasta ahora:</p><br/><br/><pre><code>aStr:=tblAcct.FieldByName('Name').AsString;<br/></code></pre><br/><br/><p>He utilizado ambos al cargar un TMemo y no parece haber diferencia alguna.</p><br/><br/><pre><code>aMemo.Lines.Text:=tblAcct.FieldByName('History').Text;<br/>aMemo.Lines.Text:=tblAcct.FieldByName('History').AsString;<br/></code></pre><br/><br/><p>¿Hay alguna razón por la que deba utilizar una y no la otra? ¿Cuál es esa razón?</p><br/><br/><p>Normalmente, para un memo, utilizo:</p><br/><br/><pre><code>aMemo.Lines.Assign(tblAcct.FieldByName('History'))<br/></code></pre><br/><br/><p>Y esto trabaja bien también.</p><br/>
# --------------------------------------------------
# Respuesta: <p>En el primer caso:</p><br/><br/><pre><code>nombreCompleto1 = () =&gt; {<br/>    return this.nombre + " " + this.apellido;<br/>}<br/></code></pre><br/><br/><p>estás creando un <em>método de instancia</em>, es equivalente a ejecutar <code>this.nombreCompleto1 = function() {...}</code> en JavaScript.</p><br/><br/><p>En el segundo caso:</p><br/><br/><pre><code>nombreCompleto2() {<br/>    return this.nombre + " " + this.apellido;<br/>}<br/></code></pre><br/><br/><p>estás creando un <em>método de prototipo</em>, es equivalente a <code>Persona.prototype.nombreCompleto2 = function() {...}</code> en JavaScript.</p><br/><br/><p>En general es preferible crear métodos de prototipo: en tal caso el método se define una sola vez, mientras que los métodos de instancia se crean una vez por instancia, consumiendo más memoria.</p><br/><br/><p>Más información: <a href="http://www.johnpapa.net/typescriptpost3" rel="noreferrer">TypeScript Classes and Interfaces</a></p><br/>
# Pregunta: <p>Dado el siguiente código en TypeScript</p><br/><br/><pre><code>class Persona {<br/>    constructor(public nombre: string, public apellido: string) {<br/>    }<br/><br/>    nombreCompleto1 = () =&gt; {<br/>        return this.nombre + " " + this.apellido;<br/>    }<br/><br/>    nombreCompleto2() {<br/>        return this.nombre + " " + this.apellido;<br/>    }<br/>}<br/><br/>var p = new Persona("Juan", "Pérez");<br/><br/>console.log(p.nombreCompleto1());<br/>console.log(p.nombreCompleto2());<br/></code></pre><br/><br/><p>Como se puede ver los métodos <code>nombreCompleto1</code> y <code>nombreCompleto2</code> hacen lo mismo pero están declarados ligeramente diferente.</p><br/><br/><p>Al ejecutarlo en los dos casos se obtiene el resultado esperado:</p><br/><br/><pre><br/>Juan Pérez<br/>Juan Pérez<br/></pre><br/><br/><p>¿Cuál es la diferencia entre las dos declaraciones si los dos hacen los mismo y cuál es la forma adecuada de declararlo?</p><br/>
# --------------------------------------------------
# Respuesta: <p>Para realizar esta operación, ejecuta <code>Xcode</code> como <code>root</code> con el comando <a href="https://es.wikipedia.org/wiki/Sudo" rel="nofollow"><code>sudo</code></a> e instala dentro de esa sesión:</p><br/><br/><pre><code>sudo /Applications/Xcode.app/Contents/MacOS/Xcode<br/></code></pre><br/><br/><p>Una vez hayas instalados debes salir e iniciar normalmente.</p><br/><br/><p>Debes tener precaución si tienes proyectos abiertos cuando usas sudo para lanzar Xcode.</p><br/>
# Pregunta: <p>Estoy tratando de descargar el simulador de <code>iOS 8.4</code> en <code>Xcode 7</code> y me devuelve este error: </p><br/><br/><blockquote><br/>  <p>Could not download and install ios 8.4. Authorization is required to install the packages.</p><br/></blockquote><br/><br/><p>Antes de eso ingresé mi password de usuario.</p><br/>
# --------------------------------------------------
# Respuesta: <p>Como ya mencioné yo no uso Perl, pero mirando la documentación en una parte de ella dice lo siguiente:</p><br/><br/><blockquote><br/>  <p>"Si el desplazamiento es más allá del final de la matriz, Perl emite<br/>  una advertencia, y (Perl) empalma/splice en el extremo de la matriz."</p><br/></blockquote><br/><br/><p><em>...If OFFSET is past the end of the array, Perl issues a warning, and splices at the end of the array.</em></p><br/><br/><p>De echo he revisado en varias versiones y es lo mismo por lo menos la documentación advierten sobre el <em>warning</em>.</p><br/><br/><p>Aquí le dejo los links (en Inglés); </p><br/><br/><ul><br/><li><p><a href="http://perldoc.perl.org/5.16.2/functions/splice.html" rel="noreferrer" title="http://perldoc.perl.org/5.16.2/functions/splice.html">Perl v 5.16.2</a></p></li><br/><li><p><a href="http://perldoc.perl.org/5.20.0/functions/splice.html" rel="noreferrer" title="http://perldoc.perl.org/5.20.0/functions/splice.html">Perl v 5.20.0</a></p></li><br/><li><p><a href="http://perldoc.perl.org/functions/splice.html" rel="noreferrer" title="http://perldoc.perl.org/functions/splice.html">Perl v 5.22</a></p></li><br/></ul><br/><br/><p>Según lo anterior lo normal es el <em>warning</em>, pero por lo que se puede ver en el siguiente link, no en todas las versiones es así y también depende del OS.</p><br/><br/><p><a href="http://www.nntp.perl.org/group/perl.perl5.porters/2013/04/msg201134.html" rel="noreferrer">http://www.nntp.perl.org/group/perl.perl5.porters/2013/04/msg201134.html</a></p><br/><br/><p>Creo que eso ocurre entre la <code>5.14</code> y <code>5.16</code> en algunos sistemas, aquí puede ver la notificación de bug pero quizás también le suceda a usted en la <code>5.20</code> debido a su OS y no es que haya cambiado algo. </p><br/><br/><p><a href="https://rt.perl.org/Public/Bug/Display.html?id=117729" rel="noreferrer">https://rt.perl.org/Public/Bug/Display.html?id=117729</a></p><br/>
# Pregunta: <p>Hoy, en mi trabajo, escribí algo así, en Perl:</p><br/><br/><pre><code>my @x = qw( 1 2 3 4 5 );<br/>splice(@x, 10);<br/></code></pre><br/><br/><p>y produjo el error:</p><br/><br/><blockquote><br/>  <p>splice() offset past end of array at ./x line X.</p><br/></blockquote><br/><br/><p>Pero en mi laptop personal, no hay ningún error así. Ya sé que <a href="https://stackoverflow.com/a/3346640/13860">es fácil suprimir el mensaje (en Inglés)</a> con <code>no warnings 'misc';</code>, pero mi pregunta es:</p><br/><br/><p>¿Por qué la diferencia entre las versiones de Perl?</p><br/><br/><p>En el trabajo, veo el mensaje con Perl 5.14, y en mi equipo personal no lo veo con Perl 5.20.  ¿Cuando lo cambió, y por qué?</p><br/>
# --------------------------------------------------
# Respuesta: <p><em>voy a sumarme con la parte de la pregunta que no se ha respondido aun: <strong>¿Por qué cambió?</em></strong></p><br/><br/><p>Cambio por que la intención de este código:</p><br/><br/><pre><code>my @x = qw( 1 2 3 4 5 );<br/>splice(@x, 3);<br/></code></pre><br/><br/><p>es claramente truncar el array si es demasiado largo y <em>no hay razon para emitir una advertencia si el array tiene <strong>menos</strong> elementos que el máximo especificado</em> (como en el caso citado en la pregunta)</p><br/><br/><p><a href="http://perl5.git.perl.org/perl.git/commitdiff/5cd408a276e19848774860967c3ec06b67b863ee?hp=0890f1a536cff0aff68038cae78e02c9d9b6a2b2">Fuente (en Inglés)</a> </p><br/>
# Pregunta: <p>Hoy, en mi trabajo, escribí algo así, en Perl:</p><br/><br/><pre><code>my @x = qw( 1 2 3 4 5 );<br/>splice(@x, 10);<br/></code></pre><br/><br/><p>y produjo el error:</p><br/><br/><blockquote><br/>  <p>splice() offset past end of array at ./x line X.</p><br/></blockquote><br/><br/><p>Pero en mi laptop personal, no hay ningún error así. Ya sé que <a href="https://stackoverflow.com/a/3346640/13860">es fácil suprimir el mensaje (en Inglés)</a> con <code>no warnings 'misc';</code>, pero mi pregunta es:</p><br/><br/><p>¿Por qué la diferencia entre las versiones de Perl?</p><br/><br/><p>En el trabajo, veo el mensaje con Perl 5.14, y en mi equipo personal no lo veo con Perl 5.20.  ¿Cuando lo cambió, y por qué?</p><br/>
# --------------------------------------------------
# Respuesta: <p>Creo que <a href="https://hexdocs.pm/elixir/Enum.html#to_list/1" rel="noreferrer">esto</a> es lo que usted esta buscando</p><br/><br/><p><strong>to_list (colección)</strong></p><br/><br/><p><strong><em>Convierte la colección a una lista</em></strong></p><br/><br/><pre><code>iex&gt; Enum.to_list 1..5<br/>[1, 2, 3, 4, 5]<br/></code></pre><br/><br/><p>espero le ayude</p><br/>
# Pregunta: <p>Si defino un rango como el siguiente,</p><br/><br/><pre><code>rango = 1..5<br/></code></pre><br/><br/><p>¿Hay una manera de convertirlo a lista?</p><br/>
# --------------------------------------------------
# Respuesta: <p>Los <code>FPS</code> varian porque solo se solicita un marco cuando es necesario. por ejemplo si la imagen no cambia o es un fondo oscuro la tasa se puede reducir a una tasa más baja, ademas cuando se ejecuta en las pestañas de fondo tambien pude darse el caso para mejorar el rendimiento y la duración de la batería.</p><br/><br/><p>Puede mirar este caso como se "ajustan los frames" usando: <code>startAnimating(5)</code>;<br/><a href="http://jsfiddle.net/m1erickson/CtsY3/" rel="noreferrer">jsfiddle</a></p><br/><br/><p><div class="snippet" data-lang="js" data-hide="false" data-console="true" data-babel="false"><br/><div class="snippet-code"><br/><pre class="snippet-code-js lang-js prettyprint-override"><code>var stop = false;<br/>var frameCount = 0;<br/>var $results = $("#results");<br/>var fps, fpsInterval, startTime, now, then, elapsed;<br/><br/>startAnimating(5);<br/><br/>function startAnimating(fps) {<br/>    fpsInterval = 1000 / fps;<br/>    then = Date.now();<br/>    startTime = then;<br/>    console.log(startTime);<br/>    animate();<br/>}<br/><br/><br/>function animate() {<br/><br/>    // stop<br/>    if (stop) {<br/>        return;<br/>    }<br/><br/>    // request another frame<br/><br/>    requestAnimationFrame(animate);<br/><br/>    // calc elapsed time since last loop<br/><br/>    now = Date.now();<br/>    elapsed = now - then;<br/><br/>    // if enough time has elapsed, draw the next frame<br/><br/>    if (elapsed &gt; fpsInterval) {<br/><br/>        // Get ready for next frame by setting then=now, but...<br/>        // Also, adjust for fpsInterval not being multiple of 16.67<br/>        then = now - (elapsed % fpsInterval);<br/><br/>        // draw stuff here<br/><br/><br/>        // TESTING...Report #seconds since start and achieved fps.<br/>        var sinceStart = now - startTime;<br/>        var currentFps = Math.round(1000 / (sinceStart / ++frameCount) * 100) / 100;<br/>        $results.text("Elapsed time= " + Math.round(sinceStart / 1000 * 100) / 100 + " secs @ " + currentFps + " fps.");<br/><br/>    }<br/>}</code></pre><br/><pre class="snippet-code-html lang-html prettyprint-override"><code>&lt;script src="https://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js"&gt;&lt;/script&gt;<br/>&lt;h3&gt;Throttling requestAnimationFrame to a FPS&lt;/h3&gt;<br/>&lt;p&gt;This test:  Results should be approximately 5 fps<br/>&lt;p id="results"&gt;Results:&lt;/p&gt;<br/>&lt;canvas id="canvas" width=300 height=300&gt;&lt;/canvas&gt;</code></pre><br/></div><br/></div><br/></p><br/>
# Pregunta: <p>Hoy intenté este algoritmo para medir a cuantos cuadros por segundo (FPS) se refresca mi pantalla (yo sé de antemano que son 50 FPS).</p><br/><br/><pre><code>function measureFpsAsync() {<br/>    requestAnimationFrame(function(t0) {<br/>        requestAnimationFrame(function(t1) {<br/>            fps = Math.round(1000/(t1 - t0));<br/>            alert(fps);<br/>        });<br/>    });<br/>}<br/>window.onload = measureFpsAsync;<br/></code></pre><br/><br/><p>Para mi sorpresa el resultado no fue 50, tampo un resultado estable, algunas veces resulta 25, otras 13, otras 7. Parece que se salta algunos "frames" (o cuadros) entre los callbacks. </p><br/><br/><p>Lo probé en Chrome, Firefox y Edge y siempre pasa lo mismo.</p><br/><br/><p>Luego intenté envolverlo en un <code>setTimeout</code> a ver que sucedía y funcionó, siempre me devuelve un resultado estable de 50 FPS.</p><br/><br/><pre><code>setTimeout(function() { <br/>        measureFpsAsync();<br/>}, 500);<br/></code></pre><br/><br/><p>La verdad me sorprende, yo entendía que requestAnimationFrame tenía cierta correlación con el refresco vertical de la pantalla y que se llama a intervalos regulares, ahora no se si este método es seguro para calcular el FPS.</p><br/><br/><p>¿Alguien me puede explicar por qué pasa esto?</p><br/><br/><p>Es importante para mi, porque estoy creando una coreografía y necesito calcular un <em>epsilon</em> muy preciso.</p><br/><br/><p>Es seguro este método o debería moverme a un enfoque que tome mas muestras? </p><br/><br/><p><a href="http://jsfiddle.net/foqoh61o/1/" rel="noreferrer">http://jsfiddle.net/foqoh61o/1/</a></p><br/>
# --------------------------------------------------

# %% [markdown]
# ### Ejercicio 3: Encontrar las 10 preguntas más vistas (`ViewCount`) y muestra el nombre del usuario que las creó.

# %%
pipeline = [
    {"$match": {"PostTypeId": 1}},          # preguntas

    {"$sort": {"ViewCount": -1}},           # más vistas primero

    {"$limit": 10},

    {
        "$lookup": {
            "from": "users",
            "localField": "OwnerUserId",
            "foreignField": "Id",
            "as": "owner"
        }
    },

    {
        "$project": {
            "_id": 0,
            "title": "$Title",
            "views": "$ViewCount",
            "user": {"$arrayElemAt": ["$owner.DisplayName", 0]}
        }
    }
]

results = list(db.posts.aggregate(pipeline))

for r in results:
    print("Pregunta:", r["title"])
    print("Vistas:", r["views"])
    print("Usuario:", r["user"])
    print("-"*50)
# Out:
# Pregunta: Cómo separar un String en Java. Cómo utilizar split()
# Vistas: 496200
# Usuario: Jorgesys
# --------------------------------------------------
# Pregunta: Guia definitiva de conversión de tipos en Java
# Vistas: 400626
# Usuario: jasilva
# --------------------------------------------------
# Pregunta: ¿Como generar números aleatorios dentro de un rango de valores?
# Vistas: 377766
# Usuario: samir Pazo torres
# --------------------------------------------------
# Pregunta: Posicionar footer SIEMPRE pegado al pie de pagina
# Vistas: 334608
# Usuario: Lucas. D
# --------------------------------------------------
# Pregunta: ¿Como crear un botón HTML que funcione como un link?
# Vistas: 295361
# Usuario: gbianchi
# --------------------------------------------------
# Pregunta: ¿Como limitar la cantidad de decimales de un double?
# Vistas: 280218
# Usuario: Roy
# --------------------------------------------------
# Pregunta: ¿Salto de línea en Javascript?
# Vistas: 258928
# Usuario: Manuel Rivero Albano
# --------------------------------------------------
# Pregunta: ¿Cómo comparar correctamente Strings (y objetos) en Java?
# Vistas: 256224
# Usuario: Jordi Castilla
# --------------------------------------------------
# Pregunta: ¿For each en JavaScript?
# Vistas: 252099
# Usuario: Jordi Castilla
# --------------------------------------------------
# Pregunta: Botón en HTML que te envíe a otra página
# Vistas: 247708
# Usuario: Sergio AG
# --------------------------------------------------

# %% [markdown]
# ### Ejercicio 4: Obtener el resultado de documentos *verbosos* en donde se indique el texto `Body` de una pregunta así como el nombre del usuario que la formuló (`DisplayName`)

# %%
pipeline = [
    {"$match": {"PostTypeId": 1}},          # preguntas

    {"$limit": 10},

    {
        "$lookup": {
            "from": "users",
            "localField": "OwnerUserId",
            "foreignField": "Id",
            "as": "owner"
        }
    },

    {
        "$project": {
            "_id": 0,
            "title": "$Title",
            "views": "$ViewCount",
            "user": {"$arrayElemAt": ["$owner.DisplayName", 0]}
        }
    }
]

results = list(db.posts.aggregate(pipeline))

for r in results:
    print("Pregunta:", r["title"])
    print("Vistas:", r["views"])
    print("Usuario:", r["user"])
    print("-"*50)
# Out:
# Pregunta: La creación manual de un alias de ruta con un DirectRouteProvider personalizado causa un error "Multiple actions were found that match the request"
# Vistas: 780
# Usuario: Konamiman
# --------------------------------------------------
# Pregunta: ¿Es igual utilizar .AsString que .Text para obtener el valor de un campo de un DataSet?
# Vistas: 1035
# Usuario: jachguate
# --------------------------------------------------
# Pregunta: ¿Cómo separar las palabras que contiene un string en C++? 'Split '
# Vistas: 37867
# Usuario: Angel Angel
# --------------------------------------------------
# Pregunta: ¿Cuándo usar y es seguro emplear const_cast, static_cast, dynamic_cast, reinterpret_cast?
# Vistas: 3291
# Usuario: Angel Angel
# --------------------------------------------------
# Pregunta: "Unknown provider: uiGmapGoogleMapApiProvider" al probar con Jasmine código que usa el componente de Google Maps para AngularJS
# Vistas: 320
# Usuario: Konamiman
# --------------------------------------------------
# Pregunta: ¿Cómo definir métodos correctamente en TypeScript?
# Vistas: 3407
# Usuario: Carlos Muñoz
# --------------------------------------------------
# Pregunta: "splice() offset past end of array" en diferentes versiones de Perl
# Vistas: 422
# Usuario: Flimzy
# --------------------------------------------------
# Pregunta: Error ios 8.4 simulator en xcode 7
# Vistas: 139
# Usuario: Gabriel C
# --------------------------------------------------
# Pregunta: ¿Cómo puedo convertir un rango a lista en elixir?
# Vistas: 238
# Usuario: Gabriel C
# --------------------------------------------------
# Pregunta: ¿Cómo mostrar una vista sin el layout de la aplicación?
# Vistas: 941
# Usuario: matiasmasca
# --------------------------------------------------

# %% [markdown]
# ### Ejercicio 5: Obtener las respuestas escritas en Enero de 2022 con un `Score` superior a 3.

# %%
from datetime import datetime

# Fechas
start_date = datetime(2022, 1, 1)
end_date = datetime(2022, 1, 28, 23, 59, 59)

pipeline = [
    {
        "$match": {
            "PostTypeId": 2,                    # respuestas
            "CreationDate": {"$gte": start_date, "$lte": end_date},
            "Score": {"$gt": 3}                  # Score superior a 3
        }
    },
    {"$limit": 10}
]

results = list(db.posts.aggregate(pipeline))

for r in results:
    print("Respuesta:", r["Body"])
    print("Score:", r["Score"])
    print("Fecha:", r["CreationDate"])
    print("-"*50)
# Out:
# Respuesta: <p>Buen día! esto se puede solucionar de varias maneras, sin el uso de paquetes</p><br/><p><div class="snippet" data-lang="js" data-hide="false" data-console="true" data-babel="false"><br/><div class="snippet-code"><br/><pre class="snippet-code-js lang-js prettyprint-override"><code>Date.prototype.addDays = function(days) {<br/>    var date = new Date(this.valueOf());<br/>    date.setDate(date.getDate() + days);<br/>    return date;<br/>}<br/><br/>var date = new Date();<br/><br/>console.log(date.addDays(1));</code></pre><br/></div><br/></div><br/></p><br/><p>O utilizando paquetes como DayJs que facilitan la manipulación de fechas:</p><br/><ul><br/><li>Instalación de paquete: <a href="https://www.npmjs.com/package/dayjs" rel="nofollow noreferrer">https://www.npmjs.com/package/dayjs</a></li><br/><li>Método que vas a necesitar: <a href="https://day.js.org/docs/en/manipulate/add" rel="nofollow noreferrer">https://day.js.org/docs/en/manipulate/add</a></li><br/></ul><br/>
# Score: 4
# Fecha: 2022-01-03 14:41:43.473000
# --------------------------------------------------
# Respuesta: <p>La verdad no se programar en C++ así que no estoy seguro de que esto resuelva la pregunta, en todo caso he probado cambiando las dobles comillas <code>&quot;</code> por comillas simples <code>'</code>.</p><br/><p>Llegué a ello probando cada vez una porción de código más reducida:</p><br/><pre><code>int main(){<br/>    char tablero[2]={&quot;v&quot;,&quot;i&quot;};<br/>}<br/></code></pre><br/><p>Aún lanzando el mismo problema:</p><br/><p><a href="https://i.stack.imgur.com/KyYYG.png" rel="nofollow noreferrer"><img src="https://i.stack.imgur.com/KyYYG.png" alt="introducir la descripción de la imagen aquí" /></a></p><br/><p>Y probando con:</p><br/><pre><code>int main(){<br/>    char tablero[2]={'v','i'};<br/>}<br/></code></pre><br/><p>Ya no me lanza el error de compilación. He comprobado con el código completo de la pregunta e igualmente no lanza error de compilación.</p><br/>
# Score: 4
# Fecha: 2022-01-03 14:46:29.720000
# --------------------------------------------------
# Respuesta: <p>Primero hay que cambiar el <code>action</code> del formulario, ya que pasaríamos a procesar la petición en la misma ruta, es decir en la raíz(/)</p><br/><p>Esto</p><br/><pre><code>action=&quot;/checkingPass&quot;<br/></code></pre><br/><p>Por</p><br/><pre><code> action=&quot;/&quot;<br/></code></pre><br/><p>Por otra parte, en la plantilla <code>html</code>, tenemos que añadir una seria de comprobaciones haciendo uso de <a href="https://flask.palletsprojects.com/en/2.0.x/templating/" rel="nofollow noreferrer">Jinja</a>, es decir</p><br/><pre><code>{% if passwd_status == True %}<br/>    &lt;div&gt;Es correcta&lt;/div&gt;<br/>{% elif passwd_status == False %}<br/>    &lt;div&gt;No es correcta&lt;/div&gt;<br/>{% endif %}<br/></code></pre><br/><p>Con esto estamos diciendo que si la variable <code>passwd_status</code> es <code>True </code> significa que el usuario ha introducido bien la contraseña, en caso contrario, le mostraremos el mensaje de error. Dicho esto tu <code>html</code> quedara de la siguiente manera.</p><br/><pre><code>&lt;html&gt;<br/>  &lt;body&gt;<br/>  &lt;form action=&quot;/&quot; method=&quot;post&quot;&gt;<br/>    &lt;label for=&quot;nombreUser&quot;&gt; Ingrese contraseña: &lt;/label&gt;<br/>    &lt;input type=&quot;text&quot; name=&quot;nombreUser&quot;&gt;&lt;br/&gt;<br/>    &lt;input type=&quot;submit&quot; value=&quot;Enviar&quot; /&gt;<br/>  &lt;/form&gt;<br/>    &lt;!--Check jinja--&gt;<br/>    {% if passwd_status == True %}<br/>        &lt;div&gt;Es correcta&lt;/div&gt;<br/>    {% elif passwd_status == False %}<br/>        &lt;div&gt;No es correcta&lt;/div&gt;<br/>    {% endif %}<br/><br/>  &lt;/body&gt;<br/>&lt;/html&gt;<br/></code></pre><br/><p>Bien, ahora miremos la logia de Flask.</p><br/><p>Primero, deberíamos de decirle a la ruta que aceptamos peticiones <code>GET</code> y <code>POST</code>, para eso hacemos añadimos el parámetro <code>methods</code> a nuestro <code>app.router</code></p><br/><pre><code>@app.route('/', methods = [&quot;GET&quot;, &quot;POST&quot;])<br/></code></pre><br/><p>Después tendremos que mirar si el método es <code>GET</code> o <code>POST</code> y aplicar la  lógica  en cada una de las peticiones.</p><br/><p>Dicho esto, tu código en flask quedara así mas o menos.</p><br/><pre><code>from flask import Flask, render_template, request<br/>app = Flask(__name__)<br/><br/>@app.route('/', methods = [&quot;GET&quot;, &quot;POST&quot;])<br/>def checkinPass():<br/>    # Flag para guardar el estado del login<br/>    passwd_status = None<br/>    if request.method == 'GET':<br/>        # Devolvemos passwd_status None.<br/>        return render_template(&quot;index.html&quot;, passwd_status=passwd_status)<br/>    else:<br/>        # Recogemos el valor que nos manda el usuario<br/>        data = request.form.get('nombreUser')<br/>        if data == '1234':<br/>            # El valor es correcto<br/>            passwd_status = True<br/>        else:<br/>            passwd_status = False<br/>        # Devolvemos la misma plantilla y si el valor es valido o no<br/>        return render_template(&quot;index.html&quot;, passwd_status=passwd_status)<br/></code></pre><br/><h3>Ampliación</h3><br/><p>Para implementarlo con <code>fetch</code>, sería de la siguiente manera.</p><br/><p>Flask:</p><br/><pre><code>@app.route('/', methods = [&quot;GET&quot;, &quot;POST&quot;])<br/>def checkinPass():<br/>    # Flag para guardar el estado del login<br/>    if request.method == 'GET':<br/>        return render_template(&quot;index.html&quot;)<br/>    else:<br/>        passwd_status = False<br/>        # Recogemos el valor que nos manda el usuario<br/>        data = request.form.get('nombreUser')<br/>        if data == '1234':<br/>            # El valor es correcto<br/>            passwd_status = True<br/>        # Devolvemos un dict(json) con los resultados<br/>        return {'passwd_status': passwd_status}<br/></code></pre><br/><p>HTML/JS</p><br/><pre><code>&lt;html&gt;<br/>  &lt;body&gt;<br/>  ...
# Score: 4
# Fecha: 2022-01-03 22:57:22.470000
# --------------------------------------------------
# Respuesta: <p>Además de tener un diccionario con los nombres de los meses que te puede servir para construir el &quot;formato largo&quot;, también puedes tener un diccionario con los días que tiene cada mes, que te puede servir para validar el día sin necesidad de la larga secuencia de <code>if</code>s.</p><br/><p>Para el tratamiento de los bisiestos bastaría añadir a febrero un día más si el año es bisiesto. Para simplificar el código escribiré una función que retorne un booleano indicando si un año dado es bisiesto o no:</p><br/><pre class="lang-py prettyprint-override"><code>def es_bisiesto(year):<br/>  return year%400 == 0 or (year%4 == 0 and year%100 != 0)<br/></code></pre><br/><p>(no he hecho más que extraer a una función una parte de tu código).</p><br/><p>Ahora definimos los dos diccionarios que nos ayudarán en la tarea:</p><br/><pre class="lang-py prettyprint-override"><code>dias_mes = {1: 31, 2: 28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}<br/>nombre_mes = {1: &quot;enero&quot;, 2: &quot;febrero&quot;, 3: &quot;marzo&quot;, 4: &quot;abril&quot;, 5: &quot;mayo&quot;, 6: &quot;junio&quot;,<br/>              7: &quot;julio&quot;, 8: &quot;agosto&quot;, 9: &quot;septiembre&quot;, 10: &quot;octubre&quot;, <br/>              11: &quot;noviembre&quot;, 12: &quot;diciembre&quot;}<br/></code></pre><br/><p>Y entonces el código de validación (a la vez que la impresión de la fecha larga) se reduce a lo siguiente:</p><br/><pre class="lang-py prettyprint-override"><code>dias_mes[2] += es_bisiesto(year)<br/>if 1920 &lt;= year &lt;= 2020:<br/>    # Validar meses.<br/>    if 1 &lt;= month &lt;= 12:<br/>        # Validar días.<br/>        if 1 &lt;= day &lt;= dias_mes[month]:<br/>            print(f'\nFecha larga: {day} de {nombre_mes[month]} de {year}')<br/>        else:<br/>            print('El día no es válido.')<br/>    else:<br/>        print('El mes no es válido.')<br/>else:<br/>    print('El año no es válido.')<br/></code></pre><br/><h2>Alternativa</h2><br/><p>Podemos también encapsular en una función la parte en la que se valida si la fecha es buena o no. Podemos hacer que la función que lo comprueba retorne una pareja de valores: un booleano (que será <code>True</code> si la fecha pasa el test, o <code>False</code> si no lo pasa) y una cadena de error (que informará de por qué no pasó el test, o bien estará vacía).</p><br/><p>A la hora de programar esa función podemos reducir su complejidad (los niveles de indentación) si miramos primero las condiciones de <strong>no</strong> pasar el test, para retornar inmediatamente si no lo pasa, y dejando para el final el caso de que pase todas para retornar <code>True</code>. Esta estrategia evita la anidación de ifs.</p><br/><p>Por otro lado, usaré el truco adicional de mirar <code>if x in range()</code> para saber si una variable está en un rango dado (cuidado porque el extremo derecho del rango debe ser 1 más).</p><br/><p>Con estas consideraciones una función de verificación podría ser así:</p><br/><pre class="lang-py prettyprint-override"><code>def validar_fecha(year, month, day):<br/>  dias_mes = {1: 31, 2: 28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}<br/>  dias_mes[2] += es_bisiesto(year)<br/>  if not year in range(1920, 2021):<br/>    return False, &quot;El año no es válido&quot;<br/>  if not month in range(1, 13):<br/>    return False, &quot;El mes no es válido&quot;<br/>  if not day in range(1, dias_mes[month]+1):<br/>    return False, &quot;El día no es válido&quot;<br/>  return True, &quot;&quot;<br/></code></pre><br/><p>Y desde el programa principal la usaríamos así:</p><br/><pre class="lang-py prettyprint-override"><code>print('Introduzca la fecha de nacimiento en formato DD/MM/YYYY: ')<br/>entrada = input().split(&quot;/&quot;)<br/>day = int(entrada[0])<br/>month = int(entrada[1])<br/>year = int(entrada[2])<br/><br/>ok, err = validar_fecha(year, month, day)<br/>if ok:<br/>  print(f'\nFecha larga: {day} de {nombre_mes[month]} de  ...
# Score: 4
# Fecha: 2022-01-04 18:10:48.860000
# --------------------------------------------------
# Respuesta: <p>No puedes. Sólo con el puntero no se puede saber el tipo del dato al que apunta. Necesitas esa información en algún otro lugar (otro parámetro de la función, por ejemplo).</p><br/><p>Un truco típico para evitar ese parámetro adicional suele ser el siguiente.</p><br/><p>Se definen una serie de estructuras similares, todas ellas con un primer campo de tamaño prefijado (ej <code>char</code>), y luego ya los restantes campos los que sean. Ese primer campo guardará un valor que servirá para diferenciar qué tipo de estructura particular es la que sigue.</p><br/><p>De ese modo la función puede comenzar por hacer un <em>casting</em> a una de estas estructuras (se puede definir incluso una especie de &quot;clase base abstracta&quot; que tendría sólo el primer campo) y así podrá acceder al &quot;discriminante&quot; (el campo que le dice de qué tipo es). Según el valor de ese discriminante ya se puede hacer después un casting al tipo adecuado para poder acceder a los restantes campos.</p><br/><p>Esta sería una demostración de la idea:</p><br/><pre class="lang-c prettyprint-override"><code>#include&lt;stdio.h&gt;<br/>#include&lt;stdlib.h&gt;<br/><br/>struct AbstractBaseClass {<br/>    char tipo;<br/>};<br/><br/>struct Entero {<br/>    char tipo;<br/>    int dato;<br/>};<br/><br/>struct Double {<br/>    char tipo;<br/>    double dato;<br/>};<br/><br/>void prueba(void *p) {<br/>    struct Entero *p_e;<br/>    struct Double *p_d; <br/><br/>    switch(((struct AbstractBaseClass*)p)-&gt;tipo) {<br/>        case 1:  // Entero<br/>            p_e  = (struct Entero*) p;<br/>            printf(&quot;El dato entero vale %d\n&quot;, p_e-&gt;dato);<br/>            break;<br/>        case 2:  // Double<br/>            p_d = (struct Double*) p;<br/>            printf(&quot;El dato double vale %f\n&quot;, p_d-&gt;dato);<br/>            break;<br/>        default:<br/>            printf(&quot;Dato de tipo desconocido\n&quot;);<br/>    }<br/>}<br/><br/><br/>int main()<br/>{<br/>    struct Entero *pe = malloc(sizeof(struct Entero));<br/>    struct Double *pd = malloc(sizeof(struct Double));<br/><br/>    pe-&gt;tipo = 1;<br/>    pe-&gt;dato = 100;<br/>    pd-&gt;tipo = 2;<br/>    pd-&gt;dato = 3.1415;<br/><br/>    prueba((void*) pe);<br/>    prueba((void*) pd);<br/>    pe-&gt;tipo = 3;<br/>    prueba((void*) pe);<br/>    return 0;<br/>}<br/></code></pre><br/><p>Produce al ejecutarse:</p><br/><pre><code>El dato entero vale 100<br/>El dato double vale 3.141500<br/>Dato de tipo desconocido<br/></code></pre><br/><p><strong>Observa</strong> que es responsabilidad del programador (el código de main) el asignar correctamente y coherentemente el valor del discriminante. Nada nos impide declarar un puntero a <code>Entero</code>, guardar un entero en el campo <code>.dato</code> y en cambio poner un 2 en el campo <code>.tipo</code>. Obviamente las funciones que reciban un dato así no funcionarán correctamente pues castearán al tipo incorrecto e interpretarán incorrectamente los bytes del campo <code>dato</code> de la estructura.</p><br/>
# Score: 5
# Fecha: 2022-01-04 19:39:22.417000
# --------------------------------------------------
# Respuesta: <p>En esta parte estas agrengando el null,frase[i] en un inicio tiene el valor de null</p><br/><pre><code>frases[i] += sc.nextLine();<br/></code></pre><br/><p>el + no debe ir ,estas iterando y agregando no debes sumarle</p><br/><pre><code>for (int i = 0; i &lt; frases.length; i++) {<br/>            System.out.println(&quot;Introduce la frase &quot; + (i+1));<br/>            frases[i] = sc.nextLine();<br/><br/>        }<br/></code></pre><br/>
# Score: 5
# Fecha: 2022-01-05 12:44:11.493000
# --------------------------------------------------
# Respuesta: <p>El segundo párrafo (<em>demo2</em>) devuelve x porque al entrar a la función <strong>myFunction</strong>, el valor de x es &quot;Iván&quot;<br/>Al terminar la función el valor de <strong>x</strong> es <strong>67</strong>, y así lo mostrará el primer párrafo (<em>demo</em>)</p><br/><p><div class="snippet" data-lang="js" data-hide="false" data-console="true" data-babel="false"><br/><div class="snippet-code"><br/><pre class="snippet-code-js lang-js prettyprint-override"><code>    var a;<br/>    let b;<br/>    a = 33;<br/>    b = 34;<br/>    var x = "Ivan";<br/><br/>    var x = myFunction(a, b); // 1er paso: se entra a la función<br/>    document.getElementById("demo").innerHTML = x; //3er paso: Una vez terminada la función, <br/>//x valdrá 67, por lo que eso mostrará el p de id="demo"<br/><br/>    function myFunction(a, b) {<br/>      document.getElementById("demo2").innerHTML = x; //2do paso: acá x sigue valiendo "Iván", <br/>//por lo que el p con id="demo2" va a contener el valor "Iván"<br/>      return a + b;<br/>        return a * b;<br/><br/>    }</code></pre><br/><pre class="snippet-code-html lang-html prettyprint-override"><code>    &lt;p id="demo"&gt;&lt;/p&gt;<br/>    &lt;p id="demo2"&gt;&lt;/p&gt;</code></pre><br/></div><br/></div><br/></p><br/>
# Score: 4
# Fecha: 2022-01-05 13:34:31.477000
# --------------------------------------------------
# Respuesta: <p>Ahí te dice el error, eso quiere decir que estas poniendo un índex al arreglo password que sobrepasa el tamaño del arreglo.</p><br/><p>Como podrás notar tu arreglo es de 1 posición, ya que las letras no están separadas por las comillas &quot;&quot; debes separar las letras por ejemplo <code>[&quot;a&quot;,&quot;b&quot;,&quot;c&quot;....]</code> en lugar de <code>[&quot;a,b,c&quot;]</code></p><br/><p>Es por eso que te esta dando un error, porque le estas diciendo que obtenga del arreglo password una posición entre 8 y 25 pero el tamaño de tu arreglo es 1</p><br/><p>Te pongo un ejemplo para que te quede mas claro</p><br/><p>Un arreglo de 3 posiciones seria algo como</p><br/><p><code>arreglo = [&quot;Auto&quot;,&quot;Motocicleta&quot;,&quot;Autobús&quot;]</code></p><br/><p>si quisiera obtener el valor motocicleta debo usar <code>arreglo[1]</code> sin embargo si le pongo <code>arreglo[3]</code> me va a dar el error de <code>Index out of range</code> porque mi arreglo es de 3 posiciones cabe destacar que los arreglos siempre empiezan desde 0, en este caso para obtener los datos debo usar las posiciones <code>0 1 2</code>, espero haberme explicado</p><br/><p>De igual manera te dejo este <a href="https://www.ecured.cu/Arreglos_(Inform%C3%A1tica)" rel="nofollow noreferrer">link</a> que puede complementar tu conocimiento sobre los arreglos</p><br/>
# Score: 4
# Fecha: 2022-01-05 22:02:53.793000
# --------------------------------------------------
# Respuesta: <p>El color <code>default</code> no existe. El <a href="https://www.w3schools.com/cssref/pr_background-color.asp" rel="noreferrer">valor por defecto del background-color</a> es <code>transparent</code>.</p><br/><p>Por lo tanto debes usar:</p><br/><pre><code>onmouseout=&quot;this.style.backgroundColor='transparent'&quot;<br/></code></pre><br/><p>o bien</p><br/><pre><code>onmouseout=&quot;this.style.backgroundColor=''&quot;<br/></code></pre><br/><p>y entonces cogerá el por defecto, que es <code>transparent</code>.</p><br/><p><div class="snippet" data-lang="js" data-hide="false" data-console="true" data-babel="false"><br/><div class="snippet-code"><br/><pre class="snippet-code-html lang-html prettyprint-override"><code>&lt;!DOCTYPE html&gt;<br/>&lt;html&gt;<br/>&lt;body&gt;<br/><br/>&lt;h2&gt;JavaScript HTML Events&lt;/h2&gt;<br/>&lt;button onmouseover="this.style.backgroundColor='red'"<br/>    onmouseout="this.style.backgroundColor=''"<br/>    onclick="this.innerHTML=Date()"&gt;The time is?&lt;/button&gt;<br/>&lt;/body&gt;<br/>&lt;/html&gt;</code></pre><br/></div><br/></div><br/></p><br/>
# Score: 5
# Fecha: 2022-01-06 11:38:51.607000
# --------------------------------------------------
# Respuesta: <p>En programación orientada a objetos sabrás que un objeto s una instancia de una clase.<br /><br/>Supongo que habrás leído que Javascript usa la programación orientada a objetos de forma un poco particular. A efectos prácticos este lenguaje puedes ver un objeto como una colección de propiedades y métodos, y si te fijas para Javascript prácticamente todo son objetos: strings, arrays, numbers, ....<br /><br/>Y el DOM sigue en la misma línea: todos los elementos se usan como objetos. Por ejemplo un bloque div es un nodo en el árbol del DOM, y se gestiona desde javascript como un objeto con sus métodos y propiedades.<br /><br/>Espero que te aclare la duda, o al menos no te líe más :)</p><br/>
# Score: 4
# Fecha: 2022-01-07 08:52:14.297000
# --------------------------------------------------

# %% [markdown]
# ### Ejercicio 6: Obtener las usuarios que se añadieron al sistema en octubre del año 2017 (`CreationDate`) pero que no hayan realizado después ninguna visita a su perfil (`Views`).

# %%
from datetime import datetime
from pprint import pprint

# Fechas de octubre 2017
start_date = datetime(2017, 10, 1)
end_date = datetime(2017, 10, 31, 23, 59, 59)

pipeline = [
    {
        "$match": {
            "CreationDate": {"$gte": start_date, "$lte": end_date},
            "$or": [                         # usuarios que no hicieron visitas
                {"Views": {"$exists": False}},
                {"Views": 0}
            ]
        }
    },
    {"$limit": 10}
]

results = list(db.users.aggregate(pipeline))

pprint(results)
# Out:
# [{'AboutMe': None,
#   'AccountId': 11891417,
#   'CreationDate': datetime.datetime(2017, 10, 1, 0, 1, 0, 470000),
#   'DisplayName': 'Michel Patron',
#   'DownVotes': 0,
#   'Id': 61613,
#   'LastAccessDate': datetime.datetime(2017, 10, 1, 0, 1, 0, 470000),
#   'Location': None,
#   'Reputation': 1,
#   'UpVotes': 0,
#   'Views': 0,
#   'WebsiteUrl': None,
#   '_id': ObjectId('69a8ddc1736d6c0569d2d8d7')},
#  {'AboutMe': None,
#   'AccountId': 11662418,
#   'CreationDate': datetime.datetime(2017, 10, 1, 0, 8, 52, 573000),
#   'DisplayName': 'bryan silva',
#   'DownVotes': 0,
#   'Id': 61614,
#   'LastAccessDate': datetime.datetime(2019, 1, 11, 19, 1, 20, 890000),
#   'Location': None,
#   'Reputation': 1,
#   'UpVotes': 0,
#   'Views': 0,
#   'WebsiteUrl': None,
#   '_id': ObjectId('69a8ddc1736d6c0569d2d8d8')},
#  {'AboutMe': None,
#   'AccountId': 4317587,
#   'CreationDate': datetime.datetime(2017, 10, 1, 0, 11, 49, 900000),
#   'DisplayName': 'user3526943',
#   'DownVotes': 0,
#   'Id': 61616,
#   'LastAccessDate': datetime.datetime(2017, 11, 28, 15, 41, 40, 47000),
#   'Location': None,
#   'Reputation': 1,
#   'UpVotes': 0,
#   'Views': 0,
#   'WebsiteUrl': None,
#   '_id': ObjectId('69a8ddc1736d6c0569d2d8da')},
#  {'AboutMe': None,
#   'AccountId': 11891465,
#   'CreationDate': datetime.datetime(2017, 10, 1, 0, 14, 38, 733000),
#   'DisplayName': 'Hermes Barrios',
#   'DownVotes': 0,
#   'Id': 61617,
#   'LastAccessDate': datetime.datetime(2018, 2, 4, 19, 55, 38, 273000),
#   'Location': None,
#   'Reputation': 1,
#   'UpVotes': 0,
#   'Views': 0,
#   'WebsiteUrl': None,
#   '_id': ObjectId('69a8ddc1736d6c0569d2d8db')},
#  {'AboutMe': None,
#   'AccountId': 8126418,
#   'CreationDate': datetime.datetime(2017, 10, 1, 0, 40, 19, 240000),
#   'DisplayName': 'teafoot',
#   'DownVotes': 0,
#   'Id': 61618,
#   'LastAccessDate': datetime.datetime(2017, 12, 11, 23, 9, 4, 227000),
#   'Location': None,
#   'Reputation': 1,
#   'UpVotes': 0,
#   'Views': 0,
#   'WebsiteUrl': None,
#   '_id': ObjectId('69a8ddc1736d6c0569d2d8dc')},
#  {'AboutMe': None,
#   'AccountId': 11877673,
#   'CreationDate': datetime.datetime(2017, 10, 1, 0, 40, 36, 783000),
#   'DisplayName': 'Runkle',
#   'DownVotes': 0,
#   'Id': 61619,
#   'LastAccessDate': datetime.datetime(2020, 6, 7, 16, 48, 19, 980000),
#   'Location': None,
#   'Reputation': 1,
#   'UpVotes': 0,
#   'Views': 0,
#   'WebsiteUrl': None,
#   '_id': ObjectId('69a8ddc1736d6c0569d2d8dd')},
#  {'AboutMe': None,
#   'AccountId': 11891606,
#   'CreationDate': datetime.datetime(2017, 10, 1, 1, 14, 54, 893000),
#   'DisplayName': 'Jhon Fredy Mejia',
#   'DownVotes': 0,
#   'Id': 61620,
#   'LastAccessDate': datetime.datetime(2017, 10, 3, 13, 57, 23, 530000),
#   'Location': None,
#   'Reputation': 1,
#   'UpVotes': 0,
#   'Views': 0,
#   'WebsiteUrl': None,
#   '_id': ObjectId('69a8ddc1736d6c0569d2d8de')},
#  {'AboutMe': None,
#   'AccountId': 11891607,
#   'CreationDate': datetime.datetime(2017, 10, 1, 1, 15, 7, 937000),
#   'DisplayName': 'Ariel Gatica',
#   'DownVotes': 0,
#   'Id': 61621,
#   'LastAccessDate': datetime.datetime(2017, 10, 1, 1, 45, 40, 650000),
#   'Location': None,
#   'Reputation': 1,
#   'UpVotes': 0,
#   'Views': 0,
#   'WebsiteUrl': None,
#   '_id': ObjectId('69a8ddc1736d6c0569d2d8df')},
#  {'AboutMe': None,
#   'AccountId': 11891646,
#   'CreationDate': datetime.datetime(2017, 10, 1, 1, 28, 25, 253000),
#   'DisplayName': 'Mario Espinoza',
#   'DownVotes': 0,
#   'Id': 61622,
#   'LastAccessDate': datetime.datetime(2017, 10, 1, 9, 58, 4, 637000),
#   'Location': None,
#   'Reputation': 1,
#   'UpVotes': 0,
#   'Views': 0,
#   'WebsiteUrl': None,
#   '_id': ObjectId('69a8ddc1736d6c0569d2d8e0')},
#  {'AboutMe': None,
#   'AccountId': 5153300,
#   'CreationDate': datetime.datetime(2017, 10, 1, 1, 40, 5, 563000),
#   'DisplayName': 'Julio Villalba',
#   'DownVotes': 0,
#   'Id': 61623,
#   'LastAccessDate': datetime.datetime(2018, 4, 20, 5, 6, 27, 320000),
#   'Location': 'Chihuahua, Mexico',
#   'Reputation': 1,
#   'UpVotes': 0,
#   'Views': 0,
#   'WebsiteUrl': 'http://julio-villalba.com',
#   '_id': ObjectId('69a8ddc1736d6c0569d2d8e1')}]

# %% [markdown]
# ### Ejercicio 7: Obtener un listado, en forma de array, con los id de los usuarios que han contestado cada pregunta. Limita la búsqueda a 2000.

# %%
pipeline = [
    {"$match": {"PostTypeId": 1}},         # preguntas
    {"$limit": 2000},

    {"$lookup": {
        "from": "posts",
        "localField": "_id",
        "foreignField": "ParentId",
        "as": "answers"
    }}]

results = list(db.posts.aggregate(pipeline))

# Mostrar los primeros 10
for r in results[:10]:
    print("Pregunta _id:", r["_id"])
    print("Usuarios que respondieron:", r["user_ids"])
    print("-"*50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2382/3578746813.py in <cell line: 0>()
#      10     }}]
#      11
# ---> 12 results = list(db.posts.aggregate(pipeline))
#      13
#      14 # Mostrar los primeros 10
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in aggregate(self, pipeline, session, let, comment, **kwargs)
#    3008         """
#    3009         with self._database.client._tmp_session(session) as s:
# -> 3010             return self._aggregate(
#    3011                 _CollectionAggregationCommand,
#    3012                 pipeline,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in _aggregate(self, aggregation_command, pipeline, cursor_class, session, let, comment, **kwargs)
#    2906         )
#    2907
# -> 2908         return self._database.client._retryable_read(
#    2909             cmd.get_cursor,
#    2910             cmd.get_read_preference(session),  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2046         )
#    2047         with self._tmp_session(session) as s:
# -> 2048             return self._retry_internal(
#    2049                 func,
#    2050                 s,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    2012             retryable=retryable,
#    2013             operation_id=operation_id,
# -> 2014         ).run()
#    2015
#    2016     def _retryable_read(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2761             self._check_last_error(check_csot=True)
#    2762             try:
# -> 2763                 return self._read() if self._is_read else self._write()
#    2764             except ServerSelectionTimeoutError:
#    2765                 # The application may think the write was never attempted
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _read(self)
#    2922                     operationId=self._operation_id,
#    2923                 )
# -> 2924             return self._func(self._session, self._server, conn, read_pref)  # type: ignore
#    2925
#    2926
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/aggregation.py in get_cursor(self, session, server, conn, read_preference)
#     160
#     161         # Run command.
# --> 162         result = conn.command(
#     163             self._database.name,
#     164             cmd,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/helpers.py in inner(*args, **kwargs)
#      45
#      46         try:
# ---> 47             return func(*args, **kwargs)
#      48         except OperationFailure as exc:
#      49             if no_reauth:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     424         # Catch socket.error, KeyboardInterrupt, CancelledError, etc. and close ourselves.
#     425         except BaseException as error:
# --> 426             self._raise_connection_failure(error)
#     427
#     428     def send_message(self, message: bytes, max_doc_size: int) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     396             self._raise_if_not_writable(unacknowledged)
#     397         try:
# --> 398             return command(
#     399                 self,
#     400                 dbname,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/network.py in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     196             response_doc: _DocumentOut = {"ok": 1}
#     197         else:
# --> 198             reply = receive_message(conn, request_id)
#     199             conn.more_to_come = reply.more_to_come
#     200             unpacked_docs = reply.unpack_response(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/network_layer.py in receive_message(conn, request_id, max_message_size)
#     757             deadline = None
#     758     # Ignore the response's request id.
# --> 759     length, _, response_to, op_code = _UNPACK_HEADER(receive_data(conn, 16, deadline))
#     760     # No request_id for exhaust cursor "getMore".
#     761     if request_id is not None:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/network_layer.py in receive_data(conn, length, deadline)
#     351                     conn.set_conn_timeout(short_timeout)
#     352
# --> 353                 chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     354             except BLOCKING_IO_ERRORS:
#     355                 if conn.cancel_context.cancelled:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/network_layer.py in recv_into(self, buffer)
#     467
#     468     def recv_into(self, buffer: bytes | memoryview) -> int:
# --> 469         return self.conn.recv_into(buffer)
#     470
#     471
#
# KeyboardInterrupt:

# %% [markdown]
# ### Ejercicio 8: Repetir el ejercicio anterior, pero obtener el listado en forma de conjunto, con los usuarios que han contestado cada pregunta mostrando para cada usuario su nombre (y no sólo si Id). Limita la búsqueda a 2000.

# %% [markdown]
# ### Ejercicio 9: Encontrar los 5 usuarios más activos (con más posts) y mostrar su nombre, número de posts y puntuación promedio.

# %%
pipeline = [
    # 1️⃣ Agrupar posts por usuario
    {
        "$group": {
            "_id": "$OwnerUserId",               # cada usuario
            "num_posts": {"$sum": 1},            # contar posts
            "avg_score": {"$avg": "$Score"}      # promedio de Score
        }
    },

    # 2️⃣ Ordenar por número de posts descendente
    {"$sort": {"num_posts": -1}},

    # 3️⃣ Limitar a los 5 más activos
    {"$limit": 5},

    # 4️⃣ Unir con la colección users para obtener DisplayName
    {
        "$lookup": {
            "from": "users",
            "localField": "_id",
            "foreignField": "Id",
            "as": "user"
        }
    },

    # 5️⃣ Proyectar los campos finales
    {
        "$project": {
            "_id": 0,
            "user_id": "$_id",
            "name": {"$ifNull": [{"$arrayElemAt": ["$user.DisplayName", 0]}, "Desconocido"]},
            "num_posts": 1,
            "avg_score": 1
        }
    }
]

results = list(db.posts.aggregate(pipeline))

# Mostrar resultados
for r in results:
    print("Usuario:", r["name"])
    print("ID:", r["user_id"])
    print("Número de posts:", r["num_posts"])
    print("Puntuación promedio:", r["avg_score"])
    print("-"*50)
# Out:
# Usuario: Desconocido
# ID: None
# Número de posts: 6467
# Puntuación promedio: 1.164836864079171
# --------------------------------------------------
# Usuario: Jorgesys
# ID: 95
# Número de posts: 5828
# Puntuación promedio: 1.2196293754289635
# --------------------------------------------------
# Usuario: A. Cedano
# ID: 29967
# Número de posts: 3530
# Puntuación promedio: 1.939943342776204
# --------------------------------------------------
# Usuario: Patricio Moracho
# ID: 31764
# Número de posts: 2746
# Puntuación promedio: 1.3794610342316096
# --------------------------------------------------
# Usuario: FJSevilla
# ID: 15089
# Número de posts: 2007
# Puntuación promedio: 1.7568510214250124
# --------------------------------------------------

# %% [markdown]
# ### Ejercicio 10: Analizar los tags más populares: obtener los 10 tags que aparecen en más preguntas, junto con el número de preguntas y la puntuación promedio de las preguntas que los contienen

# %%
print("¡Eso es todo amigos!")
